# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
dataset = datasets.load_breast_cancer()
X = dataset.data
Y = dataset.target
#for i in range(X.shape[1]):
#    X[:, i] = level(X[:, i])
feature_names = dataset.feature_names
class_names = dataset.target_names
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

def info_gain_for_cont_data_split(Y, splits):
    info_gain = 0
    split_info = 0    
    mod_Y = len(Y)
    unique_splits = list(set(splits))
    for s in unique_splits:
        indices = (splits == s)
        Y_split_i = Y[indices]
        #print([X_split_i, Y_split_i])
        mod_Y_i = len(Y_split_i)
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        possible_classes_Y_i = list(set(Y_split_i))
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    return info_gain, split_info

def split(X, Y, feature):
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    mid_values = []
    
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = []
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        current_split_labels[ X[:, feature] <= value ] = 0
        current_split_information_gain, current_split_split_info = info_gain_for_cont_data_split(Y, current_split_labels)
        #print(current_split_information_gain)
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    #print("min_info_gain, min_split_info, best_split_labels, mid_value_for_min_info_gain")
    #print(min_info_gain, min_split_info, best_split_labels, mid_value_for_min_info_gain)
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain



    
def decision_tree(X, Y, features, feature_names, level):
    node = {}
    node["level"] = level
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    max_count = -np.inf
    max_class = possible_classes[0]
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[y] = count_y
        print("Count of", y, "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    node['class_counts'] = class_counts
    node["Entropy"] = current_entropy
    
    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        node["predict_class"] = max_class
        return node
    node["is_leaf"] = False
    selected_feature = None
    max_info_gain = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    for f in features:
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        if info_gain > max_info_gain:
            selected_feature = f
            max_info_gain = info_gain
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f
    
    node["selected_feature"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    node["num_of_examples"] = len(Y)
    
    print("Splitting on feature", selected_feature,"with gain ratio", max_info_gain)
    #splits = split(X, Y, selected_feature)
    unique_splits = list(set(best_split_labels))
    
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    for s in unique_splits:
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, level + 1)
    return node
#print(split(X, Y, 0))
      
    
features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, level = 0)
# Out:
# Level 0
# Count of 0 = 151
# Count of 1 = 275
# Current Entropy is = 0.650163977215
# Splitting on feature 11 with gain ratio 0.641904298647
#
# Level 1
# Count of 0 = 143
# Count of 1 = 239
# Current Entropy is = 0.661228014264
# Splitting on feature 14 with gain ratio 0.653595522098
#
# Level 2
# Count of 0 = 140
# Count of 1 = 221
# Current Entropy is = 0.667759132292
# Splitting on feature 18 with gain ratio 0.651793144141
#
# Level 3
# Count of 0 = 134
# Count of 1 = 221
# Current Entropy is = 0.662809366296
# Splitting on feature 9 with gain ratio 0.644979001072
#
# Level 4
# Count of 0 = 20
# Count of 1 = 9
# Current Entropy is = 0.619376289741
# Splitting on feature 8 with gain ratio 0.524003624695
#
# Level 5
# Count of 0 = 9
# Count of 1 = 8
# Current Entropy is = 0.691416077617
# Splitting on feature 15 with gain ratio 0.509507044199
#
# Level 6
# Count of 0 = 5
# Count of 1 = 8
# Current Entropy is = 0.666278442415
# Splitting on feature 19 with gain ratio 0.587551539964
#
# Level 7
# Count of 0 = 4
# Count of 1 = 8
# Current Entropy is = 0.636514168295
# Splitting on feature 12 with gain ratio 0.519656046922
#
# Level 8
# Count of 0 = 1
# Count of 1 = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 17 with gain ratio 0.357430302527
#
# Level 9
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 1 with gain ratio 0.381908500977
#
# Level 10
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 4 with gain ratio 0.462098120373
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 12
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 3
# Count of 1 = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 10 with gain ratio 0.554517744448
#
# Level 9
# Count of 0 = 2
# Count of 1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 13 with gain ratio 0.69314718056
#
# Level 10
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 11
# Count of 1 = 1
# Current Entropy is = 0.286835983056
# Splitting on feature 17 with gain ratio 0.225280604433
#
# Level 6
# Count of 0 = 5
# Count of 1 = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 7 with gain ratio 0.374890096413
#
# Level 7
# Count of 0 = 3
# Count of 1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 6 with gain ratio 0.477385626221
#
# Level 8
# Count of 0 = 2
# Count of 1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 2 with gain ratio 0.462098120373
#
# Level 9
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 10
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 0 = 114
# Count of 1 = 212
# Current Entropy is = 0.647256542878
# Splitting on feature 19 with gain ratio 0.583491366655
#
# Level 5
# Count of 0 = 29
# Count of 1 = 132
# Current Entropy is = 0.471581800692
# Splitting on feature 8 with gain ratio 0.446812715698
#
# Level 6
# Count of 0 = 1
# Count of 1 = 31
# Current Entropy is = 0.139060798455
# Splitting on feature 24 with gain ratio 0.116895829353
#
# Level 7
# Count of 0 = 1
# Count of 1 = 15
# Current Entropy is = 0.233791658706
# Splitting on feature 28 with gain ratio 0.179425889251
#
# Level 8
# Count of 1 = 9
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Count of 1 = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 1 with gain ratio 0.198042051589
#
# Level 9
# Count of 1 = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 10
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 1 = 16
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 28
# Count of 1 = 101
# Current Entropy is = 0.523154276564
# Splitting on feature 15 with gain ratio 0.457091996965
#
# Level 7
# Count of 1 = 30
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 28
# Count of 1 = 71
# Current Entropy is = 0.595604723318
# Splitting on feature 17 with gain ratio 0.52911579184
#
# Level 8
# Count of 0 = 9
# Count of 1 = 51
# Current Entropy is = 0.422709087806
# Splitting on feature 4 with gain ratio 0.386062052142
#
# Level 9
# Count of 1 = 12
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 9
# Count of 1 = 39
# Current Entropy is = 0.482577565177
# Splitting on feature 12 with gain ratio 0.444303200614
#
# Level 10
# Count of 1 = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 9
# Count of 1 = 31
# Current Entropy is = 0.533163840737
# Splitting on feature 10 with gain ratio 0.494744213164
#
# Level 11
# Count of 0 = 8
# Count of 1 = 31
# Current Entropy is = 0.50742996222
# Splitting on feature 13 with gain ratio 0.458313920678
#
# Level 12
# Count of 0 = 1
# Count of 1 = 15
# Current Entropy is = 0.233791658706
# Splitting on feature 16 with gain ratio 0.188385080628
#
# Level 13
# Count of 0 = 1
# Count of 1 = 7
# Current Entropy is = 0.376770161256
# Splitting on feature 3 with gain ratio 0.281167572309
#
# Level 14
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 0 with gain ratio 0.34657359028
#
# Level 15
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 1 = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 7
# Count of 1 = 16
# Current Entropy is = 0.614503320311
# Splitting on feature 3 with gain ratio 0.55218270993
#
# Level 13
# Count of 0 = 1
# Count of 1 = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 0 with gain ratio 0.27800134641
#
# Level 14
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 20 with gain ratio 0.381908500977
#
# Level 15
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 1 with gain ratio 0.462098120373
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 2 with gain ratio 0.0
#
# Level 17
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 6
# Count of 1 = 8
# Current Entropy is = 0.6829081047
# Splitting on feature 0 with gain ratio 0.618687125099
#
# Level 14
# Count of 0 = 5
# Count of 1 = 8
# Current Entropy is = 0.666278442415
# Splitting on feature 2 with gain ratio 0.587551539964
#
# Level 15
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 4
# Count of 1 = 8
# Current Entropy is = 0.636514168295
# Splitting on feature 1 with gain ratio 0.515221182448
#
# Level 16
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 4
# Count of 1 = 5
# Current Entropy is = 0.686961576597
# Splitting on feature 21 with gain ratio 0.465320791122
#
# Level 17
# Count of 0 = 2
# Count of 1 = 5
# Current Entropy is = 0.598269588585
# Splitting on feature 16 with gain ratio 0.386195321885
#
# Level 18
# Count of 0 = 1
# Count of 1 = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 7 with gain ratio 0.374890096413
#
# Level 19
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 5 with gain ratio 0.0
#
# Level 20
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 20
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 19
# Count of 1 = 20
# Current Entropy is = 0.692818413431
# Splitting on feature 4 with gain ratio 0.618754410055
#
# Level 9
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 19
# Count of 1 = 16
# Current Entropy is = 0.689469199775
# Splitting on feature 16 with gain ratio 0.577144109543
#
# Level 10
# Count of 0 = 1
# Count of 1 = 7
# Current Entropy is = 0.376770161256
# Splitting on feature 28 with gain ratio 0.33792090665
#
# Level 11
# Count of 0 = 1
# Count of 1 = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 5 with gain ratio 0.318257084147
#
# Level 12
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 1 with gain ratio 0.462098120373
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 14
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 18
# Count of 1 = 9
# Current Entropy is = 0.636514168295
# Splitting on feature 24 with gain ratio 0.593594800936
#
# Level 11
# Count of 0 = 3
# Count of 1 = 4
# Current Entropy is = 0.6829081047
# Splitting on feature 28 with gain ratio 0.678764670881
#
# Level 12
# Count of 0 = 2
# Count of 1 = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 2 with gain ratio 0.554517744448
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 2
# Count of 1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.477385626221
#
# Level 14
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 3 with gain ratio 0.462098120373
#
# Level 15
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 15
# Count of 1 = 5
# Current Entropy is = 0.562335144619
# Splitting on feature 5 with gain ratio 0.514927874466
#
# Level 12
# Count of 0 = 12
# Count of 1 = 5
# Current Entropy is = 0.605797499372
# Splitting on feature 25 with gain ratio 0.509507044199
#
# Level 13
# Count of 0 = 8
# Count of 1 = 5
# Current Entropy is = 0.666278442415
# Splitting on feature 26 with gain ratio 0.495806061641
#
# Level 14
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 8
# Count of 1 = 3
# Current Entropy is = 0.585952618304
# Splitting on feature 6 with gain ratio 0.481136900479
#
# Level 15
# Count of 0 = 5
# Count of 1 = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 29 with gain ratio 0.551444327822
#
# Level 16
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 3 with gain ratio 0.462098120373
#
# Level 17
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 18
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 4
# Count of 1 = 1
# Current Entropy is = 0.500402423538
# Splitting on feature 0 with gain ratio 0.277258872224
#
# Level 17
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 18
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 85
# Count of 1 = 80
# Current Entropy is = 0.692687973442
# Splitting on feature 15 with gain ratio 0.652281759986
#
# Level 6
# Count of 0 = 7
# Count of 1 = 24
# Current Entropy is = 0.534159366687
# Splitting on feature 8 with gain ratio 0.498438027989
#
# Level 7
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 7
# Count of 1 = 20
# Current Entropy is = 0.572280698802
# Splitting on feature 4 with gain ratio 0.540620144144
#
# Level 8
# Count of 0 = 6
# Count of 1 = 12
# Current Entropy is = 0.636514168295
# Splitting on feature 28 with gain ratio 0.589348337564
#
# Level 9
# Count of 0 = 4
# Count of 1 = 11
# Current Entropy is = 0.579915171418
# Splitting on feature 24 with gain ratio 0.544221342219
#
# Level 10
# Count of 0 = 1
# Count of 1 = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 5 with gain ratio 0.321334368354
#
# Level 11
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 0 with gain ratio 0.34657359028
#
# Level 12
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 3
# Count of 1 = 5
# Current Entropy is = 0.661563238158
# Splitting on feature 29 with gain ratio 0.627741162589
#
# Level 11
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 1 with gain ratio 0.34657359028
#
# Level 12
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 2
# Count of 1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.477385626221
#
# Level 12
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 16 with gain ratio 0.462098120373
#
# Level 13
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 14
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 2
# Count of 1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 16 with gain ratio 0.462098120373
#
# Level 10
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Count of 1 = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 0 with gain ratio 0.27800134641
#
# Level 9
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 10 with gain ratio 0.381908500977
#
# Level 10
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 28 with gain ratio 0.462098120373
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 12
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 78
# Count of 1 = 56
# Current Entropy is = 0.679608582317
# Splitting on feature 16 with gain ratio 0.659717085368
#
# Level 7
# Count of 0 = 78
# Count of 1 = 53
# Current Entropy is = 0.674825110224
# Splitting on feature 29 with gain ratio 0.62689713647
#
# Level 8
# Count of 0 = 46
# Count of 1 = 46
# Current Entropy is = 0.69314718056
# Splitting on feature 17 with gain ratio 0.619687399512
#
# Level 9
# Count of 0 = 2
# Count of 1 = 15
# Current Entropy is = 0.362210557135
# Splitting on feature 24 with gain ratio 0.294354366787
#
# Level 10
# Count of 1 = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 2
# Count of 1 = 8
# Current Entropy is = 0.500402423538
# Splitting on feature 4 with gain ratio 0.41878871201
#
# Level 11
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 2
# Count of 1 = 5
# Current Entropy is = 0.598269588585
# Splitting on feature 28 with gain ratio 0.555472354116
#
# Level 12
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 1 with gain ratio 0.277258872224
#
# Level 13
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 14
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 13
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 44
# Count of 1 = 31
# Current Entropy is = 0.678048817117
# Splitting on feature 1 with gain ratio 0.602960096912
#
# Level 10
# Count of 0 = 9
# Count of 1 = 18
# Current Entropy is = 0.636514168295
# Splitting on feature 21 with gain ratio 0.588056211696
#
# Level 11
# Count of 0 = 9
# Count of 1 = 15
# Current Entropy is = 0.661563238158
# Splitting on feature 4 with gain ratio 0.51986038542
#
# Level 12
# Count of 1 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 9
# Count of 1 = 9
# Current Entropy is = 0.69314718056
# Splitting on feature 8 with gain ratio 0.636514168295
#
# Level 13
# Count of 0 = 3
# Count of 1 = 6
# Current Entropy is = 0.636514168295
# Splitting on feature 24 with gain ratio 0.499853461883
#
# Level 14
# Count of 0 = 2
# Count of 1 = 6
# Current Entropy is = 0.562335144619
# Splitting on feature 26 with gain ratio 0.477385626221
#
# Level 15
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 2
# Count of 1 = 4
# Current Entropy is = 0.636514168295
# Splitting on feature 25 with gain ratio 0.560843055841
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 2
# Count of 1 = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 5 with gain ratio 0.554517744448
#
# Level 17
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 2
# Count of 1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 27 with gain ratio 0.69314718056
#
# Level 18
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 19
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 19
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 6
# Count of 1 = 3
# Current Entropy is = 0.636514168295
# Splitting on feature 12 with gain ratio 0.588056211696
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 5
# Count of 1 = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 5 with gain ratio 0.51986038542
#
# Level 15
# Count of 0 = 3
# Count of 1 = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 25 with gain ratio 0.560843055841
#
# Level 16
# Count of 0 = 2
# Count of 1 = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 10 with gain ratio 0.449868115695
#
# Level 17
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 0 with gain ratio 0.34657359028
#
# Level 18
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 2 with gain ratio 0.0
#
# Level 19
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 35
# Count of 1 = 13
# Current Entropy is = 0.584085931759
# Splitting on feature 21 with gain ratio 0.525484190322
#
# Level 11
# Count of 0 = 27
# Count of 1 = 13
# Current Entropy is = 0.630581028386
# Splitting on feature 25 with gain ratio 0.509404971819
#
# Level 12
# Count of 0 = 12
# Count of 1 = 12
# Current Entropy is = 0.69314718056
# Splitting on feature 5 with gain ratio 0.562335144619
#
# Level 13
# Count of 0 = 3
# Count of 1 = 9
# Current Entropy is = 0.562335144619
# Splitting on feature 26 with gain ratio 0.477385626221
#
# Level 14
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 3
# Count of 1 = 6
# Current Entropy is = 0.636514168295
# Splitting on feature 6 with gain ratio 0.588056211696
#
# Level 15
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 3
# Count of 1 = 5
# Current Entropy is = 0.661563238158
# Splitting on feature 28 with gain ratio 0.420632291881
#
# Level 16
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 3
# Count of 1 = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 8 with gain ratio 0.449868115695
#
# Level 17
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 3
# Count of 1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 3 with gain ratio 0.34657359028
#
# Level 18
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 19
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 9
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 26 with gain ratio 0.398363061075
#
# Level 14
# Count of 0 = 4
# Count of 1 = 3
# Current Entropy is = 0.6829081047
# Splitting on feature 6 with gain ratio 0.480722619292
#
# Level 15
# Count of 0 = 2
# Count of 1 = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 4 with gain ratio 0.381908500977
#
# Level 16
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 2
# Count of 1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 24 with gain ratio 0.462098120373
#
# Level 17
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 18
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 15
# Count of 1 = 1
# Current Entropy is = 0.233791658706
# Splitting on feature 8 with gain ratio 0.188385080628
#
# Level 13
# Count of 0 = 7
# Count of 1 = 1
# Current Entropy is = 0.376770161256
# Splitting on feature 23 with gain ratio 0.281167572309
#
# Level 14
# Count of 0 = 3
# Count of 1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 0 with gain ratio 0.34657359028
#
# Level 15
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 2 with gain ratio 0.0
#
# Level 16
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 32
# Count of 1 = 7
# Current Entropy is = 0.470614981181
# Splitting on feature 17 with gain ratio 0.460223000873
#
# Level 9
# Count of 0 = 15
# Count of 1 = 2
# Current Entropy is = 0.362210557135
# Splitting on feature 28 with gain ratio 0.324235498382
#
# Level 10
# Count of 0 = 2
# Count of 1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 4 with gain ratio 0.462098120373
#
# Level 11
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 12
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 13
# Count of 1 = 1
# Current Entropy is = 0.257318640544
# Splitting on feature 5 with gain ratio 0.205058159144
#
# Level 11
# Count of 0 = 6
# Count of 1 = 1
# Current Entropy is = 0.410116318288
# Splitting on feature 3 with gain ratio 0.321334368354
#
# Level 12
# Count of 0 = 3
# Count of 1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 0 with gain ratio 0.34657359028
#
# Level 13
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.0
#
# Level 14
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 17
# Count of 1 = 5
# Current Entropy is = 0.535959889216
# Splitting on feature 26 with gain ratio 0.463483031237
#
# Level 10
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 4 with gain ratio 0.462098120373
#
# Level 11
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 12
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 16
# Count of 1 = 3
# Current Entropy is = 0.436162325385
# Splitting on feature 25 with gain ratio 0.355159038707
#
# Level 11
# Count of 0 = 9
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 28 with gain ratio 0.477385626221
#
# Level 12
# Count of 0 = 6
# Count of 1 = 3
# Current Entropy is = 0.636514168295
# Splitting on feature 21 with gain ratio 0.462098120373
#
# Level 13
# Count of 0 = 3
# Count of 1 = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 1 with gain ratio 0.560843055841
#
# Level 14
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of 0 = 3
# Count of 1 = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 6 with gain ratio 0.381908500977
#
# Level 15
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 8 with gain ratio 0.462098120373
#
# Level 16
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 17
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of 0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of 0 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of 0 = 3
# Count of 1 = 18
# Current Entropy is = 0.410116318288
# Splitting on feature 15 with gain ratio 0.37723749373
#
# Level 3
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of 0 = 3
# Count of 1 = 14
# Current Entropy is = 0.465999256961
# Splitting on feature 5 with gain ratio 0.441531550181
#
# Level 4
# Count of 0 = 3
# Count of 1 = 12
# Current Entropy is = 0.500402423538
# Splitting on feature 18 with gain ratio 0.464499576415
#
# Level 5
# Count of 0 = 2
# Count of 1 = 11
# Current Entropy is = 0.429323021931
# Splitting on feature 24 with gain ratio 0.384924941183
#
# Level 6
# Count of 0 = 2
# Count of 1 = 8
# Current Entropy is = 0.500402423538
# Splitting on feature 4 with gain ratio 0.41878871201
#
# Level 7
# Count of 0 = 2
# Count of 1 = 5
# Current Entropy is = 0.598269588585
# Splitting on feature 8 with gain ratio 0.555472354116
#
# Level 8
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 9
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 17 with gain ratio 0.381908500977
#
# Level 9
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 16 with gain ratio 0.462098120373
#
# Level 10
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 11
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 6
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of 0 = 8
# Count of 1 = 36
# Current Entropy is = 0.474139313058
# Splitting on feature 14 with gain ratio 0.449767466513
#
# Level 2
# Count of 0 = 8
# Count of 1 = 31
# Current Entropy is = 0.50742996222
# Splitting on feature 18 with gain ratio 0.472469074456
#
# Level 3
# Count of 0 = 7
# Count of 1 = 18
# Current Entropy is = 0.592953317447
# Splitting on feature 21 with gain ratio 0.548980026925
#
# Level 4
# Count of 0 = 1
# Count of 1 = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 5 with gain ratio 0.300374139244
#
# Level 5
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 1
# Count of 1 = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 0 with gain ratio 0.374890096413
#
# Level 6
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 8 with gain ratio 0.477385626221
#
# Level 7
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 1 with gain ratio 0.462098120373
#
# Level 8
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 2 with gain ratio 0.0
#
# Level 9
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 0 = 6
# Count of 1 = 10
# Current Entropy is = 0.661563238158
# Splitting on feature 28 with gain ratio 0.482346535083
#
# Level 5
# Count of 0 = 2
# Count of 1 = 9
# Current Entropy is = 0.474139313058
# Splitting on feature 9 with gain ratio 0.411434838519
#
# Level 6
# Count of 0 = 1
# Count of 1 = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 24 with gain ratio 0.27800134641
#
# Level 7
# Count of 1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 1
# Count of 1 = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 1 with gain ratio 0.381908500977
#
# Level 8
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 4 with gain ratio 0.462098120373
#
# Level 9
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 10
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 7
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 4
# Count of 1 = 1
# Current Entropy is = 0.500402423538
# Splitting on feature 8 with gain ratio 0.381908500977
#
# Level 6
# Count of 0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 0 = 2
# Count of 1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 1 with gain ratio 0.462098120373
#
# Level 7
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 8
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of 0 = 1
# Count of 1 = 13
# Current Entropy is = 0.257318640544
# Splitting on feature 4 with gain ratio 0.205058159144
#
# Level 4
# Count of 1 = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 0 = 1
# Count of 1 = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 9 with gain ratio 0.321334368354
#
# Level 5
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of 0 = 1
# Count of 1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 6 with gain ratio 0.477385626221
#
# Level 6
# Count of 0 = 1
# Count of 1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 5 with gain ratio 0.462098120373
#
# Level 7
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of 0 = 1
# Count of 1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 0 with gain ratio 0.0
#
# Level 8
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of 0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of 1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of 1 = 5
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature"]
    feature_value = tree_dict["best_split_mid_value"]

    #print("Feature:", feature_names[index])
    #print("Feature Value:", feature_value)
    
    if X[index] <= feature_value :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    else :
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])

def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary, level = 0):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key], level + 1)
        else:
            print(key, dictionary[key])


print_dict(tree_dict)
# Out:
# level 0
# class_counts 0 151
# 1 275
# Entropy 0.650163977215
# is_leaf False
# selected_feature 11
# max_info_gain 0.641904298647
# best_split_mid_value 1.9
# num_of_examples 426
# 0 level 1
# class_counts 0 143
# 1 239
# Entropy 0.661228014264
# is_leaf False
# selected_feature 14
# max_info_gain 0.653595522098
# best_split_mid_value 0.0112445
# num_of_examples 382
# 0 level 2
# class_counts 0 140
# 1 221
# Entropy 0.667759132292
# is_leaf False
# selected_feature 18
# max_info_gain 0.651793144141
# best_split_mid_value 0.04631
# num_of_examples 361
# 0 level 3
# class_counts 0 134
# 1 221
# Entropy 0.662809366296
# is_leaf False
# selected_feature 9
# max_info_gain 0.644979001072
# best_split_mid_value 0.054965
# num_of_examples 355
# 0 level 4
# class_counts 0 20
# 1 9
# Entropy 0.619376289741
# is_leaf False
# selected_feature 8
# max_info_gain 0.524003624695
# best_split_mid_value 0.17145
# num_of_examples 29
# 0 level 5
# class_counts 0 9
# 1 8
# Entropy 0.691416077617
# is_leaf False
# selected_feature 15
# max_info_gain 0.509507044199
# best_split_mid_value 0.02406
# num_of_examples 17
# 0 level 6
# class_counts 0 5
# 1 8
# Entropy 0.666278442415
# is_leaf False
# selected_feature 19
# max_info_gain 0.587551539964
# best_split_mid_value 0.002108
# num_of_examples 13
# 0 level 7
# class_counts 0 4
# 1 8
# Entropy 0.636514168295
# is_leaf False
# selected_feature 12
# max_info_gain 0.519656046922
# best_split_mid_value 1.744
# num_of_examples 12
# 0 level 8
# class_counts 0 1
# 1 6
# Entropy 0.410116318288
# is_leaf False
# selected_feature 17
# max_info_gain 0.357430302527
# best_split_mid_value 0.004208
# num_of_examples 7
# 0 level 9
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 1
# max_info_gain 0.381908500977
# best_split_mid_value 17.64
# num_of_examples 5
# 0 level 10
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.07708
# num_of_examples 3
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 15.29
# num_of_examples 2
# 0 level 12
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 3
# 1 2
# Entropy 0.673011667009
# is_leaf False
# selected_feature 10
# max_info_gain 0.554517744448
# best_split_mid_value 0.5097
# num_of_examples 5
# 0 level 9
# class_counts 0 2
# 1 2
# Entropy 0.69314718056
# is_leaf False
# selected_feature 13
# max_info_gain 0.69314718056
# best_split_mid_value 32.635
# num_of_examples 4
# 0 level 10
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 16.46
# num_of_examples 2
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 16.04
# num_of_examples 2
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts 0 4
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 5
# class_counts 0 11
# 1 1
# Entropy 0.286835983056
# is_leaf False
# selected_feature 17
# max_info_gain 0.225280604433
# best_split_mid_value 0.013205
# num_of_examples 12
# 0 level 6
# class_counts 0 5
# 1 1
# Entropy 0.450561208866
# is_leaf False
# selected_feature 7
# max_info_gain 0.374890096413
# best_split_mid_value 0.06534
# num_of_examples 6
# 0 level 7
# class_counts 0 3
# 1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature 6
# max_info_gain 0.477385626221
# best_split_mid_value 0.06337
# num_of_examples 4
# 0 level 8
# class_counts 0 2
# 1 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature 2
# max_info_gain 0.462098120373
# best_split_mid_value 101.905
# num_of_examples 3
# 0 level 9
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.735
# num_of_examples 2
# 0 level 10
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts 0 6
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 4
# class_counts 0 114
# 1 212
# Entropy 0.647256542878
# is_leaf False
# selected_feature 19
# max_info_gain 0.583491366655
# best_split_mid_value 0.003035
# num_of_examples 326
# 0 level 5
# class_counts 0 29
# 1 132
# Entropy 0.471581800692
# is_leaf False
# selected_feature 8
# max_info_gain 0.446812715698
# best_split_mid_value 0.1557
# num_of_examples 161
# 0 level 6
# class_counts 0 1
# 1 31
# Entropy 0.139060798455
# is_leaf False
# selected_feature 24
# max_info_gain 0.116895829353
# best_split_mid_value 0.12655
# num_of_examples 32
# 0 level 7
# class_counts 0 1
# 1 15
# Entropy 0.233791658706
# is_leaf False
# selected_feature 28
# max_info_gain 0.179425889251
# best_split_mid_value 0.24325
# num_of_examples 16
# 0 level 8
# class_counts 1 9
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts 0 1
# 1 6
# Entropy 0.410116318288
# is_leaf False
# selected_feature 1
# max_info_gain 0.198042051589
# best_split_mid_value 24.705
# num_of_examples 7
# 0 level 9
# class_counts 1 5
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 16.985
# num_of_examples 2
# 0 level 10
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 1 16
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 0 28
# 1 101
# Entropy 0.523154276564
# is_leaf False
# selected_feature 15
# max_info_gain 0.457091996965
# best_split_mid_value 0.010106
# num_of_examples 129
# 0 level 7
# class_counts 1 30
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 0 28
# 1 71
# Entropy 0.595604723318
# is_leaf False
# selected_feature 17
# max_info_gain 0.52911579184
# best_split_mid_value 0.0092215
# num_of_examples 99
# 0 level 8
# class_counts 0 9
# 1 51
# Entropy 0.422709087806
# is_leaf False
# selected_feature 4
# max_info_gain 0.386062052142
# best_split_mid_value 0.0815
# num_of_examples 60
# 0 level 9
# class_counts 1 12
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 9
# 1 39
# Entropy 0.482577565177
# is_leaf False
# selected_feature 12
# max_info_gain 0.444303200614
# best_split_mid_value 1.305
# num_of_examples 48
# 0 level 10
# class_counts 1 8
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 9
# 1 31
# Entropy 0.533163840737
# is_leaf False
# selected_feature 10
# max_info_gain 0.494744213164
# best_split_mid_value 0.4335
# num_of_examples 40
# 0 level 11
# class_counts 0 8
# 1 31
# Entropy 0.50742996222
# is_leaf False
# selected_feature 13
# max_info_gain 0.458313920678
# best_split_mid_value 19.39
# num_of_examples 39
# 0 level 12
# class_counts 0 1
# 1 15
# Entropy 0.233791658706
# is_leaf False
# selected_feature 16
# max_info_gain 0.188385080628
# best_split_mid_value 0.015035
# num_of_examples 16
# 0 level 13
# class_counts 0 1
# 1 7
# Entropy 0.376770161256
# is_leaf False
# selected_feature 3
# max_info_gain 0.281167572309
# best_split_mid_value 475.0
# num_of_examples 8
# 0 level 14
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 0
# max_info_gain 0.34657359028
# best_split_mid_value 13.19
# num_of_examples 4
# 0 level 15
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 17.795
# num_of_examples 2
# 0 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 1 8
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 7
# 1 16
# Entropy 0.614503320311
# is_leaf False
# selected_feature 3
# max_info_gain 0.55218270993
# best_split_mid_value 562.15
# num_of_examples 23
# 0 level 13
# class_counts 0 1
# 1 8
# Entropy 0.348832095843
# is_leaf False
# selected_feature 0
# max_info_gain 0.27800134641
# best_split_mid_value 12.485
# num_of_examples 9
# 0 level 14
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 20
# max_info_gain 0.381908500977
# best_split_mid_value 14.345
# num_of_examples 5
# 0 level 15
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 15
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 1
# max_info_gain 0.462098120373
# best_split_mid_value 16.72
# num_of_examples 3
# 0 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 2
# max_info_gain 0.0
# best_split_mid_value 82.195
# num_of_examples 2
# 0 level 17
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 17
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 6
# 1 8
# Entropy 0.6829081047
# is_leaf False
# selected_feature 0
# max_info_gain 0.618687125099
# best_split_mid_value 17.38
# num_of_examples 14
# 0 level 14
# class_counts 0 5
# 1 8
# Entropy 0.666278442415
# is_leaf False
# selected_feature 2
# max_info_gain 0.587551539964
# best_split_mid_value 86.685
# num_of_examples 13
# 0 level 15
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 0 4
# 1 8
# Entropy 0.636514168295
# is_leaf False
# selected_feature 1
# max_info_gain 0.515221182448
# best_split_mid_value 16.46
# num_of_examples 12
# 0 level 16
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 4
# 1 5
# Entropy 0.686961576597
# is_leaf False
# selected_feature 21
# max_info_gain 0.465320791122
# best_split_mid_value 29.605
# num_of_examples 9
# 0 level 17
# class_counts 0 2
# 1 5
# Entropy 0.598269588585
# is_leaf False
# selected_feature 16
# max_info_gain 0.386195321885
# best_split_mid_value 0.0203
# num_of_examples 7
# 0 level 18
# class_counts 0 1
# 1 5
# Entropy 0.450561208866
# is_leaf False
# selected_feature 7
# max_info_gain 0.374890096413
# best_split_mid_value 0.026085
# num_of_examples 6
# 0 level 19
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 19
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 5
# max_info_gain 0.0
# best_split_mid_value 0.092025
# num_of_examples 4
# 0 level 20
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 20
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 18
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 17
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 19
# 1 20
# Entropy 0.692818413431
# is_leaf False
# selected_feature 4
# max_info_gain 0.618754410055
# best_split_mid_value 0.090105
# num_of_examples 39
# 0 level 9
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 19
# 1 16
# Entropy 0.689469199775
# is_leaf False
# selected_feature 16
# max_info_gain 0.577144109543
# best_split_mid_value 0.019245
# num_of_examples 35
# 0 level 10
# class_counts 0 1
# 1 7
# Entropy 0.376770161256
# is_leaf False
# selected_feature 28
# max_info_gain 0.33792090665
# best_split_mid_value 0.2839
# num_of_examples 8
# 0 level 11
# class_counts 0 1
# 1 5
# Entropy 0.450561208866
# is_leaf False
# selected_feature 5
# max_info_gain 0.318257084147
# best_split_mid_value 0.07481
# num_of_examples 6
# 0 level 12
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 1
# max_info_gain 0.462098120373
# best_split_mid_value 18.81
# num_of_examples 3
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 12.805
# num_of_examples 2
# 0 level 14
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 18
# 1 9
# Entropy 0.636514168295
# is_leaf False
# selected_feature 24
# max_info_gain 0.593594800936
# best_split_mid_value 0.1397
# num_of_examples 27
# 0 level 11
# class_counts 0 3
# 1 4
# Entropy 0.6829081047
# is_leaf False
# selected_feature 28
# max_info_gain 0.678764670881
# best_split_mid_value 0.30245
# num_of_examples 7
# 0 level 12
# class_counts 0 2
# 1 3
# Entropy 0.673011667009
# is_leaf False
# selected_feature 2
# max_info_gain 0.554517744448
# best_split_mid_value 89.285
# num_of_examples 5
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 2
# 1 2
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.477385626221
# best_split_mid_value 16.88
# num_of_examples 4
# 0 level 14
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 3
# max_info_gain 0.462098120373
# best_split_mid_value 729.95
# num_of_examples 3
# 0 level 15
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 17.125
# num_of_examples 2
# 0 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.58
# num_of_examples 2
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 15
# 1 5
# Entropy 0.562335144619
# is_leaf False
# selected_feature 5
# max_info_gain 0.514927874466
# best_split_mid_value 0.1362
# num_of_examples 20
# 0 level 12
# class_counts 0 12
# 1 5
# Entropy 0.605797499372
# is_leaf False
# selected_feature 25
# max_info_gain 0.509507044199
# best_split_mid_value 0.30585
# num_of_examples 17
# 0 level 13
# class_counts 0 8
# 1 5
# Entropy 0.666278442415
# is_leaf False
# selected_feature 26
# max_info_gain 0.495806061641
# best_split_mid_value 0.2269
# num_of_examples 13
# 0 level 14
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 8
# 1 3
# Entropy 0.585952618304
# is_leaf False
# selected_feature 6
# max_info_gain 0.481136900479
# best_split_mid_value 0.1366
# num_of_examples 11
# 0 level 15
# class_counts 0 5
# 1 3
# Entropy 0.661563238158
# is_leaf False
# selected_feature 29
# max_info_gain 0.551444327822
# best_split_mid_value 0.078995
# num_of_examples 8
# 0 level 16
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 3
# max_info_gain 0.462098120373
# best_split_mid_value 565.85
# num_of_examples 3
# 0 level 17
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 13.47
# num_of_examples 2
# 0 level 18
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 18
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 17
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 4
# 1 1
# Entropy 0.500402423538
# is_leaf False
# selected_feature 0
# max_info_gain 0.277258872224
# best_split_mid_value 16.515
# num_of_examples 5
# 0 level 17
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 15.705
# num_of_examples 2
# 0 level 18
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 18
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 17
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 4
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 5
# class_counts 0 85
# 1 80
# Entropy 0.692687973442
# is_leaf False
# selected_feature 15
# max_info_gain 0.652281759986
# best_split_mid_value 0.020805
# num_of_examples 165
# 0 level 6
# class_counts 0 7
# 1 24
# Entropy 0.534159366687
# is_leaf False
# selected_feature 8
# max_info_gain 0.498438027989
# best_split_mid_value 0.15275
# num_of_examples 31
# 0 level 7
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 0 7
# 1 20
# Entropy 0.572280698802
# is_leaf False
# selected_feature 4
# max_info_gain 0.540620144144
# best_split_mid_value 0.102135
# num_of_examples 27
# 0 level 8
# class_counts 0 6
# 1 12
# Entropy 0.636514168295
# is_leaf False
# selected_feature 28
# max_info_gain 0.589348337564
# best_split_mid_value 0.3501
# num_of_examples 18
# 0 level 9
# class_counts 0 4
# 1 11
# Entropy 0.579915171418
# is_leaf False
# selected_feature 24
# max_info_gain 0.544221342219
# best_split_mid_value 0.1236
# num_of_examples 15
# 0 level 10
# class_counts 0 1
# 1 6
# Entropy 0.410116318288
# is_leaf False
# selected_feature 5
# max_info_gain 0.321334368354
# best_split_mid_value 0.05644
# num_of_examples 7
# 0 level 11
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 0
# max_info_gain 0.34657359028
# best_split_mid_value 15.53
# num_of_examples 4
# 0 level 12
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 19.655
# num_of_examples 2
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts 0 3
# 1 5
# Entropy 0.661563238158
# is_leaf False
# selected_feature 29
# max_info_gain 0.627741162589
# best_split_mid_value 0.085115
# num_of_examples 8
# 0 level 11
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 1
# max_info_gain 0.34657359028
# best_split_mid_value 18.41
# num_of_examples 4
# 0 level 12
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 13.955
# num_of_examples 2
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 2
# 1 2
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.477385626221
# best_split_mid_value 16.895
# num_of_examples 4
# 0 level 12
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 16
# max_info_gain 0.462098120373
# best_split_mid_value 0.02047
# num_of_examples 3
# 0 level 13
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 13.25
# num_of_examples 2
# 0 level 14
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 0 2
# 1 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature 16
# max_info_gain 0.462098120373
# best_split_mid_value 0.033785
# num_of_examples 3
# 0 level 10
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 15.805
# num_of_examples 2
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 1
# 1 8
# Entropy 0.348832095843
# is_leaf False
# selected_feature 0
# max_info_gain 0.27800134641
# best_split_mid_value 11.08
# num_of_examples 9
# 0 level 9
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 10
# max_info_gain 0.381908500977
# best_split_mid_value 0.24165
# num_of_examples 5
# 0 level 10
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 28
# max_info_gain 0.462098120373
# best_split_mid_value 0.29575
# num_of_examples 3
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 17.225
# num_of_examples 2
# 0 level 12
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 0 78
# 1 56
# Entropy 0.679608582317
# is_leaf False
# selected_feature 16
# max_info_gain 0.659717085368
# best_split_mid_value 0.110065
# num_of_examples 134
# 0 level 7
# class_counts 0 78
# 1 53
# Entropy 0.674825110224
# is_leaf False
# selected_feature 29
# max_info_gain 0.62689713647
# best_split_mid_value 0.10236
# num_of_examples 131
# 0 level 8
# class_counts 0 46
# 1 46
# Entropy 0.69314718056
# is_leaf False
# selected_feature 17
# max_info_gain 0.619687399512
# best_split_mid_value 0.0115455
# num_of_examples 92
# 0 level 9
# class_counts 0 2
# 1 15
# Entropy 0.362210557135
# is_leaf False
# selected_feature 24
# max_info_gain 0.294354366787
# best_split_mid_value 0.1272
# num_of_examples 17
# 0 level 10
# class_counts 1 7
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 2
# 1 8
# Entropy 0.500402423538
# is_leaf False
# selected_feature 4
# max_info_gain 0.41878871201
# best_split_mid_value 0.101195
# num_of_examples 10
# 0 level 11
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 2
# 1 5
# Entropy 0.598269588585
# is_leaf False
# selected_feature 28
# max_info_gain 0.555472354116
# best_split_mid_value 0.3245
# num_of_examples 7
# 0 level 12
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 1
# max_info_gain 0.277258872224
# best_split_mid_value 17.265
# num_of_examples 5
# 0 level 13
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.985
# num_of_examples 2
# 0 level 14
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 15.99
# num_of_examples 2
# 0 level 13
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 13
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 0 44
# 1 31
# Entropy 0.678048817117
# is_leaf False
# selected_feature 1
# max_info_gain 0.602960096912
# best_split_mid_value 18.575
# num_of_examples 75
# 0 level 10
# class_counts 0 9
# 1 18
# Entropy 0.636514168295
# is_leaf False
# selected_feature 21
# max_info_gain 0.588056211696
# best_split_mid_value 26.63
# num_of_examples 27
# 0 level 11
# class_counts 0 9
# 1 15
# Entropy 0.661563238158
# is_leaf False
# selected_feature 4
# max_info_gain 0.51986038542
# best_split_mid_value 0.08931
# num_of_examples 24
# 0 level 12
# class_counts 1 6
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 9
# 1 9
# Entropy 0.69314718056
# is_leaf False
# selected_feature 8
# max_info_gain 0.636514168295
# best_split_mid_value 0.1949
# num_of_examples 18
# 0 level 13
# class_counts 0 3
# 1 6
# Entropy 0.636514168295
# is_leaf False
# selected_feature 24
# max_info_gain 0.499853461883
# best_split_mid_value 0.15535
# num_of_examples 9
# 0 level 14
# class_counts 0 2
# 1 6
# Entropy 0.562335144619
# is_leaf False
# selected_feature 26
# max_info_gain 0.477385626221
# best_split_mid_value 0.20105
# num_of_examples 8
# 0 level 15
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 15
# class_counts 0 2
# 1 4
# Entropy 0.636514168295
# is_leaf False
# selected_feature 25
# max_info_gain 0.560843055841
# best_split_mid_value 0.2753
# num_of_examples 6
# 0 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 2
# 1 3
# Entropy 0.673011667009
# is_leaf False
# selected_feature 5
# max_info_gain 0.554517744448
# best_split_mid_value 0.1085
# num_of_examples 5
# 0 level 17
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 17
# class_counts 0 2
# 1 2
# Entropy 0.69314718056
# is_leaf False
# selected_feature 27
# max_info_gain 0.69314718056
# best_split_mid_value 0.16975
# num_of_examples 4
# 0 level 18
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 15.995
# num_of_examples 2
# 0 level 19
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 19
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 18
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.685
# num_of_examples 2
# 0 level 19
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 19
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 6
# 1 3
# Entropy 0.636514168295
# is_leaf False
# selected_feature 12
# max_info_gain 0.588056211696
# best_split_mid_value 2.606
# num_of_examples 9
# 0 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 14
# class_counts 0 5
# 1 3
# Entropy 0.661563238158
# is_leaf False
# selected_feature 5
# max_info_gain 0.51986038542
# best_split_mid_value 0.20145
# num_of_examples 8
# 0 level 15
# class_counts 0 3
# 1 3
# Entropy 0.69314718056
# is_leaf False
# selected_feature 25
# max_info_gain 0.560843055841
# best_split_mid_value 0.37145
# num_of_examples 6
# 0 level 16
# class_counts 0 2
# 1 3
# Entropy 0.673011667009
# is_leaf False
# selected_feature 10
# max_info_gain 0.449868115695
# best_split_mid_value 0.6295
# num_of_examples 5
# 0 level 17
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 0
# max_info_gain 0.34657359028
# best_split_mid_value 14.87
# num_of_examples 4
# 0 level 18
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 18
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 2
# max_info_gain 0.0
# best_split_mid_value 101.04
# num_of_examples 2
# 0 level 19
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 19
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 17
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 16
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 35
# 1 13
# Entropy 0.584085931759
# is_leaf False
# selected_feature 21
# max_info_gain 0.525484190322
# best_split_mid_value 33.305
# num_of_examples 48
# 0 level 11
# class_counts 0 27
# 1 13
# Entropy 0.630581028386
# is_leaf False
# selected_feature 25
# max_info_gain 0.509404971819
# best_split_mid_value 0.3572
# num_of_examples 40
# 0 level 12
# class_counts 0 12
# 1 12
# Entropy 0.69314718056
# is_leaf False
# selected_feature 5
# max_info_gain 0.562335144619
# best_split_mid_value 0.11895
# num_of_examples 24
# 0 level 13
# class_counts 0 3
# 1 9
# Entropy 0.562335144619
# is_leaf False
# selected_feature 26
# max_info_gain 0.477385626221
# best_split_mid_value 0.2113
# num_of_examples 12
# 0 level 14
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 3
# 1 6
# Entropy 0.636514168295
# is_leaf False
# selected_feature 6
# max_info_gain 0.588056211696
# best_split_mid_value 0.07401
# num_of_examples 9
# 0 level 15
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 15
# class_counts 0 3
# 1 5
# Entropy 0.661563238158
# is_leaf False
# selected_feature 28
# max_info_gain 0.420632291881
# best_split_mid_value 0.2342
# num_of_examples 8
# 0 level 16
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 3
# 1 2
# Entropy 0.673011667009
# is_leaf False
# selected_feature 8
# max_info_gain 0.449868115695
# best_split_mid_value 0.16045
# num_of_examples 5
# 0 level 17
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 17
# class_counts 0 3
# 1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature 3
# max_info_gain 0.34657359028
# best_split_mid_value 679.55
# num_of_examples 4
# 0 level 18
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.04
# num_of_examples 2
# 0 level 19
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 19
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 18
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 9
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 26
# max_info_gain 0.398363061075
# best_split_mid_value 0.38575
# num_of_examples 12
# 0 level 14
# class_counts 0 4
# 1 3
# Entropy 0.6829081047
# is_leaf False
# selected_feature 6
# max_info_gain 0.480722619292
# best_split_mid_value 0.1539
# num_of_examples 7
# 0 level 15
# class_counts 0 2
# 1 3
# Entropy 0.673011667009
# is_leaf False
# selected_feature 4
# max_info_gain 0.381908500977
# best_split_mid_value 0.092415
# num_of_examples 5
# 0 level 16
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 2
# 1 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature 24
# max_info_gain 0.462098120373
# best_split_mid_value 0.1344
# num_of_examples 3
# 0 level 17
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.36
# num_of_examples 2
# 0 level 18
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 18
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 17
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 14
# class_counts 0 5
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 15
# 1 1
# Entropy 0.233791658706
# is_leaf False
# selected_feature 8
# max_info_gain 0.188385080628
# best_split_mid_value 0.1892
# num_of_examples 16
# 0 level 13
# class_counts 0 7
# 1 1
# Entropy 0.376770161256
# is_leaf False
# selected_feature 23
# max_info_gain 0.281167572309
# best_split_mid_value 1430.95
# num_of_examples 8
# 0 level 14
# class_counts 0 3
# 1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature 0
# max_info_gain 0.34657359028
# best_split_mid_value 14.765
# num_of_examples 4
# 0 level 15
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 2
# max_info_gain 0.0
# best_split_mid_value 94.72
# num_of_examples 2
# 0 level 16
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 15
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 14
# class_counts 0 4
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 8
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 8
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 32
# 1 7
# Entropy 0.470614981181
# is_leaf False
# selected_feature 17
# max_info_gain 0.460223000873
# best_split_mid_value 0.013055
# num_of_examples 39
# 0 level 9
# class_counts 0 15
# 1 2
# Entropy 0.362210557135
# is_leaf False
# selected_feature 28
# max_info_gain 0.324235498382
# best_split_mid_value 0.32525
# num_of_examples 17
# 0 level 10
# class_counts 0 2
# 1 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.1123
# num_of_examples 3
# 0 level 11
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 12.935
# num_of_examples 2
# 0 level 12
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts 0 13
# 1 1
# Entropy 0.257318640544
# is_leaf False
# selected_feature 5
# max_info_gain 0.205058159144
# best_split_mid_value 0.1521
# num_of_examples 14
# 0 level 11
# class_counts 0 6
# 1 1
# Entropy 0.410116318288
# is_leaf False
# selected_feature 3
# max_info_gain 0.321334368354
# best_split_mid_value 593.15
# num_of_examples 7
# 0 level 12
# class_counts 0 3
# 1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature 0
# max_info_gain 0.34657359028
# best_split_mid_value 13.14
# num_of_examples 4
# 0 level 13
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.0
# best_split_mid_value 23.19
# num_of_examples 2
# 0 level 14
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 7
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 0 17
# 1 5
# Entropy 0.535959889216
# is_leaf False
# selected_feature 26
# max_info_gain 0.463483031237
# best_split_mid_value 0.3616
# num_of_examples 22
# 0 level 10
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.123525
# num_of_examples 3
# 0 level 11
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 12.49
# num_of_examples 2
# 0 level 12
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 12
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 16
# 1 3
# Entropy 0.436162325385
# is_leaf False
# selected_feature 25
# max_info_gain 0.355159038707
# best_split_mid_value 0.5969
# num_of_examples 19
# 0 level 11
# class_counts 0 9
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 28
# max_info_gain 0.477385626221
# best_split_mid_value 0.3377
# num_of_examples 12
# 0 level 12
# class_counts 0 6
# 1 3
# Entropy 0.636514168295
# is_leaf False
# selected_feature 21
# max_info_gain 0.462098120373
# best_split_mid_value 28.26
# num_of_examples 9
# 0 level 13
# class_counts 0 3
# 1 3
# Entropy 0.69314718056
# is_leaf False
# selected_feature 1
# max_info_gain 0.560843055841
# best_split_mid_value 15.69
# num_of_examples 6
# 0 level 14
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 14
# class_counts 0 3
# 1 2
# Entropy 0.673011667009
# is_leaf False
# selected_feature 6
# max_info_gain 0.381908500977
# best_split_mid_value 0.17135
# num_of_examples 5
# 0 level 15
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 8
# max_info_gain 0.462098120373
# best_split_mid_value 0.18275
# num_of_examples 3
# 0 level 16
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 16
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 13.4
# num_of_examples 2
# 0 level 17
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 17
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 15
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 13
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 12
# class_counts 0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 11
# class_counts 0 7
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 3
# class_counts 0 6
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 2
# class_counts 0 3
# 1 18
# Entropy 0.410116318288
# is_leaf False
# selected_feature 15
# max_info_gain 0.37723749373
# best_split_mid_value 0.017546
# num_of_examples 21
# 0 level 3
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 3
# class_counts 0 3
# 1 14
# Entropy 0.465999256961
# is_leaf False
# selected_feature 5
# max_info_gain 0.441531550181
# best_split_mid_value 0.15222
# num_of_examples 17
# 0 level 4
# class_counts 0 3
# 1 12
# Entropy 0.500402423538
# is_leaf False
# selected_feature 18
# max_info_gain 0.464499576415
# best_split_mid_value 0.035835
# num_of_examples 15
# 0 level 5
# class_counts 0 2
# 1 11
# Entropy 0.429323021931
# is_leaf False
# selected_feature 24
# max_info_gain 0.384924941183
# best_split_mid_value 0.15565
# num_of_examples 13
# 0 level 6
# class_counts 0 2
# 1 8
# Entropy 0.500402423538
# is_leaf False
# selected_feature 4
# max_info_gain 0.41878871201
# best_split_mid_value 0.1064
# num_of_examples 10
# 0 level 7
# class_counts 0 2
# 1 5
# Entropy 0.598269588585
# is_leaf False
# selected_feature 8
# max_info_gain 0.555472354116
# best_split_mid_value 0.152
# num_of_examples 7
# 0 level 8
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 13.185
# num_of_examples 2
# 0 level 9
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 17
# max_info_gain 0.381908500977
# best_split_mid_value 0.01359
# num_of_examples 5
# 0 level 9
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 16
# max_info_gain 0.462098120373
# best_split_mid_value 0.03277
# num_of_examples 3
# 0 level 10
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 16.11
# num_of_examples 2
# 0 level 11
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 18.7025
# num_of_examples 2
# 0 level 6
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 4
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 1
# class_counts 0 8
# 1 36
# Entropy 0.474139313058
# is_leaf False
# selected_feature 14
# max_info_gain 0.449767466513
# best_split_mid_value 0.014172
# num_of_examples 44
# 0 level 2
# class_counts 0 8
# 1 31
# Entropy 0.50742996222
# is_leaf False
# selected_feature 18
# max_info_gain 0.472469074456
# best_split_mid_value 0.03062
# num_of_examples 39
# 0 level 3
# class_counts 0 7
# 1 18
# Entropy 0.592953317447
# is_leaf False
# selected_feature 21
# max_info_gain 0.548980026925
# best_split_mid_value 30.24
# num_of_examples 25
# 0 level 4
# class_counts 0 1
# 1 8
# Entropy 0.348832095843
# is_leaf False
# selected_feature 5
# max_info_gain 0.300374139244
# best_split_mid_value 0.05604
# num_of_examples 9
# 0 level 5
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts 0 1
# 1 5
# Entropy 0.450561208866
# is_leaf False
# selected_feature 0
# max_info_gain 0.374890096413
# best_split_mid_value 11.735
# num_of_examples 6
# 0 level 6
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 8
# max_info_gain 0.477385626221
# best_split_mid_value 0.17395
# num_of_examples 4
# 0 level 7
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 1
# max_info_gain 0.462098120373
# best_split_mid_value 17.85
# num_of_examples 3
# 0 level 8
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 2
# max_info_gain 0.0
# best_split_mid_value 81.08
# num_of_examples 2
# 0 level 9
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts 0 6
# 1 10
# Entropy 0.661563238158
# is_leaf False
# selected_feature 28
# max_info_gain 0.482346535083
# best_split_mid_value 0.28875
# num_of_examples 16
# 0 level 5
# class_counts 0 2
# 1 9
# Entropy 0.474139313058
# is_leaf False
# selected_feature 9
# max_info_gain 0.411434838519
# best_split_mid_value 0.06952
# num_of_examples 11
# 0 level 6
# class_counts 0 1
# 1 8
# Entropy 0.348832095843
# is_leaf False
# selected_feature 24
# max_info_gain 0.27800134641
# best_split_mid_value 0.1235
# num_of_examples 9
# 0 level 7
# class_counts 1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 0 1
# 1 4
# Entropy 0.500402423538
# is_leaf False
# selected_feature 1
# max_info_gain 0.381908500977
# best_split_mid_value 25.77
# num_of_examples 5
# 0 level 8
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.096805
# num_of_examples 3
# 0 level 9
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 9
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.5075
# num_of_examples 2
# 0 level 10
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 10
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts 1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 15.275
# num_of_examples 2
# 0 level 7
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 5
# class_counts 0 4
# 1 1
# Entropy 0.500402423538
# is_leaf False
# selected_feature 8
# max_info_gain 0.381908500977
# best_split_mid_value 0.18915
# num_of_examples 5
# 0 level 6
# class_counts 0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts 0 2
# 1 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature 1
# max_info_gain 0.462098120373
# best_split_mid_value 23.705
# num_of_examples 3
# 0 level 7
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 12.315
# num_of_examples 2
# 0 level 8
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 3
# class_counts 0 1
# 1 13
# Entropy 0.257318640544
# is_leaf False
# selected_feature 4
# max_info_gain 0.205058159144
# best_split_mid_value 0.092265
# num_of_examples 14
# 0 level 4
# class_counts 1 7
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts 0 1
# 1 6
# Entropy 0.410116318288
# is_leaf False
# selected_feature 9
# max_info_gain 0.321334368354
# best_split_mid_value 0.06914
# num_of_examples 7
# 0 level 5
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts 0 1
# 1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature 6
# max_info_gain 0.477385626221
# best_split_mid_value 0.30415
# num_of_examples 4
# 0 level 6
# class_counts 0 1
# 1 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature 5
# max_info_gain 0.462098120373
# best_split_mid_value 0.1876
# num_of_examples 3
# 0 level 7
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts 0 1
# 1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature 0
# max_info_gain 0.0
# best_split_mid_value 14.106
# num_of_examples 2
# 0 level 8
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts 0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts 1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 2
# class_counts 1 5
# Entropy 0.0
# is_leaf True
# predict_class 1

# %%
for i in range(len(X)):
    print("Example", i)
    pred = predict_single(X[i], tree_dict)

    print("\tActual Class:", Y[i])
    print("\tPredicted Class:", pred)
# Out:
# Example 0
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 1
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 2
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 3
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 4
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 5
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 6
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 7
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 8
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 9
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 10
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 11
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 12
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 13
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 14
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 15
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 16
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 17
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 18
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 19
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 20
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 21
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 22
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 23
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 24
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 25
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 26
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 27
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 28
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 29
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 30
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 31
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 32
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 33
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 34
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 35
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 36
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 37
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 38
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 39
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 40
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 41
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 42
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 43
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 44
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 45
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 46
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 47
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 48
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 49
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 50
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 51
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 52
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 53
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 54
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 55
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 56
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 57
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 58
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 59
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 60
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 61
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 62
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 63
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 64
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 65
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 66
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 67
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 68
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 69
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 70
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 71
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 72
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 73
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 74
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 75
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 76
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 77
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 78
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 79
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 80
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 81
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 82
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 83
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 84
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 85
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 86
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 87
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 88
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 89
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 90
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 91
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 92
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 93
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 94
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 95
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 96
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 97
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 98
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 99
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 100
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 101
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 102
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 103
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 104
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 105
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 106
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 107
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 108
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 109
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 110
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 111
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 112
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 113
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 114
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 115
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 116
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 117
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 118
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 119
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 120
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 121
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 122
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 123
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 124
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 125
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 126
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 127
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 128
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 129
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 130
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 131
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 132
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 133
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 134
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 135
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 136
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 137
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 138
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 139
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 140
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 141
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 142
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 143
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 144
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 145
# 	Actual Class: 1
# 	Predicted Class: 0
# Example 146
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 147
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 148
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 149
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 150
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 151
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 152
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 153
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 154
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 155
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 156
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 157
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 158
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 159
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 160
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 161
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 162
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 163
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 164
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 165
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 166
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 167
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 168
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 169
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 170
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 171
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 172
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 173
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 174
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 175
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 176
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 177
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 178
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 179
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 180
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 181
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 182
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 183
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 184
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 185
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 186
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 187
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 188
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 189
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 190
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 191
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 192
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 193
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 194
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 195
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 196
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 197
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 198
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 199
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 200
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 201
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 202
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 203
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 204
# 	Actual Class: 1
# 	Predicted Class: 0
# Example 205
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 206
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 207
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 208
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 209
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 210
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 211
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 212
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 213
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 214
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 215
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 216
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 217
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 218
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 219
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 220
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 221
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 222
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 223
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 224
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 225
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 226
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 227
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 228
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 229
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 230
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 231
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 232
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 233
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 234
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 235
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 236
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 237
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 238
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 239
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 240
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 241
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 242
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 243
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 244
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 245
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 246
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 247
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 248
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 249
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 250
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 251
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 252
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 253
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 254
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 255
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 256
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 257
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 258
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 259
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 260
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 261
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 262
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 263
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 264
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 265
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 266
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 267
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 268
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 269
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 270
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 271
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 272
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 273
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 274
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 275
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 276
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 277
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 278
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 279
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 280
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 281
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 282
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 283
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 284
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 285
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 286
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 287
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 288
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 289
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 290
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 291
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 292
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 293
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 294
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 295
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 296
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 297
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 298
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 299
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 300
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 301
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 302
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 303
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 304
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 305
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 306
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 307
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 308
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 309
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 310
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 311
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 312
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 313
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 314
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 315
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 316
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 317
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 318
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 319
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 320
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 321
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 322
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 323
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 324
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 325
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 326
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 327
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 328
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 329
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 330
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 331
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 332
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 333
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 334
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 335
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 336
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 337
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 338
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 339
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 340
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 341
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 342
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 343
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 344
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 345
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 346
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 347
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 348
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 349
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 350
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 351
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 352
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 353
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 354
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 355
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 356
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 357
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 358
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 359
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 360
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 361
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 362
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 363
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 364
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 365
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 366
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 367
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 368
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 369
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 370
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 371
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 372
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 373
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 374
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 375
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 376
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 377
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 378
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 379
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 380
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 381
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 382
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 383
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 384
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 385
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 386
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 387
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 388
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 389
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 390
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 391
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 392
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 393
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 394
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 395
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 396
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 397
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 398
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 399
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 400
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 401
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 402
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 403
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 404
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 405
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 406
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 407
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 408
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 409
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 410
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 411
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 412
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 413
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 414
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 415
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 416
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 417
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 418
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 419
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 420
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 421
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 422
# 	Actual Class: 1
# 	Predicted Class: 0
# Example 423
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 424
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 425
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 426
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 427
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 428
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 429
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 430
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 431
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 432
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 433
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 434
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 435
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 436
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 437
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 438
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 439
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 440
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 441
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 442
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 443
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 444
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 445
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 446
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 447
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 448
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 449
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 450
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 451
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 452
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 453
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 454
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 455
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 456
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 457
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 458
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 459
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 460
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 461
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 462
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 463
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 464
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 465
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 466
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 467
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 468
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 469
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 470
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 471
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 472
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 473
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 474
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 475
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 476
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 477
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 478
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 479
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 480
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 481
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 482
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 483
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 484
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 485
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 486
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 487
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 488
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 489
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 490
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 491
# 	Actual Class: 1
# 	Predicted Class: 0
# Example 492
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 493
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 494
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 495
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 496
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 497
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 498
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 499
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 500
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 501
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 502
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 503
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 504
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 505
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 506
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 507
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 508
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 509
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 510
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 511
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 512
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 513
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 514
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 515
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 516
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 517
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 518
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 519
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 520
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 521
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 522
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 523
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 524
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 525
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 526
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 527
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 528
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 529
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 530
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 531
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 532
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 533
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 534
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 535
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 536
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 537
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 538
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 539
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 540
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 541
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 542
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 543
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 544
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 545
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 546
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 547
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 548
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 549
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 550
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 551
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 552
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 553
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 554
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 555
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 556
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 557
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 558
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 559
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 560
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 561
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 562
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 563
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 564
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 565
# 	Actual Class: 0
# 	Predicted Class: 1
# Example 566
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 567
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 568
# 	Actual Class: 1
# 	Predicted Class: 1

# %%
import matplotlib.pyplot as plt

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.scatter(indices, Y_train_pred, color = "r")
plt.scatter(indices, Y_train, color = "b")
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.scatter(indices, Y_test_pred, color = "r")
plt.scatter(indices, Y_test, color = "b")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[151   0]
#  [  0 275]]
# Confusion Matrix for Y_test
#  [[46 15]
#  [ 4 78]]
