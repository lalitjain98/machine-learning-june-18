# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
"""
Load the Dataset

"""
dataset = datasets.load_breast_cancer()


X = dataset.data
Y = dataset.target

feature_names = dataset.feature_names

class_names = dataset.target_names

class_dict = {i : class_names[i] for i in range(len(class_names))}

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

print(class_dict)
# Out:
# {0: 'malignant', 1: 'benign'}

# %%
"""
Entropy function takes as input, list of labels Y and a list of all possible classes 
It returns the entropy of the current data subset.
"""

def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

"""
info_gain_for_split return inforamation gain of the current split of Y with list of integers splits
ith value of list splits means the ith Y value belongs to that split

lengths of Y and splits are equal

e.g. say Y = 1.2 4.5 3.2 2.3
    splits = 0 1 0 1 
    then 1.2 and 3.2 belong to same group, 4.5 and  2.3 belong to same group
"""

def info_gain_split_info_for_split(Y, splits):
    
    #initialize info_gain and split_info values
    info_gain = 0
    split_info = 0    
    
    # mod_Y is number of examples
    mod_Y = len(Y)
    
    # unique splits are number of groups in which data is divided
    unique_splits = list(set(splits))
    
    
    for s in unique_splits:
        
        # find indices of examples in group s
        indices = (splits == s)
        Y_split_i = Y[indices]
                
        #number of examples in current group s
        mod_Y_i = len(Y_split_i)
        
        """
                                           |Yi|
         ratio_mod_Y_i_to_mod_Y, ratio =   ----
                                           |Y|
        """
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        
        # list of all possible classes in group s
        possible_classes_Y_i = list(set(Y_split_i))
        
        # update info gain and split info values
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    
    return info_gain, split_info

"""
Considering input data to be continious, split method takes as input X - the data, Y - the labels, 
and feature index on which to split the data

1. find the set of unique values of feature f and sort it
2. build list of mid values ie mean of each pair of adjacent values
3. for each mid value
    3.1 split data into two parts
    3.2 find information gain
    3.3 keep the best split
returns min_info_gain: information gain for best split
        min_split_info : split info for best split
        best_split_labels : list of labels for each example
        mid_value_for_min_info_gain : the mid value for which best split on feature f was made
"""


def split(X, Y, feature):
    # find the set of unique values of feature f and sort it
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    pvcf.sort()
    
    
    # build list of mid values ie mean of each pair of adjacent values
    mid_values = []
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    
    # initialize variables
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = np.array([])
    
    # iterate over list of mid values
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        
        # splitting data into two parts, one group belongs to split 0 and other to split 1
        current_split_labels[ X[:, feature] <= value ] = 0
        
        # find information gain and split info for current split
        current_split_information_gain, current_split_split_info = info_gain_split_info_for_split(Y, current_split_labels)
        
        # keep the best split
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain

"""
decision_tree:
    Input:
        X : list of examples
        Y : list of labels
        features : list of indices of features; after each split, one element is removed from this list
        feature_names: list of feature names
        class_dict : dictionary of possible classes indices mapped to class names
        level : level in recursion tree (only used for printing steps)
    
    
    
    Output:
        dictionary of nodes where each node is a decision node used for prediction
"""
    
def decision_tree(X, Y, features, feature_names, class_dict, level):
    # current decision node dictionary
    node = {}
    
    #
    node["level"] = level
    
    # dictionary of classes mapped to respective counts in Y
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    
    # max_class is majority class, max_count is count of majority class
    max_count = -np.inf
    max_class = possible_classes[0]
    
    # add key value pairs of classes and their counts in class_counts dictionary
    # also find the majority class 
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[class_dict[y]] = count_y
        print("Count of", class_dict[y], "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    
    # find current entropy
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    # add the class_counts dictionary to node dictionary
    node['class_counts'] = class_counts
    
    # add entropy value to node dictionary
    node["Entropy"] = current_entropy
    
    """
    check for base case, ie either all the examples are marked with a single class
    or
    there is no more feature to split current data
    
    mark this decision node as leaf node
    add the value of predict class to this node
    
    return the node
    """
    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        node["predict_class"] = max_class
        return node
    
    """
    else
    this node is NOT a leaf node and splitting can be done
    
    """
    node["is_leaf"] = False
    
    """ initialize few variables
    
    selected_feature : index of selected feature to make split on
    
    max_info_gain : information gain on splitting using the selected_feature
    
    max_split_info : split info on splitting using the selected_feature
    
    best_split_labels : labels assigned to examples
    
    best_split_mid_value : mid value of selected feature to use for prediction
    
    """
    selected_feature = None
    max_info_gain = -np.inf
    max_split_info = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    
    # iterate over all available features
    for f in features:
        
        # find info gain
        # split info
        # current split labels for best split on curent feature 
        # mid value for current feature
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        # keep feature that gives maximum gain
        if info_gain > max_info_gain:
            selected_feature = f
            max_info_gain = info_gain
            max_split_info = split_info
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f

    """
    add index, name of selected feature 
    information gain
    mid value of selected feature
    number of examples at current decision
    to node dictionary
    """
    node["selected_feature"] = feature_names[selected_feature]
    node["selected_feature_index"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    node["num_of_examples"] = len(Y)
    
    print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio", max_info_gain/max_split_info)
    #splits = split(X, Y, selected_feature)
    
    # find list of groups in which current dataset is divided
    unique_splits = list(set(best_split_labels))
    
    # remove index of selected feature
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    """
    recursively call decision tree on 'split' datasets
    """
    for s in unique_splits:
        # find indices of examples that belong to split s
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        # store the output dictionaries of child splits in current node dictionary
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, class_dict, level + 1)
    """
    return the "decision tree" (dictionary)
    """
    return node

features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, class_dict, level = 0)
# Out:
# Level 0
# Count of malignant = 161
# Count of benign = 265
# Current Entropy is = 0.663043790756
# Splitting on feature 'smoothness error' with gain ratio 3.33976255934
#
# Level 1
# Count of malignant = 158
# Count of benign = 247
# Current Entropy is = 0.66880327855
# Splitting on feature 'texture error' with gain ratio 1.27422216735
#
# Level 2
# Count of malignant = 20
# Count of benign = 65
# Current Entropy is = 0.545594573969
# Splitting on feature 'mean smoothness' with gain ratio 1.83629727014
#
# Level 3
# Count of benign = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of malignant = 20
# Count of benign = 58
# Current Entropy is = 0.569268569218
# Splitting on feature 'fractal dimension error' with gain ratio 0.839326215171
#
# Level 4
# Count of malignant = 9
# Count of benign = 43
# Current Entropy is = 0.460731676834
# Splitting on feature 'concave points error' with gain ratio 1.39446414988
#
# Level 5
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 9
# Count of benign = 38
# Current Entropy is = 0.488375362016
# Splitting on feature 'mean symmetry' with gain ratio 0.645360650393
#
# Level 6
# Count of malignant = 2
# Count of benign = 22
# Current Entropy is = 0.286835983056
# Splitting on feature 'concavity error' with gain ratio 0.465245813615
#
# Level 7
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 2
# Count of benign = 16
# Current Entropy is = 0.348832095843
# Splitting on feature 'worst smoothness' with gain ratio 0.471904875345
#
# Level 8
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 2
# Count of benign = 10
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean compactness' with gain ratio 0.973552038096
#
# Level 9
# Count of malignant = 1
# Count of benign = 10
# Current Entropy is = 0.304636097349
# Splitting on feature 'radius error' with gain ratio 0.296260768787
#
# Level 10
# Count of benign = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst fractal dimension' with gain ratio 0.725982457879
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 7
# Count of benign = 16
# Current Entropy is = 0.614503320311
# Splitting on feature 'mean compactness' with gain ratio 0.824980787018
#
# Level 7
# Count of malignant = 1
# Count of benign = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 'concavity error' with gain ratio 0.404682526477
#
# Level 8
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'worst concave points' with gain ratio 0.567461932234
#
# Level 9
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 6
# Count of benign = 8
# Current Entropy is = 0.6829081047
# Splitting on feature 'concavity error' with gain ratio 1.44867718808
#
# Level 8
# Count of malignant = 6
# Count of benign = 6
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean fractal dimension' with gain ratio 1.24476551644
#
# Level 9
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 4
# Count of benign = 6
# Current Entropy is = 0.673011667009
# Splitting on feature 'radius error' with gain ratio 0.998164339358
#
# Level 10
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.725982457879
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 2
# Count of benign = 5
# Current Entropy is = 0.598269588585
# Splitting on feature 'compactness error' with gain ratio 1.33031422671
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 2
# Count of benign = 4
# Current Entropy is = 0.636514168295
# Splitting on feature 'perimeter error' with gain ratio 0.725982457879
#
# Level 12
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 2
# Count of benign = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 'area error' with gain ratio 0.848934360211
#
# Level 13
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 11
# Count of benign = 15
# Current Entropy is = 0.681265729663
# Splitting on feature 'compactness error' with gain ratio 1.49340121655
#
# Level 5
# Count of malignant = 8
# Count of benign = 14
# Current Entropy is = 0.655481773901
# Splitting on feature 'worst smoothness' with gain ratio 1.47578678746
#
# Level 6
# Count of malignant = 8
# Count of benign = 11
# Current Entropy is = 0.680629487892
# Splitting on feature 'symmetry error' with gain ratio 0.907672499883
#
# Level 7
# Count of malignant = 5
# Count of benign = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'mean symmetry' with gain ratio 1.38940379001
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 5
# Count of benign = 2
# Current Entropy is = 0.598269588585
# Splitting on feature 'concavity error' with gain ratio 0.803521737465
#
# Level 9
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 3
# Count of benign = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'mean fractal dimension' with gain ratio 0.899012663676
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean texture' with gain ratio 0.5
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 3
# Count of benign = 8
# Current Entropy is = 0.585952618304
# Splitting on feature 'mean symmetry' with gain ratio 0.821119123713
#
# Level 8
# Count of malignant = 3
# Count of benign = 5
# Current Entropy is = 0.661563238158
# Splitting on feature 'mean texture' with gain ratio 1.38940379001
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 2
# Count of benign = 5
# Current Entropy is = 0.598269588585
# Splitting on feature 'worst compactness' with gain ratio 0.803521737465
#
# Level 10
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'worst symmetry' with gain ratio 0.899012663676
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst fractal dimension' with gain ratio 0.5
#
# Level 12
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 13
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst compactness' with gain ratio 0.5
#
# Level 6
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 7
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of malignant = 138
# Count of benign = 182
# Current Entropy is = 0.683664040795
# Splitting on feature 'symmetry error' with gain ratio 6.31778854502
#
# Level 3
# Count of malignant = 131
# Count of benign = 182
# Current Entropy is = 0.679813202082
# Splitting on feature 'mean fractal dimension' with gain ratio 2.88893135333
#
# Level 4
# Count of malignant = 15
# Count of benign = 4
# Current Entropy is = 0.514653165429
# Splitting on feature 'worst compactness' with gain ratio 0.610853741785
#
# Level 5
# Count of malignant = 8
# Count of benign = 4
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst fractal dimension' with gain ratio 0.689105093899
#
# Level 6
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean compactness' with gain ratio 0.5
#
# Level 7
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 7
# Count of benign = 1
# Current Entropy is = 0.376770161256
# Splitting on feature 'worst concavity' with gain ratio 0.40563906223
#
# Level 7
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'compactness error' with gain ratio 0.5
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 116
# Count of benign = 178
# Current Entropy is = 0.670743256725
# Splitting on feature 'fractal dimension error' with gain ratio 0.896744808259
#
# Level 5
# Count of malignant = 30
# Count of benign = 104
# Current Entropy is = 0.531775807708
# Splitting on feature 'mean symmetry' with gain ratio 1.25420767995
#
# Level 6
# Count of benign = 18
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 30
# Count of benign = 86
# Current Entropy is = 0.571609252075
# Splitting on feature 'worst symmetry' with gain ratio 2.61122199785
#
# Level 7
# Count of malignant = 25
# Count of benign = 85
# Current Entropy is = 0.535959889216
# Splitting on feature 'worst fractal dimension' with gain ratio 0.809065634835
#
# Level 8
# Count of malignant = 11
# Count of benign = 67
# Current Entropy is = 0.406820961305
# Splitting on feature 'worst smoothness' with gain ratio 0.678391002684
#
# Level 9
# Count of benign = 18
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 11
# Count of benign = 49
# Current Entropy is = 0.476410518752
# Splitting on feature 'mean smoothness' with gain ratio 0.643558539427
#
# Level 10
# Count of malignant = 1
# Count of benign = 22
# Current Entropy is = 0.178844912717
# Splitting on feature 'mean compactness' with gain ratio 0.210481315194
#
# Level 11
# Count of malignant = 1
# Count of benign = 10
# Current Entropy is = 0.304636097349
# Splitting on feature 'perimeter error' with gain ratio 0.356687030678
#
# Level 12
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Count of benign = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean texture' with gain ratio 0.459147917027
#
# Level 13
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'area error' with gain ratio 0.725982457879
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of benign = 12
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 10
# Count of benign = 27
# Current Entropy is = 0.583527471778
# Splitting on feature 'compactness error' with gain ratio 1.66034483953
#
# Level 11
# Count of malignant = 7
# Count of benign = 27
# Current Entropy is = 0.508449747395
# Splitting on feature 'mean compactness' with gain ratio 0.672828420477
#
# Level 12
# Count of malignant = 2
# Count of benign = 20
# Current Entropy is = 0.304636097349
# Splitting on feature 'concavity error' with gain ratio 0.664995251716
#
# Level 13
# Count of malignant = 1
# Count of benign = 18
# Current Entropy is = 0.206192050633
# Splitting on feature 'mean radius' with gain ratio 0.24733423596
#
# Level 14
# Count of benign = 9
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 9
# Current Entropy is = 0.325082973391
# Splitting on feature 'mean texture' with gain ratio 0.360964047444
#
# Level 15
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean concavity' with gain ratio 0.411967408316
#
# Level 16
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean perimeter' with gain ratio 0.0
#
# Level 17
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean concavity' with gain ratio 0.725982457879
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 5
# Count of benign = 7
# Current Entropy is = 0.679193265992
# Splitting on feature 'worst compactness' with gain ratio 0.692902343326
#
# Level 13
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 5
# Count of benign = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'mean perimeter' with gain ratio 0.635815697758
#
# Level 14
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'mean radius' with gain ratio 0.567461932234
#
# Level 15
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst radius' with gain ratio 0.725982457879
#
# Level 16
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 14
# Count of benign = 18
# Current Entropy is = 0.685314207276
# Splitting on feature 'mean smoothness' with gain ratio 1.08292315779
#
# Level 9
# Count of malignant = 8
# Count of benign = 15
# Current Entropy is = 0.646090505061
# Splitting on feature 'compactness error' with gain ratio 1.84892919128
#
# Level 10
# Count of malignant = 6
# Count of benign = 15
# Current Entropy is = 0.598269588585
# Splitting on feature 'worst compactness' with gain ratio 0.918330670371
#
# Level 11
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 6
# Count of benign = 10
# Current Entropy is = 0.661563238158
# Splitting on feature 'concavity error' with gain ratio 1.58596580372
#
# Level 12
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 6
# Count of benign = 8
# Current Entropy is = 0.6829081047
# Splitting on feature 'worst smoothness' with gain ratio 0.836325990425
#
# Level 13
# Count of malignant = 1
# Count of benign = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean concavity' with gain ratio 0.459147917027
#
# Level 14
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean compactness' with gain ratio 0.725982457879
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 16
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 5
# Count of benign = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'mean compactness' with gain ratio 0.924467180105
#
# Level 14
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 3
# Count of benign = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.588973686818
#
# Level 15
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst texture' with gain ratio 0.5
#
# Level 16
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 6
# Count of benign = 3
# Current Entropy is = 0.636514168295
# Splitting on feature 'concave points error' with gain ratio 0.725982457879
#
# Level 10
# Count of malignant = 3
# Count of benign = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.588973686818
#
# Level 11
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean perimeter' with gain ratio 0.5
#
# Level 12
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 13
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 5
# Count of benign = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'compactness error' with gain ratio 0.459147917027
#
# Level 8
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'concavity error' with gain ratio 0.725982457879
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 86
# Count of benign = 74
# Current Entropy is = 0.690332037891
# Splitting on feature 'worst fractal dimension' with gain ratio 1.01011885359
#
# Level 6
# Count of malignant = 46
# Count of benign = 61
# Current Entropy is = 0.683288554527
# Splitting on feature 'compactness error' with gain ratio 1.64569996517
#
# Level 7
# Count of benign = 13
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 46
# Count of benign = 48
# Current Entropy is = 0.692920816716
# Splitting on feature 'concavity error' with gain ratio 2.72955725742
#
# Level 8
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 46
# Count of benign = 42
# Current Entropy is = 0.692113766678
# Splitting on feature 'worst symmetry' with gain ratio 1.72787322954
#
# Level 9
# Count of malignant = 36
# Count of benign = 42
# Current Entropy is = 0.690185676019
# Splitting on feature 'mean texture' with gain ratio 0.892227009498
#
# Level 10
# Count of malignant = 7
# Count of benign = 25
# Current Entropy is = 0.525321319516
# Splitting on feature 'concave points error' with gain ratio 0.739692979001
#
# Level 11
# Count of malignant = 1
# Count of benign = 11
# Current Entropy is = 0.286835983056
# Splitting on feature 'worst compactness' with gain ratio 0.325011210824
#
# Level 12
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Count of benign = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'worst texture' with gain ratio 0.459147917027
#
# Level 13
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst smoothness' with gain ratio 0.725982457879
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 6
# Count of benign = 14
# Current Entropy is = 0.610864302055
# Splitting on feature 'worst texture' with gain ratio 2.75806236408
#
# Level 12
# Count of malignant = 5
# Count of benign = 14
# Current Entropy is = 0.576334127757
# Splitting on feature 'mean compactness' with gain ratio 0.976407451176
#
# Level 13
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 5
# Count of benign = 10
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean symmetry' with gain ratio 1.47053441197
#
# Level 14
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 5
# Count of benign = 8
# Current Entropy is = 0.666278442415
# Splitting on feature 'worst smoothness' with gain ratio 1.35797007705
#
# Level 15
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 5
# Count of benign = 6
# Current Entropy is = 0.689009238477
# Splitting on feature 'mean smoothness' with gain ratio 0.821119123713
#
# Level 16
# Count of malignant = 5
# Count of benign = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'perimeter error' with gain ratio 0.924467180105
#
# Level 17
# Count of malignant = 3
# Count of benign = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'worst concavity' with gain ratio 1.24476551644
#
# Level 18
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of malignant = 3
# Count of benign = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'mean concavity' with gain ratio 0.899012663676
#
# Level 19
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'radius error' with gain ratio 0.5
#
# Level 20
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 21
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 21
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 20
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 29
# Count of benign = 17
# Current Entropy is = 0.65872387652
# Splitting on feature 'worst texture' with gain ratio 2.44662494381
#
# Level 11
# Count of malignant = 29
# Count of benign = 14
# Current Entropy is = 0.631005192805
# Splitting on feature 'mean symmetry' with gain ratio 1.1484899366
#
# Level 12
# Count of malignant = 1
# Count of benign = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 'concave points error' with gain ratio 0.399456068151
#
# Level 13
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 14
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 28
# Count of benign = 8
# Current Entropy is = 0.529706199058
# Splitting on feature 'mean smoothness' with gain ratio 1.17614041171
#
# Level 13
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'concave points error' with gain ratio 0.899012663676
#
# Level 14
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 26
# Count of benign = 5
# Current Entropy is = 0.44180334801
# Splitting on feature 'worst smoothness' with gain ratio 0.462818807972
#
# Level 14
# Count of malignant = 11
# Count of benign = 5
# Current Entropy is = 0.621086374555
# Splitting on feature 'mean compactness' with gain ratio 0.563852146553
#
# Level 15
# Count of malignant = 4
# Count of benign = 5
# Current Entropy is = 0.686961576597
# Splitting on feature 'worst compactness' with gain ratio 0.768497242548
#
# Level 16
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'radius error' with gain ratio 0.411967408316
#
# Level 17
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 18
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'concave points error' with gain ratio 0.5
#
# Level 17
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 18
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 15
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 10
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 40
# Count of benign = 13
# Current Entropy is = 0.557093426542
# Splitting on feature 'perimeter error' with gain ratio 0.715936250887
#
# Level 7
# Count of malignant = 18
# Count of benign = 11
# Current Entropy is = 0.663725497472
# Splitting on feature 'radius error' with gain ratio 0.946582529342
#
# Level 8
# Count of malignant = 10
# Count of benign = 10
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.968133108272
#
# Level 9
# Count of malignant = 1
# Count of benign = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'worst concavity' with gain ratio 0.459147917027
#
# Level 10
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean concavity' with gain ratio 0.725982457879
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 9
# Count of benign = 5
# Current Entropy is = 0.651756561173
# Splitting on feature 'area error' with gain ratio 2.22740595349
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 9
# Count of benign = 4
# Current Entropy is = 0.61724176973
# Splitting on feature 'concave points error' with gain ratio 1.91408162204
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 9
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst concavity' with gain ratio 0.848934360211
#
# Level 12
# Count of malignant = 6
# Count of benign = 3
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst compactness' with gain ratio 0.805238208678
#
# Level 13
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean compactness' with gain ratio 0.725982457879
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 5
# Count of benign = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean radius' with gain ratio 0.362991228939
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean perimeter' with gain ratio 0.0
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 8
# Count of benign = 1
# Current Entropy is = 0.348832095843
# Splitting on feature 'concavity error' with gain ratio 0.404682526477
#
# Level 9
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 4
# Count of benign = 1
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean compactness' with gain ratio 0.411967408316
#
# Level 10
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 22
# Count of benign = 2
# Current Entropy is = 0.286835983056
# Splitting on feature 'mean compactness' with gain ratio 0.370972157855
#
# Level 8
# Count of malignant = 13
# Count of benign = 2
# Current Entropy is = 0.392674467228
# Splitting on feature 'mean concavity' with gain ratio 0.524107132738
#
# Level 9
# Count of malignant = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 8
# Count of benign = 2
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean symmetry' with gain ratio 0.567461932234
#
# Level 10
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 4
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst concavity' with gain ratio 0.459147917027
#
# Level 11
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 9
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of malignant = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of malignant = 3
# Count of benign = 18
# Current Entropy is = 0.410116318288
# Splitting on feature 'symmetry error' with gain ratio 0.597440199781
#
# Level 2
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of malignant = 3
# Count of benign = 12
# Current Entropy is = 0.500402423538
# Splitting on feature 'worst fractal dimension' with gain ratio 0.740968003484
#
# Level 3
# Count of malignant = 3
# Count of benign = 8
# Current Entropy is = 0.585952618304
# Splitting on feature 'mean symmetry' with gain ratio 1.49329412399
#
# Level 4
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 2
# Count of benign = 8
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean fractal dimension' with gain ratio 0.485475297227
#
# Level 5
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'texture error' with gain ratio 0.899012663676
#
# Level 6
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'compactness error' with gain ratio 0.5
#
# Level 7
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature_index"]
    feature_value = tree_dict["best_split_mid_value"]

    if X[index] <= feature_value :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    else :
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])


def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key])
        else:
            print(key, dictionary[key])


#print_dict(tree_dict)

# %%
for i in range(len(X)):
    print("Example", i)
    pred = predict_single(X[i], tree_dict)

    print("\tActual Class:", class_dict[Y[i]])
    print("\tPredicted Class:", class_dict[pred])
# Out:
# Example 0
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 1
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 2
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 3
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 4
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 5
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 6
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 7
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 8
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 9
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 10
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 11
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 12
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 13
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 14
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 15
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 16
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 17
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 18
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 19
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 20
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 21
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 22
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 23
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 24
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 25
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 26
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 27
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 28
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 29
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 30
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 31
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 32
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 33
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 34
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 35
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 36
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 37
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 38
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 39
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 40
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 41
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 42
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 43
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 44
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 45
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 46
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 47
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 48
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 49
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 50
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 51
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 52
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 53
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 54
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 55
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 56
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 57
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 58
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 59
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 60
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 61
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 62
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 63
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 64
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 65
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 66
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 67
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 68
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 69
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 70
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 71
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 72
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 73
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 74
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 75
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 76
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 77
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 78
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 79
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 80
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 81
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 82
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 83
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 84
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 85
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 86
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 87
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 88
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 89
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 90
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 91
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 92
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 93
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 94
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 95
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 96
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 97
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 98
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 99
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 100
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 101
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 102
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 103
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 104
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 105
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 106
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 107
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 108
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 109
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 110
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 111
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 112
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 113
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 114
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 115
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 116
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 117
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 118
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 119
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 120
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 121
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 122
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 123
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 124
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 125
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 126
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 127
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 128
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 129
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 130
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 131
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 132
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 133
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 134
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 135
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 136
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 137
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 138
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 139
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 140
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 141
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 142
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 143
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 144
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 145
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 146
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 147
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 148
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 149
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 150
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 151
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 152
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 153
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 154
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 155
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 156
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 157
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 158
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 159
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 160
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 161
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 162
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 163
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 164
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 165
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 166
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 167
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 168
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 169
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 170
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 171
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 172
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 173
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 174
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 175
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 176
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 177
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 178
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 179
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 180
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 181
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 182
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 183
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 184
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 185
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 186
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 187
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 188
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 189
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 190
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 191
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 192
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 193
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 194
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 195
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 196
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 197
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 198
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 199
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 200
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 201
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 202
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 203
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 204
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 205
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 206
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 207
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 208
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 209
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 210
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 211
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 212
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 213
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 214
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 215
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 216
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 217
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 218
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 219
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 220
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 221
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 222
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 223
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 224
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 225
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 226
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 227
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 228
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 229
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 230
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 231
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 232
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 233
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 234
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 235
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 236
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 237
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 238
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 239
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 240
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 241
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 242
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 243
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 244
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 245
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 246
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 247
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 248
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 249
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 250
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 251
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 252
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 253
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 254
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 255
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 256
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 257
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 258
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 259
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 260
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 261
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 262
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 263
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 264
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 265
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 266
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 267
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 268
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 269
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 270
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 271
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 272
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 273
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 274
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 275
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 276
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 277
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 278
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 279
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 280
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 281
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 282
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 283
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 284
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 285
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 286
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 287
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 288
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 289
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 290
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 291
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 292
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 293
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 294
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 295
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 296
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 297
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 298
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 299
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 300
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 301
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 302
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 303
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 304
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 305
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 306
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 307
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 308
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 309
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 310
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 311
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 312
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 313
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 314
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 315
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 316
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 317
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 318
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 319
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 320
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 321
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 322
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 323
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 324
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 325
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 326
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 327
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 328
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 329
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 330
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 331
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 332
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 333
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 334
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 335
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 336
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 337
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 338
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 339
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 340
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 341
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 342
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 343
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 344
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 345
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 346
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 347
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 348
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 349
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 350
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 351
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 352
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 353
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 354
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 355
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 356
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 357
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 358
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 359
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 360
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 361
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 362
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 363
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 364
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 365
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 366
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 367
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 368
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 369
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 370
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 371
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 372
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 373
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 374
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 375
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 376
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 377
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 378
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 379
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 380
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 381
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 382
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 383
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 384
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 385
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 386
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 387
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 388
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 389
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 390
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 391
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 392
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 393
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 394
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 395
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 396
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 397
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 398
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 399
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 400
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 401
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 402
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 403
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 404
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 405
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 406
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 407
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 408
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 409
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 410
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 411
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 412
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 413
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 414
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 415
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 416
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 417
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 418
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 419
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 420
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 421
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 422
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 423
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 424
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 425
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 426
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 427
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 428
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 429
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 430
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 431
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 432
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 433
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 434
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 435
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 436
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 437
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 438
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 439
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 440
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 441
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 442
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 443
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 444
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 445
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 446
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 447
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 448
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 449
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 450
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 451
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 452
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 453
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 454
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 455
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 456
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 457
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 458
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 459
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 460
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 461
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 462
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 463
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 464
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 465
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 466
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 467
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 468
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 469
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 470
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 471
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 472
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 473
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 474
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 475
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 476
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 477
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 478
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 479
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 480
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 481
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 482
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 483
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 484
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 485
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 486
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 487
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 488
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 489
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 490
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 491
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 492
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 493
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 494
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 495
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 496
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 497
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 498
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 499
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 500
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 501
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 502
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 503
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 504
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 505
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 506
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 507
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 508
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 509
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 510
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 511
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 512
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 513
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 514
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 515
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 516
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 517
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 518
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 519
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 520
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 521
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 522
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 523
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 524
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 525
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 526
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 527
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 528
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 529
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 530
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 531
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 532
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 533
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 534
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 535
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 536
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 537
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 538
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 539
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 540
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 541
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 542
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 543
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 544
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 545
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 546
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 547
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 548
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 549
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 550
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 551
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 552
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 553
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 554
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 555
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 556
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 557
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 558
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 559
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 560
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 561
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 562
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 563
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 564
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 565
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 566
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 567
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 568
# 	Actual Class: benign
# 	Predicted Class: benign

# %%
import matplotlib.pyplot as plt

def get_lines(indices, Y_pred, Y):
    lines = []
    for i in indices :
        if Y_pred[i] != Y[i] :
            line = [[i, i], [Y_pred[i], Y[i]]]
            lines.append(line)
    return lines

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_train), -1, len(class_dict)))
plt.scatter(indices, Y_train_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_train, c = Y_train)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_train_pred, Y_train)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
    
plt.legend()
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_test), -1, len(class_dict)))
plt.scatter(indices, Y_test_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_test, c = Y_test)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_test_pred, Y_test)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[161   0]
#  [  0 265]]
# Confusion Matrix for Y_test
#  [[37 14]
#  [18 74]]
