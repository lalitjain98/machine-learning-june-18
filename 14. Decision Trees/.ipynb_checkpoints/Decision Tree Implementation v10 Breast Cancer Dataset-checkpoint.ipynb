# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
"""
Load the Dataset

"""
dataset = datasets.load_wine()


X = dataset.data
Y = dataset.target

feature_names = dataset.feature_names


class_names = dataset.target_names

class_dict = {i : class_names[i] for i in range(len(class_names))}

print(dataset.DESCR)
# Out:
# Wine Data Database
# ====================
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- 1) Alcohol
#  		- 2) Malic acid
#  		- 3) Ash
# 		- 4) Alcalinity of ash
#  		- 5) Magnesium
# 		- 6) Total phenols
#  		- 7) Flavanoids
#  		- 8) Nonflavanoid phenols
#  		- 9) Proanthocyanins
# 		- 10)Color intensity
#  		- 11)Hue
#  		- 12)OD280/OD315 of diluted wines
#  		- 13)Proline
#         	- class:
#                 - class_0
#                 - class_1
#                 - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
#     Alcalinity of Ash:            10.6  30.0    19.5   3.3
#     Magnesium:                    70.0 162.0    99.7  14.3
#     Total Phenols:                0.98  3.88    2.29  0.63
#     Flavanoids:                   0.34  5.08    2.03  1.00
#     Nonflavanoid Phenols:         0.13  0.66    0.36  0.12
#     Proanthocyanins:              0.41  3.58    1.59  0.57
#     Colour Intensity:              1.3  13.0     5.1   2.3
#     Hue:                          0.48  1.71    0.96  0.23
#     OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71
#     Proline:                       278  1680     746   315
#     ============================= ==== ===== ======= =====
#
#     :Missing Attribute Values: None
#     :Class Distribution: class_0 (59), class_1 (71), class_2 (48)
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# This is a copy of UCI ML Wine recognition datasets.
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same
# region in Italy by three different cultivators. There are thirteen different
# measurements taken for different constituents found in the three types of
# wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS -
# An Extendible Package for Data Exploration, Classification and Correlation.
# Institute of Pharmaceutical and Food Analysis and Technologies,
# Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository
# [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California,
# School of Information and Computer Science.
#
# References
# ----------
# (1)
# S. Aeberhard, D. Coomans and O. de Vel,
# Comparison of Classifiers in High Dimensional Settings,
# Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of
# Mathematics and Statistics, James Cook University of North Queensland.
# (Also submitted to Technometrics).
#
# The data was used with many others for comparing various
# classifiers. The classes are separable, though only RDA
# has achieved 100% correct classification.
# (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
# (All results using the leave-one-out technique)
#
# (2)
# S. Aeberhard, D. Coomans and O. de Vel,
# "THE CLASSIFICATION PERFORMANCE OF RDA"
# Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of
# Mathematics and Statistics, James Cook University of North Queensland.
# (Also submitted to Journal of Chemometrics).

# %%
"""
Split Dataset into Training and Testing sets
"""
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 1)


print("Class Dictionary", class_dict)
# Out:
# Class Dictionary {0: 'class_0', 1: 'class_1', 2: 'class_2'}

# %%
import pandas as pd
df = pd.DataFrame(X)
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean    13.000618    2.336348    2.366517   19.494944   99.741573    2.295112
# std      0.811827    1.117146    0.274344    3.339564   14.282484    0.625851
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.362500    1.602500    2.210000   17.200000   88.000000    1.742500
# 50%     13.050000    1.865000    2.360000   19.500000   98.000000    2.355000
# 75%     13.677500    3.082500    2.557500   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#                6           7           8           9           10          11  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     2.029270    0.361854    1.590899    5.058090    0.957449    2.611685
# std      0.998859    0.124453    0.572359    2.318286    0.228572    0.709990
# min      0.340000    0.130000    0.410000    1.280000    0.480000    1.270000
# 25%      1.205000    0.270000    1.250000    3.220000    0.782500    1.937500
# 50%      2.135000    0.340000    1.555000    4.690000    0.965000    2.780000
# 75%      2.875000    0.437500    1.950000    6.200000    1.120000    3.170000
# max      5.080000    0.660000    3.580000   13.000000    1.710000    4.000000
#
#                 12
# count   178.000000
# mean    746.893258
# std     314.907474
# min     278.000000
# 25%     500.500000
# 50%     673.500000
# 75%     985.000000
# max    1680.000000

# %%
"""
Entropy function takes as input, list of labels Y and a list of all possible classes 
It returns the entropy of the current data subset.
"""

def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

"""
info_gain_for_split return inforamation gain of the current split of Y with list of integers splits
ith value of list splits means the ith Y value belongs to that split

lengths of Y and splits are equal

e.g. say Y = 1.2 4.5 3.2 2.3
    splits = 0 1 0 1 
    then 1.2 and 3.2 belong to same group, 4.5 and  2.3 belong to same group
"""

def info_gain_split_info_for_split(Y, splits):
    
    #initialize info_gain and split_info values
    info_gain = 0
    split_info = 0    
    
    # mod_Y is number of examples
    mod_Y = len(Y)
    
    # unique splits are number of groups in which data is divided
    unique_splits = list(set(splits))
    
    
    for s in unique_splits:
        
        # find indices of examples in group s
        indices = (splits == s)
        Y_split_i = Y[indices]
                
        #number of examples in current group s
        mod_Y_i = len(Y_split_i)
        
        """
                                           |Yi|
         ratio_mod_Y_i_to_mod_Y, ratio =   ----
                                           |Y|
        """
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        
        # list of all possible classes in group s
        possible_classes_Y_i = list(set(Y_split_i))
        
        # update info gain and split info values
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    
    return info_gain, split_info

"""
Considering input data to be continious, split method takes as input X - the data, Y - the labels, 
and feature index on which to split the data

1. find the set of unique values of feature f and sort it
2. build list of mid values ie mean of each pair of adjacent values
3. for each mid value
    3.1 split data into two parts
    3.2 find information gain
    3.3 keep the best split
returns min_info_gain: information gain for best split
        min_split_info : split info for best split
        best_split_labels : list of labels for each example
        mid_value_for_min_info_gain : the mid value for which best split on feature f was made
"""


def split(X, Y, feature):
    # find the set of unique values of feature f and sort it
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    pvcf.sort()
    
    
    # build list of mid values ie mean of each pair of adjacent values
    mid_values = []
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    
    # initialize variables
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = np.array([])
    
    # iterate over list of mid values
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        
        # splitting data into two parts, one group belongs to split 0 and other to split 1
        current_split_labels[ X[:, feature] <= value ] = 0
        
        # find information gain and split info for current split
        current_split_information_gain, current_split_split_info = info_gain_split_info_for_split(Y, current_split_labels)
        
        # keep the best split
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain

"""
decision_tree:
    Input:
        X : list of examples
        Y : list of labels
        features : list of indices of features; after each split, one element is removed from this list
        feature_names: list of feature names
        class_dict : dictionary of possible classes indices mapped to class names
        level : level in recursion tree (only used for printing steps)
    
    
    
    Output:
        dictionary of nodes where each node is a decision node used for prediction
"""
    
def decision_tree(X, Y, features, feature_names, class_dict, level):
    # current decision node dictionary
    node = {}
    
    #
    node["level"] = level
    
    # dictionary of classes mapped to respective counts in Y
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    
    # max_class is majority class, max_count is count of majority class
    max_count = -np.inf
    max_class = possible_classes[0]
    
    # add key value pairs of classes and their counts in class_counts dictionary
    # also find the majority class 
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[class_dict[y]] = count_y
        print("Count of", class_dict[y], "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    
    # find current entropy
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    # add the class_counts dictionary to node dictionary
    node['class_counts'] = class_counts
    
    # add entropy value to node dictionary
    node["Entropy"] = current_entropy
    
    """
    check for base case, ie either all the examples are marked with a single class
    or
    there is no more feature to split current data
    
    mark this decision node as leaf node
    add the value of predict class to this node
    
    return the node
    """
    
    node["predict_class"] = max_class
    node["num_of_examples"] = len(Y)

    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        return node
    
    """
    else
    this node is NOT a leaf node and splitting can be done
    
    """
    node["is_leaf"] = False
    
    """ initialize few variables
    
    selected_feature : index of selected feature to make split on
    
    max_info_gain : information gain on splitting using the selected_feature
    
    max_split_info : split info on splitting using the selected_feature
    
    best_split_labels : labels assigned to examples
    
    best_split_mid_value : mid value of selected feature to use for prediction
    
    """
    selected_feature = None
    max_info_gain = -np.inf
    max_split_info = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    
    # iterate over all available features
    for f in features:
        
        # find info gain
        # split info
        # current split labels for best split on curent feature 
        # mid value for current feature
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        # keep feature that gives maximum gain
        if info_gain > max_info_gain and info_gain < np.inf:
            selected_feature = f
            max_info_gain = info_gain
            max_split_info = split_info
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f

    """
    add index, name of selected feature 
    information gain
    mid value of selected feature
    number of examples at current decision
    to node dictionary
    """
    node["selected_feature"] = feature_names[selected_feature]
    node["selected_feature_index"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    
    if max_split_info != 0 :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio", max_info_gain/max_split_info)
    else :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio inf")
    #splits = split(X, Y, selected_feature)
    
    # find list of groups in which current dataset is divided
    unique_splits = list(set(best_split_labels))
    
    # remove index of selected feature
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    """
    recursively call decision tree on 'split' datasets
    """
    for s in unique_splits:
        # find indices of examples that belong to split s
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        # store the output dictionaries of child splits in current node dictionary
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, class_dict, level + 1)
    """
    return the "decision tree" (dictionary)
    """
    return node

features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, class_dict, level = 0)
# Out:
# Level 0
# Count of class_0 = 41
# Count of class_1 = 54
# Count of class_2 = 38
# Current Entropy is = 1.0866659153
# Splitting on feature 'ash' with gain ratio 2.6280606001
#
# Level 1
# Count of class_1 = 16
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of class_0 = 41
# Count of class_1 = 38
# Count of class_2 = 38
# Current Entropy is = 1.09796023502
# Splitting on feature 'nonflavanoid_phenols' with gain ratio 1.32977401334
#
# Level 2
# Count of class_0 = 35
# Count of class_1 = 14
# Count of class_2 = 7
# Current Entropy is = 0.900256051269
# Splitting on feature 'malic_acid' with gain ratio 1.14914146104
#
# Level 3
# Count of class_0 = 29
# Count of class_1 = 9
# Current Entropy is = 0.547412468525
# Splitting on feature 'proanthocyanins' with gain ratio 4.1772385344
#
# Level 4
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 29
# Count of class_1 = 8
# Current Entropy is = 0.522077063913
# Splitting on feature 'hue' with gain ratio 0.860609237763
#
# Level 5
# Count of class_0 = 24
# Count of class_1 = 4
# Current Entropy is = 0.410116318288
# Splitting on feature 'magnesium' with gain ratio 2.1831666215
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 24
# Count of class_1 = 3
# Current Entropy is = 0.348832095843
# Splitting on feature 'total_phenols' with gain ratio 1.64853470303
#
# Level 7
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 24
# Count of class_1 = 2
# Current Entropy is = 0.271189373042
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.332532449525
#
# Level 8
# Count of class_0 = 11
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 13
# Count of class_1 = 2
# Current Entropy is = 0.392674467228
# Splitting on feature 'flavanoids' with gain ratio 0.980541535273
#
# Level 9
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_0 = 13
# Count of class_1 = 1
# Current Entropy is = 0.257318640544
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.241446198014
#
# Level 10
# Count of class_0 = 12
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 11
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 5
# Count of class_1 = 4
# Current Entropy is = 0.686961576597
# Splitting on feature 'total_phenols' with gain ratio 1.68578585143
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 5
# Count of class_1 = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 1.38940379001
#
# Level 7
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 5
# Count of class_1 = 2
# Current Entropy is = 0.598269588585
# Splitting on feature 'flavanoids' with gain ratio 0.579996196342
#
# Level 8
# Count of class_0 = 2
# Count of class_1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.848934360211
#
# Level 9
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_0 = 2
# Count of class_1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.0
#
# Level 10
# Count of class_0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_0 = 6
# Count of class_1 = 5
# Count of class_2 = 7
# Current Entropy is = 1.08930967896
# Splitting on feature 'alcohol' with gain ratio 1.3488503746
#
# Level 4
# Count of class_1 = 4
# Count of class_2 = 1
# Current Entropy is = 0.500402423538
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.411967408316
#
# Level 5
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'magnesium' with gain ratio 0.0
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 6
# Count of class_1 = 1
# Count of class_2 = 6
# Current Entropy is = 0.911017539713
# Splitting on feature 'magnesium' with gain ratio 0.922555393651
#
# Level 5
# Count of class_0 = 5
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.796311640174
# Splitting on feature 'total_phenols' with gain ratio 0.941672653985
#
# Level 6
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 5
# Count of class_1 = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'flavanoids' with gain ratio 0.459147917027
#
# Level 7
# Count of class_0 = 2
# Count of class_1 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.725982457879
#
# Level 8
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.0
#
# Level 9
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 1
# Count of class_2 = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'proanthocyanins' with gain ratio 0.362991228939
#
# Level 6
# Count of class_2 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.0
#
# Level 7
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of class_0 = 6
# Count of class_1 = 24
# Count of class_2 = 31
# Current Entropy is = 0.93911235462
# Splitting on feature 'alcalinity_of_ash' with gain ratio 3.60498872873
#
# Level 3
# Count of class_0 = 2
# Count of class_1 = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 'magnesium' with gain ratio 0.848934360211
#
# Level 4
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 1
# Count of class_1 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'total_phenols' with gain ratio 0.725982457879
#
# Level 5
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_0 = 4
# Count of class_1 = 22
# Count of class_2 = 31
# Current Entropy is = 0.885126447529
# Splitting on feature 'magnesium' with gain ratio 1.69536869522
#
# Level 4
# Count of class_1 = 20
# Count of class_2 = 28
# Current Entropy is = 0.679193265992
# Splitting on feature 'proline' with gain ratio 1.47822188307
#
# Level 5
# Count of class_1 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_1 = 14
# Count of class_2 = 28
# Current Entropy is = 0.636514168295
# Splitting on feature 'total_phenols' with gain ratio 0.901822179164
#
# Level 6
# Count of class_1 = 6
# Count of class_2 = 22
# Current Entropy is = 0.519579839131
# Splitting on feature 'alcohol' with gain ratio 0.723185925509
#
# Level 7
# Count of class_1 = 4
# Count of class_2 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.459147917027
#
# Level 8
# Count of class_1 = 1
# Count of class_2 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'malic_acid' with gain ratio 0.0
#
# Level 9
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_1 = 2
# Count of class_2 = 20
# Current Entropy is = 0.304636097349
# Splitting on feature 'malic_acid' with gain ratio 0.7992545375
#
# Level 8
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'flavanoids' with gain ratio 0.0
#
# Level 9
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_1 = 1
# Count of class_2 = 19
# Current Entropy is = 0.198515243346
# Splitting on feature 'color_intensity' with gain ratio 0.224753165919
#
# Level 9
# Count of class_1 = 1
# Count of class_2 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'hue' with gain ratio 0.5
#
# Level 10
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'flavanoids' with gain ratio 0.0
#
# Level 11
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_2 = 16
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_1 = 8
# Count of class_2 = 6
# Current Entropy is = 0.6829081047
# Splitting on feature 'malic_acid' with gain ratio 1.44867718808
#
# Level 7
# Count of class_1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_1 = 6
# Count of class_2 = 6
# Current Entropy is = 0.69314718056
# Splitting on feature 'proanthocyanins' with gain ratio 0.588973686818
#
# Level 8
# Count of class_2 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_1 = 6
# Count of class_2 = 2
# Current Entropy is = 0.562335144619
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 9
# Count of class_1 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 4
# Count of class_1 = 2
# Count of class_2 = 3
# Current Entropy is = 1.06085694716
# Splitting on feature 'proanthocyanins' with gain ratio 1.13231195862
#
# Level 5
# Count of class_0 = 1
# Count of class_1 = 1
# Count of class_2 = 3
# Current Entropy is = 0.950270539233
# Splitting on feature 'alcohol' with gain ratio 0.899012663676
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Count of class_2 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'malic_acid' with gain ratio 0.0
#
# Level 7
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_2 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 3
# Count of class_1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'malic_acid' with gain ratio 0.5
#
# Level 6
# Count of class_0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 7
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature_index"]
    feature_value = tree_dict["best_split_mid_value"]

    if X[index] <= feature_value :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    else:
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])
    
def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key])
        else:
            print(key, dictionary[key])

# %%
print_dict(tree_dict)
# Out:
# level 0
# class_counts class_0 41
# class_1 54
# class_2 38
# Entropy 1.0866659153
# predict_class 1
# num_of_examples 133
# is_leaf False
# selected_feature ash
# selected_feature_index 2
# max_info_gain 0.965874793212
# best_split_mid_value 2.03
# 0 level 1
# class_counts class_1 16
# Entropy 0.0
# predict_class 1
# num_of_examples 16
# is_leaf True
# 1 level 1
# class_counts class_0 41
# class_1 38
# class_2 38
# Entropy 1.09796023502
# predict_class 0
# num_of_examples 117
# is_leaf False
# selected_feature nonflavanoid_phenols
# selected_feature_index 7
# max_info_gain 0.920514465836
# best_split_mid_value 0.355
# 0 level 2
# class_counts class_0 35
# class_1 14
# class_2 7
# Entropy 0.900256051269
# predict_class 0
# num_of_examples 56
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.721593714735
# best_split_mid_value 2.235
# 0 level 3
# class_counts class_0 29
# class_1 9
# Entropy 0.547412468525
# predict_class 0
# num_of_examples 38
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.50833819381
# best_split_mid_value 1.14
# 0 level 4
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 4
# class_counts class_0 29
# class_1 8
# Entropy 0.522077063913
# predict_class 0
# num_of_examples 37
# is_leaf False
# selected_feature hue
# selected_feature_index 10
# max_info_gain 0.477457056796
# best_split_mid_value 1.155
# 0 level 5
# class_counts class_0 24
# class_1 4
# Entropy 0.410116318288
# predict_class 0
# num_of_examples 28
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.336373806706
# best_split_mid_value 88.5
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_0 24
# class_1 3
# Entropy 0.348832095843
# predict_class 0
# num_of_examples 27
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.261145322188
# best_split_mid_value 1.975
# 0 level 7
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_0 24
# class_1 2
# Entropy 0.271189373042
# predict_class 0
# num_of_examples 26
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.226542961862
# best_split_mid_value 3.115
# 0 level 8
# class_counts class_0 11
# Entropy 0.0
# predict_class 0
# num_of_examples 11
# is_leaf True
# 1 level 8
# class_counts class_0 13
# class_1 2
# Entropy 0.392674467228
# predict_class 0
# num_of_examples 15
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.240164064508
# best_split_mid_value 2.255
# 0 level 9
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_0 13
# class_1 1
# Entropy 0.257318640544
# predict_class 0
# num_of_examples 14
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0990210257943
# best_split_mid_value 18.9
# 0 level 10
# class_counts class_0 12
# Entropy 0.0
# predict_class 0
# num_of_examples 12
# is_leaf True
# 1 level 10
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.555
# 0 level 11
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts class_0 5
# class_1 4
# Entropy 0.686961576597
# predict_class 0
# num_of_examples 9
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.588056211696
# best_split_mid_value 2.3
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_0 5
# class_1 3
# Entropy 0.661563238158
# predict_class 0
# num_of_examples 8
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.523485890012
# best_split_mid_value 2.66
# 0 level 7
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_0 5
# class_1 2
# Entropy 0.598269588585
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.396084103177
# best_split_mid_value 3.175
# 0 level 8
# class_counts class_0 2
# class_1 2
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.477385626221
# best_split_mid_value 12.72
# 0 level 9
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_0 2
# class_1 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 21.1
# 0 level 10
# class_counts class_0 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 10
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts class_0 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 3
# class_counts class_0 6
# class_1 5
# class_2 7
# Entropy 1.08930967896
# predict_class 2
# num_of_examples 18
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.79695778522
# best_split_mid_value 12.61
# 0 level 4
# class_counts class_1 4
# class_2 1
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.277258872224
# best_split_mid_value 19.75
# 0 level 5
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# predict_class 1
# num_of_examples 2
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.0
# best_split_mid_value 100.0
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_2 1
# Entropy 0.0
# predict_class 2
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts class_1 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 4
# class_counts class_0 6
# class_1 1
# class_2 6
# Entropy 0.911017539713
# predict_class 0
# num_of_examples 13
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.636734518032
# best_split_mid_value 103.5
# 0 level 5
# class_counts class_0 5
# class_1 1
# class_2 1
# Entropy 0.796311640174
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.386195321885
# best_split_mid_value 1.78
# 0 level 6
# class_counts class_2 1
# Entropy 0.0
# predict_class 2
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_0 5
# class_1 1
# Entropy 0.450561208866
# predict_class 0
# num_of_examples 6
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.318257084147
# best_split_mid_value 2.665
# 0 level 7
# class_counts class_0 2
# class_1 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.462098120373
# best_split_mid_value 3.05
# 0 level 8
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 20.05
# 0 level 9
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_0 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 5
# class_counts class_0 1
# class_2 5
# Entropy 0.450561208866
# predict_class 2
# num_of_examples 6
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.231049060187
# best_split_mid_value 1.195
# 0 level 6
# class_counts class_2 4
# Entropy 0.0
# predict_class 2
# num_of_examples 4
# is_leaf True
# 1 level 6
# class_counts class_0 1
# class_2 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 21.45
# 0 level 7
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_2 1
# Entropy 0.0
# predict_class 2
# num_of_examples 1
# is_leaf True
# 1 level 2
# class_counts class_0 6
# class_1 24
# class_2 31
# Entropy 0.93911235462
# predict_class 2
# num_of_examples 61
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.872537643138
# best_split_mid_value 17.35
# 0 level 3
# class_counts class_0 2
# class_1 2
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.477385626221
# best_split_mid_value 96.0
# 0 level 4
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 4
# class_counts class_0 1
# class_1 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.462098120373
# best_split_mid_value 2.235
# 0 level 5
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.51
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 3
# class_counts class_0 4
# class_1 22
# class_2 31
# Entropy 0.885126447529
# predict_class 2
# num_of_examples 57
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.739455952491
# best_split_mid_value 106.5
# 0 level 4
# class_counts class_1 20
# class_2 28
# Entropy 0.679193265992
# predict_class 2
# num_of_examples 48
# is_leaf False
# selected_feature proline
# selected_feature_index 12
# max_info_gain 0.556949897258
# best_split_mid_value 411.0
# 0 level 5
# class_counts class_1 6
# Entropy 0.0
# predict_class 1
# num_of_examples 6
# is_leaf True
# 1 level 5
# class_counts class_1 14
# class_2 28
# Entropy 0.636514168295
# predict_class 2
# num_of_examples 42
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.574022594321
# best_split_mid_value 1.91
# 0 level 6
# class_counts class_1 6
# class_2 22
# Entropy 0.519579839131
# predict_class 2
# num_of_examples 28
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.375752826838
# best_split_mid_value 12.37
# 0 level 7
# class_counts class_1 4
# class_2 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 6
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.318257084147
# best_split_mid_value 2.045
# 0 level 8
# class_counts class_1 1
# class_2 2
# Entropy 0.636514168295
# predict_class 2
# num_of_examples 3
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 2.32
# 0 level 9
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_2 2
# Entropy 0.0
# predict_class 2
# num_of_examples 2
# is_leaf True
# 1 level 8
# class_counts class_1 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 7
# class_counts class_1 2
# class_2 20
# Entropy 0.304636097349
# predict_class 2
# num_of_examples 22
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.243481783093
# best_split_mid_value 1.96
# 0 level 8
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# predict_class 1
# num_of_examples 2
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.0
# best_split_mid_value 1.02
# 0 level 9
# class_counts class_2 1
# Entropy 0.0
# predict_class 2
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts class_1 1
# class_2 19
# Entropy 0.198515243346
# predict_class 2
# num_of_examples 20
# is_leaf False
# selected_feature color_intensity
# selected_feature_index 9
# max_info_gain 0.112467028924
# best_split_mid_value 4.85
# 0 level 9
# class_counts class_1 1
# class_2 3
# Entropy 0.562335144619
# predict_class 2
# num_of_examples 4
# is_leaf False
# selected_feature hue
# selected_feature_index 10
# max_info_gain 0.34657359028
# best_split_mid_value 0.805
# 0 level 10
# class_counts class_2 2
# Entropy 0.0
# predict_class 2
# num_of_examples 2
# is_leaf True
# 1 level 10
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# predict_class 1
# num_of_examples 2
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.0
# best_split_mid_value 1.055
# 0 level 11
# class_counts class_2 1
# Entropy 0.0
# predict_class 2
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts class_2 16
# Entropy 0.0
# predict_class 2
# num_of_examples 16
# is_leaf True
# 1 level 6
# class_counts class_1 8
# class_2 6
# Entropy 0.6829081047
# predict_class 1
# num_of_examples 14
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.594126154766
# best_split_mid_value 1.225
# 0 level 7
# class_counts class_1 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 7
# class_counts class_1 6
# class_2 6
# Entropy 0.69314718056
# predict_class 1
# num_of_examples 12
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.374890096413
# best_split_mid_value 1.295
# 0 level 8
# class_counts class_2 4
# Entropy 0.0
# predict_class 2
# num_of_examples 4
# is_leaf True
# 1 level 8
# class_counts class_1 6
# class_2 2
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 8
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.415
# 0 level 9
# class_counts class_1 6
# Entropy 0.0
# predict_class 1
# num_of_examples 6
# is_leaf True
# 1 level 9
# class_counts class_2 2
# Entropy 0.0
# predict_class 2
# num_of_examples 2
# is_leaf True
# 1 level 4
# class_counts class_0 4
# class_1 2
# class_2 3
# Entropy 1.06085694716
# predict_class 0
# num_of_examples 9
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.777854808293
# best_split_mid_value 1.59
# 0 level 5
# class_counts class_0 1
# class_1 1
# class_2 3
# Entropy 0.950270539233
# predict_class 2
# num_of_examples 5
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.449868115695
# best_split_mid_value 12.505
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts class_0 1
# class_2 3
# Entropy 0.562335144619
# predict_class 2
# num_of_examples 4
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 2.06
# 0 level 7
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_2 3
# Entropy 0.0
# predict_class 2
# num_of_examples 3
# is_leaf True
# 1 level 5
# class_counts class_0 3
# class_1 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.34657359028
# best_split_mid_value 1.975
# 0 level 6
# class_counts class_0 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 6
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.305
# 0 level 7
# class_counts class_1 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts class_0 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True

# %%
for i in range(len(X)):
    print("Example", i)
    pred = predict_single(X[i], tree_dict)

    print("\tActual Class:", class_dict[Y[i]])
    print("\tPredicted Class:", class_dict[pred])
# Out:
# Example 0
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 1
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 2
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 3
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 4
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 5
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 6
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 7
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 8
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 9
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 10
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 11
# 	Actual Class: class_0
# 	Predicted Class: class_1
# Example 12
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 13
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 14
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 15
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 16
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 17
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 18
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 19
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 20
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 21
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 22
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 23
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 24
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 25
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 26
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 27
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 28
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 29
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 30
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 31
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 32
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 33
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 34
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 35
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 36
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 37
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 38
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 39
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 40
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 41
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 42
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 43
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 44
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 45
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 46
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 47
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 48
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 49
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 50
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 51
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 52
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 53
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 54
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 55
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 56
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 57
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 58
# 	Actual Class: class_0
# 	Predicted Class: class_0
# Example 59
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 60
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 61
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 62
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 63
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 64
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 65
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 66
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 67
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 68
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 69
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 70
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 71
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 72
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 73
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 74
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 75
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 76
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 77
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 78
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 79
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 80
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 81
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 82
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 83
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 84
# 	Actual Class: class_1
# 	Predicted Class: class_0
# Example 85
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 86
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 87
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 88
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 89
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 90
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 91
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 92
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 93
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 94
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 95
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 96
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 97
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 98
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 99
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 100
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 101
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 102
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 103
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 104
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 105
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 106
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 107
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 108
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 109
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 110
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 111
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 112
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 113
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 114
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 115
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 116
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 117
# 	Actual Class: class_1
# 	Predicted Class: class_0
# Example 118
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 119
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 120
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 121
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 122
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 123
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 124
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 125
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 126
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 127
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 128
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 129
# 	Actual Class: class_1
# 	Predicted Class: class_1
# Example 130
# 	Actual Class: class_2
# 	Predicted Class: class_1
# Example 131
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 132
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 133
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 134
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 135
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 136
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 137
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 138
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 139
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 140
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 141
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 142
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 143
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 144
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 145
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 146
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 147
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 148
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 149
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 150
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 151
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 152
# 	Actual Class: class_2
# 	Predicted Class: class_0
# Example 153
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 154
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 155
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 156
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 157
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 158
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 159
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 160
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 161
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 162
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 163
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 164
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 165
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 166
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 167
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 168
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 169
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 170
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 171
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 172
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 173
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 174
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 175
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 176
# 	Actual Class: class_2
# 	Predicted Class: class_2
# Example 177
# 	Actual Class: class_2
# 	Predicted Class: class_2

# %%
import matplotlib.pyplot as plt

def get_lines(indices, Y_pred, Y):
    lines = []
    for i in indices :
        if Y_pred[i] != Y[i] :
            line = [[i, i], [Y_pred[i], Y[i]]]
            lines.append(line)
    return lines

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_train), -1, len(class_dict)))
plt.scatter(indices, Y_train_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_train, c = Y_train)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_train_pred, Y_train)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
    
plt.legend()
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_test), -1, len(class_dict)))
plt.scatter(indices, Y_test_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_test, c = Y_test)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_test_pred, Y_test)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[41  0  0]
#  [ 0 54  0]
#  [ 0  0 38]]
# Confusion Matrix for Y_test
#  [[17  1  0]
#  [ 2 15  0]
#  [ 1  1  8]]

# %%
# Level order traversal

def print_node(node):
    for key, val in node.items() :
        if not isinstance(val, dict) :
            print(key, ":", val)
    
def print_tree_level_order(tree_dict):
    from collections import deque
    q = deque([tree_dict])
    while len(q)!= 0 :
        node = q.popleft()
        print("*" * 100)
        print("Len", len(q))
        print("*" * 100)
        if 0 in node.keys() :
            q.append(node[0])
            
        if 1 in node.keys() :
            q.append(node[1])
        print_node(node)

print_tree_level_order(tree_dict)
# Out:
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 0
# Entropy : 1.0866659153
# predict_class : 1
# num_of_examples : 133
# is_leaf : False
# selected_feature : ash
# selected_feature_index : 2
# max_info_gain : 0.965874793212
# best_split_mid_value : 2.03
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 1
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 16
# is_leaf : True
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 1
# Entropy : 1.09796023502
# predict_class : 0
# num_of_examples : 117
# is_leaf : False
# selected_feature : nonflavanoid_phenols
# selected_feature_index : 7
# max_info_gain : 0.920514465836
# best_split_mid_value : 0.355
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 2
# Entropy : 0.900256051269
# predict_class : 0
# num_of_examples : 56
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.721593714735
# best_split_mid_value : 2.235
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 2
# Entropy : 0.93911235462
# predict_class : 2
# num_of_examples : 61
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.872537643138
# best_split_mid_value : 17.35
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 3
# Entropy : 0.547412468525
# predict_class : 0
# num_of_examples : 38
# is_leaf : False
# selected_feature : proanthocyanins
# selected_feature_index : 8
# max_info_gain : 0.50833819381
# best_split_mid_value : 1.14
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 3
# Entropy : 1.08930967896
# predict_class : 2
# num_of_examples : 18
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.79695778522
# best_split_mid_value : 12.61
# ****************************************************************************************************
# Len 5
# ****************************************************************************************************
# level : 3
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : magnesium
# selected_feature_index : 4
# max_info_gain : 0.477385626221
# best_split_mid_value : 96.0
# ****************************************************************************************************
# Len 6
# ****************************************************************************************************
# level : 3
# Entropy : 0.885126447529
# predict_class : 2
# num_of_examples : 57
# is_leaf : False
# selected_feature : magnesium
# selected_feature_index : 4
# max_info_gain : 0.739455952491
# best_split_mid_value : 106.5
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 4
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 6
# ****************************************************************************************************
# level : 4
# Entropy : 0.522077063913
# predict_class : 0
# num_of_examples : 37
# is_leaf : False
# selected_feature : hue
# selected_feature_index : 10
# max_info_gain : 0.477457056796
# best_split_mid_value : 1.155
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 4
# Entropy : 0.500402423538
# predict_class : 1
# num_of_examples : 5
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.277258872224
# best_split_mid_value : 19.75
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 4
# Entropy : 0.911017539713
# predict_class : 0
# num_of_examples : 13
# is_leaf : False
# selected_feature : magnesium
# selected_feature_index : 4
# max_info_gain : 0.636734518032
# best_split_mid_value : 103.5
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 4
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 4
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 3
# is_leaf : False
# selected_feature : total_phenols
# selected_feature_index : 5
# max_info_gain : 0.462098120373
# best_split_mid_value : 2.235
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 4
# Entropy : 0.679193265992
# predict_class : 2
# num_of_examples : 48
# is_leaf : False
# selected_feature : proline
# selected_feature_index : 12
# max_info_gain : 0.556949897258
# best_split_mid_value : 411.0
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 4
# Entropy : 1.06085694716
# predict_class : 0
# num_of_examples : 9
# is_leaf : False
# selected_feature : proanthocyanins
# selected_feature_index : 8
# max_info_gain : 0.777854808293
# best_split_mid_value : 1.59
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 5
# Entropy : 0.410116318288
# predict_class : 0
# num_of_examples : 28
# is_leaf : False
# selected_feature : magnesium
# selected_feature_index : 4
# max_info_gain : 0.336373806706
# best_split_mid_value : 88.5
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 5
# Entropy : 0.686961576597
# predict_class : 0
# num_of_examples : 9
# is_leaf : False
# selected_feature : total_phenols
# selected_feature_index : 5
# max_info_gain : 0.588056211696
# best_split_mid_value : 2.3
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 5
# Entropy : 0.69314718056
# predict_class : 1
# num_of_examples : 2
# is_leaf : False
# selected_feature : magnesium
# selected_feature_index : 4
# max_info_gain : 0.0
# best_split_mid_value : 100.0
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 5
# Entropy : 0.796311640174
# predict_class : 0
# num_of_examples : 7
# is_leaf : False
# selected_feature : total_phenols
# selected_feature_index : 5
# max_info_gain : 0.386195321885
# best_split_mid_value : 1.78
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.450561208866
# predict_class : 2
# num_of_examples : 6
# is_leaf : False
# selected_feature : proanthocyanins
# selected_feature_index : 8
# max_info_gain : 0.231049060187
# best_split_mid_value : 1.195
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 5
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 13.51
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 5
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 6
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.636514168295
# predict_class : 2
# num_of_examples : 42
# is_leaf : False
# selected_feature : total_phenols
# selected_feature_index : 5
# max_info_gain : 0.574022594321
# best_split_mid_value : 1.91
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 5
# Entropy : 0.950270539233
# predict_class : 2
# num_of_examples : 5
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.449868115695
# best_split_mid_value : 12.505
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 5
# Entropy : 0.562335144619
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.34657359028
# best_split_mid_value : 1.975
# ****************************************************************************************************
# Len 17
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 6
# Entropy : 0.348832095843
# predict_class : 0
# num_of_examples : 27
# is_leaf : False
# selected_feature : total_phenols
# selected_feature_index : 5
# max_info_gain : 0.261145322188
# best_split_mid_value : 1.975
# ****************************************************************************************************
# Len 17
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 6
# Entropy : 0.661563238158
# predict_class : 0
# num_of_examples : 8
# is_leaf : False
# selected_feature : od280/od315_of_diluted_wines
# selected_feature_index : 11
# max_info_gain : 0.523485890012
# best_split_mid_value : 2.66
# ****************************************************************************************************
# Len 17
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.450561208866
# predict_class : 0
# num_of_examples : 6
# is_leaf : False
# selected_feature : flavanoids
# selected_feature_index : 6
# max_info_gain : 0.318257084147
# best_split_mid_value : 2.665
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 4
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.0
# best_split_mid_value : 21.45
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 6
# Entropy : 0.519579839131
# predict_class : 2
# num_of_examples : 28
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.375752826838
# best_split_mid_value : 12.37
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.6829081047
# predict_class : 1
# num_of_examples : 14
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.594126154766
# best_split_mid_value : 1.225
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.562335144619
# predict_class : 2
# num_of_examples : 4
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.0
# best_split_mid_value : 2.06
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 6
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 12.305
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.271189373042
# predict_class : 0
# num_of_examples : 26
# is_leaf : False
# selected_feature : od280/od315_of_diluted_wines
# selected_feature_index : 11
# max_info_gain : 0.226542961862
# best_split_mid_value : 3.115
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.598269588585
# predict_class : 0
# num_of_examples : 7
# is_leaf : False
# selected_feature : flavanoids
# selected_feature_index : 6
# max_info_gain : 0.396084103177
# best_split_mid_value : 3.175
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.636514168295
# predict_class : 0
# num_of_examples : 3
# is_leaf : False
# selected_feature : od280/od315_of_diluted_wines
# selected_feature_index : 11
# max_info_gain : 0.462098120373
# best_split_mid_value : 3.05
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 7
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 6
# is_leaf : False
# selected_feature : od280/od315_of_diluted_wines
# selected_feature_index : 11
# max_info_gain : 0.318257084147
# best_split_mid_value : 2.045
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.304636097349
# predict_class : 2
# num_of_examples : 22
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.243481783093
# best_split_mid_value : 1.96
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.69314718056
# predict_class : 1
# num_of_examples : 12
# is_leaf : False
# selected_feature : proanthocyanins
# selected_feature_index : 8
# max_info_gain : 0.374890096413
# best_split_mid_value : 1.295
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 11
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 8
# Entropy : 0.392674467228
# predict_class : 0
# num_of_examples : 15
# is_leaf : False
# selected_feature : flavanoids
# selected_feature_index : 6
# max_info_gain : 0.240164064508
# best_split_mid_value : 2.255
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.477385626221
# best_split_mid_value : 12.72
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.0
# best_split_mid_value : 20.05
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 8
# Entropy : 0.636514168295
# predict_class : 2
# num_of_examples : 3
# is_leaf : False
# selected_feature : malic_acid
# selected_feature_index : 1
# max_info_gain : 0.0
# best_split_mid_value : 2.32
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 1
# num_of_examples : 2
# is_leaf : False
# selected_feature : flavanoids
# selected_feature_index : 6
# max_info_gain : 0.0
# best_split_mid_value : 1.02
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 8
# Entropy : 0.198515243346
# predict_class : 2
# num_of_examples : 20
# is_leaf : False
# selected_feature : color_intensity
# selected_feature_index : 9
# max_info_gain : 0.112467028924
# best_split_mid_value : 4.85
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 4
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 8
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 8
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 13.415
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 9
# Entropy : 0.257318640544
# predict_class : 0
# num_of_examples : 14
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.0990210257943
# best_split_mid_value : 18.9
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 9
# Entropy : 0.636514168295
# predict_class : 0
# num_of_examples : 3
# is_leaf : False
# selected_feature : alcalinity_of_ash
# selected_feature_index : 3
# max_info_gain : 0.0
# best_split_mid_value : 21.1
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 9
# Entropy : 0.562335144619
# predict_class : 2
# num_of_examples : 4
# is_leaf : False
# selected_feature : hue
# selected_feature_index : 10
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.805
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 16
# is_leaf : True
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 6
# is_leaf : True
# ****************************************************************************************************
# Len 6
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 5
# ****************************************************************************************************
# level : 10
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 12
# is_leaf : True
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 10
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : alcohol
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 12.555
# ****************************************************************************************************
# Len 5
# ****************************************************************************************************
# level : 10
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 10
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 10
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 10
# Entropy : 0.69314718056
# predict_class : 1
# num_of_examples : 2
# is_leaf : False
# selected_feature : flavanoids
# selected_feature_index : 6
# max_info_gain : 0.0
# best_split_mid_value : 1.055
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 11
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 11
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 11
# Entropy : 0.0
# predict_class : 2
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 11
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True

# %% [markdown]
# ### PyDotPlus Documentation Reference
# http://pydotplus.readthedocs.io/reference.html

# %%
import pydotplus as dot

def get_node_data(node, class_dict):
    data = ""
    if not node['is_leaf'] :
        data += node['selected_feature'] + " <= " + str(node['best_split_mid_value']) + "\n"
        data += "Gain = " + str(node['max_info_gain']) + "\n"
    data += "entropy = " + str(node['Entropy']) + "\n"
    data += "samples = " + str(node['num_of_examples']) + "\n"
    value = [0 for i in range(len(class_dict))]
    for index, name in class_dict.items():
        if name in node["class_counts"] :
            value[index] = (node["class_counts"][name])
    data += "value = " + str(value) + "\n"
    data += "class = " + class_dict[node['predict_class']]
        
    return data

def get_decision_tree_graph(tree_dict, class_dict):
    graph = dot.Dot(graph_type = "digraph", simplify = True, strict = True)
    
    from collections import deque
    q = deque([tree_dict])
    
    
    while len(q)!= 0 :
        
        node = q.popleft()
        
        parent_node = get_node_data(node, class_dict)
        
        if 0 in node.keys() :
            q.append(node[0])
            child_0_node = get_node_data(node[0], class_dict)
            edge = dot.Edge(parent_node, child_0_node, label = True)
            graph.add_edge(edge)
            
        if 1 in node.keys() :
            q.append(node[1])
            child_1_node = get_node_data(node[1], class_dict)
            edge = dot.Edge(parent_node, child_1_node, label = False)
            graph.add_edge(edge)
    return graph

graph = get_decision_tree_graph(tree_dict, class_dict)
graph.write_png("wine_dataset_decision_tree.png")
# Out:
# True
