# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
train_df = pd.read_csv("training_twitter_x_y_train.csv")
train_df
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# 5      569677636613439488          negative      United
# 6      569658903044218880          negative       Delta
# 7      568542766860541952          positive       Delta
# 8      570116209263427584          negative      United
# 9      568870144891600896          positive   Southwest
# 10     567793635892174848          negative   Southwest
# 11     569879497891303424           neutral       Delta
# 12     568517827482685440          positive  US Airways
# 13     568212893012860928          negative   Southwest
# 14     569270187725160449          negative  US Airways
# 15     567816651900583936          negative  US Airways
# ...

# %%
non_zero_retweets = train_df[train_df['retweet_count'] > 0]
print(len(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'negative']))
print(len(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'positive']))
print(len(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'neutral']))

print(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'negative'])
print(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'positive'])
print(non_zero_retweets[non_zero_retweets['airline_sentiment'] == 'neutral'])
# Out:
# 454
# 54
# 62
#                  tweet_id airline_sentiment     airline  \
# 8      570116209263427584          negative      United
# 17     569932678688055296          negative       Delta
# 62     568964974611193858          negative      United
# 83     568246093856641024          negative      United
# 90     570042796624777216          negative  US Airways
# 113    568918820632403969          negative      United
# 130    569722907187752960          negative      United
# 143    569617808885096448          negative    American
# 163    569204255191490560          negative      United
# 190    567822065471860736          negative      United
# 194    569555930028748800          negative  US Airways
# 222    570269172774649856          negative      United
# 227    567823459276877824          negative   Southwest
# 248    569011727532032001          negative      United
# 263    568900770860392448          negative      United
# ...

# %%
def num_senti(s):
    if s == "negative" :
        return -1
    elif s == "neutral" :
        return 0
    else:
        return 1
def num_to_sent(s):
    if s == -1 :
        return "negative"
    elif s == 0 :
        return "neutral"
    else:
        return "positive"

# %%
tweets = train_df["text"].values

# %%
def split_attached_words_remove_punct(tweets) :
    clean_tweets = []
    import re
    import string
    printable = set(string.printable)
    
    for tweet in tweets :
        new_tweet = []
        for word in re.findall("[A-Z][^A-Z]+", tweet):
            clean_word = re.sub("[0-9]*", '', word)
            clean_word = re.sub("\s+", " ", clean_word)
            content = [c for c in clean_word if c in printable]
            clean_word = ""
            for c in content :
                clean_word += c
            new_tweet.append(clean_word)
        clean_tweets.append(" ".join(new_tweet))
    return clean_tweets
        
def remove_stop_words(tweets, stops) :
    from nltk import word_tokenize
    clean_tweets = []
    for tweet in tweets :
        new_tweet = []
        for word in word_tokenize(tweet):
            if word.lower() not in stops :            
                new_tweet.append(word)
        clean_tweets.append(" ".join(new_tweet))
    return clean_tweets
        
import string
from nltk.corpus import stopwords
stops = list(stopwords.words('english'))
stops += (list(string.punctuation))
stops


def remove_hrefs(tweets) :
    clean_tweets = []
    import re
    for tweet in tweets :
        new_tweet = []
        for word in tweet.split():
            if not (word.startswith("http://") or word.startswith("https://")):
                new_tweet.append(word)
            else:
                print("found", word)
        clean_tweets.append(" ".join(new_tweet))
    return clean_tweets

# %%
hrefs_removed = remove_hrefs(tweets)
stop_words_removed = remove_stop_words(hrefs_removed, stops)
clean_tweets = split_attached_words_remove_punct(stop_words_removed)
clean_tweets
# Out:
# found http://t.co/413GiAL0yl
# found http://t.co/vUdWJm1lYB
# found http://t.co/FeFHPmFPlE
# found http://t.co/Q37pOWn6uv
# found http://t.co/U390cZpLHl
# found http://t.co/N3LrFo4UaY
# found http://t.co/1G9RnmYUQe”
# found http://t.co/Hlm2Oks6xl
# found http://t.co/EczHcmM5vi
# found http://t.co/vC6Keulg2J
# found http://t.co/deWIthPeW2
# found http://t.co/xmRvR4lGEg
# found http://t.co/wJoc9f14SU”@tori_leggieri
# found http://t.co/5hpSqVRjK8
# found http://t.co/bdUaUZFhW2
# found http://t.co/xMAQcucWZl
# found http://t.co/e0C9bI09cf
# found http://t.co/aJM3BhJVaa”
# found http://t.co/oA2dRfAoQ2
# found http://t.co/lWWdAc2kHx
# found http://t.co/fTTfyFMvCO
# found http://t.co/aQjn4HwNaC
# found http://t.co/1ESmMnIZEk
# found http://t.co/qgtCao1J2U
# found http://t.co/se57dmjHiW
# found http://t.co/kfD4WQRkLW
# found http://t.co/lyoocx5mSH
# found http://t.co/TwETPXUpPN
# found http://t.co/tmccExYaaQ
# found http://t.co/nw7vx7DGMF
# found http://t.co/ZL4bVEXmcJ
# ...

# %%
stop_words_removed = remove_stop_words(clean_tweets, stops)
stop_words_removed
# Out:
# ['Southwest Air scheduled morning days fact yes..not sure evening flight one Cancelled Flightled',
#  'Southwest Air seeing workers time time going beyond love flying guys Thank',
#  'Flew Miami back great crew service legs',
#  "Southwest Air dultch 's horse radish",
#  'delayed Air Force One last flight N mins landed',
#  'Late Flight incompetent beyond belief',
#  "Jet Blue stock response Delays frustrating poor cust serv amp told ppl wait amp 'd come back",
#  "Jet Blue 'd nice Hoping rack enough miles take trip Seattle enjoy perfect latte city coffee",
#  'Problems happen deal defines company Never United',
#  "Southwest Air yeah haha Never one 's expensive much fun destinationdragons",
#  "Southwest Air O- gt flight almost full people screwed Y- Cancelled Flightation united Airways n't Cancelled Flight A=mistake",
#  "Jet Blue 's easiest way get ticket receipt get one check get one online Thanks",
# ...

# %%
final_train_tweets = stop_words_removed

# %%
test_df = pd.read_csv("test_twitter_x_test.csv")
test_df
# Out:
#                 tweet_id         airline airline_sentiment_gold  \
# 0     569682010270101504        American                    NaN
# 1     569608307184242688        American                    NaN
# 2     567879304593408001       Southwest                    NaN
# 3     569757651539660801      US Airways                    NaN
# 4     569900705852608513        American                    NaN
# 5     569235062862036992          United                    NaN
# 6     569824422279950336      US Airways                    NaN
# 7     567880416201293824      US Airways                    NaN
# 8     570021943899877377      US Airways                    NaN
# 9     569690664029462529        American                    NaN
# 10    570271205300703232          United                    NaN
# 11    569996446348517376      US Airways                    NaN
# 12    568105481018822656       Southwest                    NaN
# 13    570275010759102466        American                    NaN
# ...

# %%
test_tweets = test_df["text"].values

# %%
hrefs_removed = remove_hrefs(test_tweets)
stop_words_removed = remove_stop_words(hrefs_removed, stops)
clean_tweets = split_attached_words_remove_punct(stop_words_removed)
clean_tweets
# Out:
# found https://t.co/9zA6xb1h89
# found http://t.co/Ci5cfrlqBe
# found https://t.co/dFmvmiBH4x
# found http://t.co/EIw2sYb8Fu
# found http://t.co/KDzQcZlpyR
# found http://t.co/lJzDTHD9Bv
# found http://t.co/WHAGPknnLF
# found http://t.co/DNMsblzumr
# found http://t.co/eQqi1nfSZh
# found http://t.co/V5QWkYXSW6”
# found http://t.co/0EWj7oKlji
# found http://t.co/A1ChOxKPJp
# found http://t.co/xAIzW2isml
# found http://t.co/scQUjbvsTA
# found http://t.co/MbLTALr4BS
# found http://t.co/5fmipW9dhi
# found http://t.co/pyJAoayNx6
# found http://t.co/dzKc3auZU9
# found http://t.co/ZoFWLdQXbe
# found http://t.co/9SHhTvIOTI
# found http://t.co/JM8gQ1KGrF
# found http://t.co/lwOtKIEKGU
# found http://t.co/vGN2X1ckg0
# found http://t.co/ILqzmMJiYQ
# found http://t.co/ToPqmVqnJp
# found http://t.co/dr5oCtp1DY
# found http://t.co/1ZT2kEe8up
# found http://t.co/778AzTDaer
# found http://t.co/t3E4SH5xNg
# found http://t.co/PEQ90pqMpp
# found http://t.co/22iPGeIcSm
# found http://t.co/5IMDckODfx
# ...

# %%
stop_words_removed = remove_stop_words(clean_tweets, stops)
stop_words_removed
# Out:
# ["American Air car gng W Pulled hr ago icy roads On-hold since hr Ca n't reach arpt Wat",
#  'American Air plane land identical worse conditions K according Rs',
#  "Southwest Air ca n't believe many paying customers left high dry reason flight Cancelled Flightlations Monday L Wow",
#  'Airways legitimately say would rather driven cross country flown Airways',
#  'American Air still response great job guys',
#  '',
#  'Airways hello Anyone',
#  'Airways husainhaqqani Mr. Husain u shld protest well one ur party member Rehman Malik delayed flight hours..',
#  "Airways likely flightaware says plane still Durango n't departed",
#  "American Air n't even give option hold.. say lines busy Plz try Late Flightr",
#  '',
#  'Airways really embarrassing asking complimentary drink/snack detailed amp argued',
#  'Southwest Air passport time trip Could still fly photo thingsishouldknow ifeeldumb',
#  'American Air delayed bag friend Lisa Pafe got bag days Costa Rica Issue updates system',
# ...

# %%
final_test_tweets = stop_words_removed

# %%
tfidf = TfidfVectorizer(max_features = 20000, max_df = 0.999, min_df = 0.0001, ngram_range=(1, 3))

# %%
X_train = tfidf.fit_transform(final_train_tweets).todense()
X_test = tfidf.transform(final_test_tweets)
print(X_train.shape)
print(X_test.shape)
# Out:
# (10980, 15852)
# (3660, 15852)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test.todense())
pca = PCA()
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
Y_train = [num_senti(sentiment) for sentiment in train_df['airline_sentiment'].values]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)

# %%
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# Out:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)

# %%
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
# Out:
# BaggingClassifier(base_estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=-1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)

# %%
print("Neural Network", nn_clf.score(X_train_pca, Y_train))
print("Random Forest", rf_clf.score(X_train_pca, Y_train))
print("Naive Bayes", nb_clf.score(X_train, Y_train))
print("Adaboost Log Regr", ada_clf.score(X_train_pca, Y_train))
print("Bagging SVM", bag_clf.score(X_train_pca, Y_train))
# Out:
# Neural Network 0.957559198543
# Random Forest 0.945173041894
# Naive Bayes 0.812659380692
# Adaboost Log Regr 0.813479052823
# Bagging SVM 0.866666666667

# %%
# Out:
# (3660, 5)

# %%
# Out:
# -1

# %%
# Out:
# Counter({-1: 5})
# Counter({-1: 3, 0: 2})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({0: 3, -1: 2})
# Counter({-1: 5})
# Counter({-1: 3, 0: 2})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({0: 3, -1: 2})
# Counter({-1: 3, 0: 2})
# Counter({-1: 4, 0: 1})
# Counter({-1: 3, 1: 2})
# Counter({-1: 4, 1: 1})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({0: 4, -1: 1})
# Counter({-1: 4, 0: 1})
# Counter({-1: 4, 0: 1})
# Counter({-1: 3, 0: 2})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({1: 5})
# Counter({1: 3, -1: 2})
# Counter({-1: 3, 0: 2})
# Counter({1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# Counter({-1: 5})
# ...

# %%
# 0.73
# 0.67
# 0.753
# 0.71
# 0.72

# %%
#tfidf = TfidfVectorizer(max_features = 20000, max_df = 0.999, min_df = 0.0003, ngram_range=(1, 4))
#X_train = tfidf.fit_transform(final_train_tweets).todense()
#X_test = tfidf.transform(final_test_tweets)

tfidf = CountVectorizer(max_features = 10000, max_df = 0.999, min_df = 0.0001, ngram_range=(1, 4))
X_train = tfidf.fit_transform(final_train_tweets).todense()
X_test = tfidf.transform(final_test_tweets)
print(X_train.shape)
print(X_test.shape)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test.todense())
# Out:
# (10980, 5253)
# (3660, 5253)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# %%
clf = LogisticRegressionCV(Cs = [0.00001, 0.0001, 0.001, 0.01], cv = 3, solver = 'sag', n_jobs = -1, verbose = 1, max_iter = 500)

# %%
clf.fit(X_train_scaled, Y_train)
# Out:
# convergence after 58 epochs took 64 seconds
# convergence after 60 epochs took 66 seconds
# convergence after 60 epochs took 67 seconds
# convergence after 24 epochs took 22 seconds
# convergence after 26 epochs took 23 seconds
# convergence after 27 epochs took 25 seconds
# convergence after 101 epochs took 103 seconds
# convergence after 50 epochs took 43 seconds
# convergence after 106 epochs took 92 seconds
# convergence after 105 epochs took 90 seconds
# convergence after 115 epochs took 99 seconds
# convergence after 182 epochs took 157 seconds
# convergence after 419 epochs took 365 seconds
# convergence after 430 epochs took 375 seconds
# convergence after 448 epochs took 391 seconds
# convergence after 95 epochs took 104 seconds
# convergence after 97 epochs took 110 seconds
# convergence after 92 epochs took 106 seconds
# convergence after 53 epochs took 58 seconds
# convergence after 49 epochs took 53 seconds
# convergence after 46 epochs took 49 seconds
# ...

# %%
clf.scores_
# Out:
# {-1: array([[ 0.62551216,  0.74269325,  0.78912865,  0.76864245],
#         [ 0.62496586,  0.74323955,  0.78339252,  0.76454521],
#         [ 0.6265719 ,  0.75150355,  0.79141607,  0.7695462 ]]),
#  0: array([[ 0.78803606,  0.79704999,  0.80797596,  0.79322589],
#         [ 0.78803606,  0.79650369,  0.80961486,  0.78639716],
#         [ 0.78813559,  0.79496993,  0.81355932,  0.7870421 ]]),
#  1: array([[ 0.8358372 ,  0.84130019,  0.87899481,  0.87926796],
#         [ 0.8358372 ,  0.84457798,  0.8855504 ,  0.88309205],
#         [ 0.83597594,  0.84472389,  0.88135593,  0.88026244]])}

# %%
clf.C_
# Out:
# array([ 0.001,  0.001,  0.001])

# %%
Y_train_pred = clf.predict(X_train_scaled)
import matplotlib.pyplot as plt
plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 2], c = Y_train_pred)
plt.show()

# %%
best_clf = LogisticRegression(C = 0.001, solver = 'sag', max_iter=1000, fit_intercept = True)

# %%
best_clf.fit(X_train_pca, Y_train)

# %%
best_clf.score(X_train_pca, Y_train)
# Out:
# 0.87295081967213117

# %%
Y_pred = clf.predict(X_train_pca)
Y_pred_txt = [num_to_sent(sent) for sent in Y_pred]
np.savetxt("predictions.csv", Y_pred_txt, fmt = "%s")

# %%
def make_grid (X, Y, h = 0.2) :
    x = np.arange(X.min() -1, X.max() + 1, h)
    y = np.arange(Y.min() -1, Y.max() + 1, h)
    x_grid, y_grid = np.meshgrid(x, y)
    return x_grid, y_grid

# %%
x_grid, y_grid = make_grid(X_train_scaled[:, 1], X_train_scaled[:, 2], 1)

# %%
size = len(x_grid)
print(size)
grid = np.c_[x_grid.reshape(-1), y_grid.reshape(-1)]
print(grid.shape)
# Out:
# 210
# (57540, 2)

# %%
pred_grid = clf.predict(grid)

# %%
Y_train_pred = clf.predict(X_train_scaled[:, :2])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(x_grid.reshape(-1), y_grid.reshape(-1), c = pred_grid)
plt.show()

# %%
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c = Y_train_pred)
plt.show()
