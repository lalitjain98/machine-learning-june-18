# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
dataset = datasets.load_iris()
X = dataset.data
Y = dataset.target
#for i in range(X.shape[1]):
#    X[:, i] = level(X[:, i])
feature_names = dataset.feature_names
class_names = dataset.target_names
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

def info_gain_for_cont_data_split(Y, splits):
    info_gain = 0
    split_info = 0    
    mod_Y = len(Y)
    unique_splits = list(set(splits))
    for s in unique_splits:
        indices = (splits == s)
        Y_split_i = Y[indices]
        #print([X_split_i, Y_split_i])
        mod_Y_i = len(Y_split_i)
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        possible_classes_Y_i = list(set(Y_split_i))
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    return info_gain, split_info

def split(X, Y, feature):
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    mid_values = []
    
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = []
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        current_split_labels[ X[:, feature] <= value ] = 0
        current_split_information_gain, current_split_split_info = info_gain_for_cont_data_split(Y, current_split_labels)
        #print(current_split_information_gain)
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    #print("min_info_gain, min_split_info, best_split_labels, mid_value_for_min_info_gain")
    #print(min_info_gain, min_split_info, best_split_labels, mid_value_for_min_info_gain)
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain



    
def decision_tree(X, Y, features, feature_names, level):
    node = {}
    node["level"] = level
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    max_count = -np.inf
    max_class = possible_classes[0]
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[y] = count_y
        print("Count of", y, "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    node['class_counts'] = class_counts
    node["Entropy"] = current_entropy
    
    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        node["predict_class"] = max_class
        return node
    node["is_leaf"] = False
    selected_feature = None
    max_info_gain = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    for f in features:
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        if info_gain > max_info_gain:
            selected_feature = f
            max_info_gain = info_gain
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f
    
    node["selected_feature"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    node["num_of_examples"] = len(Y)
    
    print("Splitting on feature", selected_feature,"with gain ratio", max_info_gain)
    #splits = split(X, Y, selected_feature)
    unique_splits = list(set(best_split_labels))
    
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    for s in unique_splits:
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, level + 1)
    return node
#print(split(X, Y, 0))
      
    
features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, level = 0)
# Out:
# Level 0
# Count of 0 = 37
# Count of 1 = 39
# Count of 2 = 36
# Current Entropy is = 1.09805647173
# Splitting on feature 1 with gain ratio 0.946980474023
#
# Level 1
# Count of 0 = 6
# Count of 1 = 31
# Count of 2 = 21
# Current Entropy is = 0.937354539053
# Splitting on feature 0 with gain ratio 0.716909207175
#
# Level 2
# Count of 0 = 6
# Count of 1 = 3
# Count of 2 = 1
# Current Entropy is = 0.897945724857
# Splitting on feature 2 with gain ratio 0.224934057848
#
# Level 3
# Count of 0 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of 1 = 3
# Count of 2 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 3 with gain ratio 0.0
#
# Level 4
# Count of 1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of 1 = 28
# Count of 2 = 20
# Current Entropy is = 0.679193265992
# Splitting on feature 3 with gain ratio 0.205334170586
#
# Level 3
# Count of 1 = 28
# Count of 2 = 3
# Current Entropy is = 0.317936780262
# Splitting on feature 2 with gain ratio 0.0725593734992
#
# Level 4
# Count of 1 = 27
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 1 = 1
# Count of 2 = 3
# Current Entropy is = 0.562335144619
# Reached leaf Node
#
# Level 3
# Count of 2 = 17
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of 0 = 31
# Count of 1 = 8
# Count of 2 = 15
# Current Entropy is = 0.957319441212
# Splitting on feature 0 with gain ratio 0.2751866966
#
# Level 2
# Count of 0 = 31
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of 1 = 8
# Count of 2 = 15
# Current Entropy is = 0.646090505061
# Splitting on feature 3 with gain ratio 0.136499515765
#
# Level 3
# Count of 1 = 8
# Count of 2 = 1
# Current Entropy is = 0.348832095843
# Splitting on feature 2 with gain ratio 0.0
#
# Level 4
# Count of 1 = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of 2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of 2 = 14
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature"]
    feature_value = tree_dict["best_split_mid_value"]

    #print("Feature:", feature_names[index])
    #print("Feature Value:", feature_value)
    
    if X[index] <= feature_value :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    else :
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])

def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary, level = 0):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key], level + 1)
        else:
            print(key, dictionary[key])


print_dict(tree_dict)
# Out:
# level 0
# class_counts 0 37
# 1 39
# 2 36
# Entropy 1.09805647173
# is_leaf False
# selected_feature 1
# max_info_gain 0.946980474023
# best_split_mid_value 3.1
# num_of_examples 112
# 0 level 1
# class_counts 0 6
# 1 31
# 2 21
# Entropy 0.937354539053
# is_leaf False
# selected_feature 0
# max_info_gain 0.716909207175
# best_split_mid_value 5.05
# num_of_examples 58
# 0 level 2
# class_counts 0 6
# 1 3
# 2 1
# Entropy 0.897945724857
# is_leaf False
# selected_feature 2
# max_info_gain 0.224934057848
# best_split_mid_value 2.3
# num_of_examples 10
# 0 level 3
# class_counts 0 6
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 3
# class_counts 1 3
# 2 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature 3
# max_info_gain 0.0
# best_split_mid_value 1.35
# num_of_examples 4
# 0 level 4
# class_counts 1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts 2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 2
# class_counts 1 28
# 2 20
# Entropy 0.679193265992
# is_leaf False
# selected_feature 3
# max_info_gain 0.205334170586
# best_split_mid_value 1.7
# num_of_examples 48
# 0 level 3
# class_counts 1 28
# 2 3
# Entropy 0.317936780262
# is_leaf False
# selected_feature 2
# max_info_gain 0.0725593734992
# best_split_mid_value 4.85
# num_of_examples 31
# 0 level 4
# class_counts 1 27
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts 1 1
# 2 3
# Entropy 0.562335144619
# is_leaf True
# predict_class 2
# 1 level 3
# class_counts 2 17
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 1
# class_counts 0 31
# 1 8
# 2 15
# Entropy 0.957319441212
# is_leaf False
# selected_feature 0
# max_info_gain 0.2751866966
# best_split_mid_value 5.8
# num_of_examples 54
# 0 level 2
# class_counts 0 31
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 2
# class_counts 1 8
# 2 15
# Entropy 0.646090505061
# is_leaf False
# selected_feature 3
# max_info_gain 0.136499515765
# best_split_mid_value 1.9
# num_of_examples 23
# 0 level 3
# class_counts 1 8
# 2 1
# Entropy 0.348832095843
# is_leaf False
# selected_feature 2
# max_info_gain 0.0
# best_split_mid_value 5.0
# num_of_examples 9
# 0 level 4
# class_counts 1 8
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts 2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 3
# class_counts 2 14
# Entropy 0.0
# is_leaf True
# predict_class 2

# %%
for i in range(len(X)):
    print("Example", i, ":", X[i])
    pred = predict_single(X[i], tree_dict)

    print("\tActual Class:", Y[i])
    print("\tPredicted Class:", pred)
# Out:
# Example 0 : [ 5.1  3.5  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 1 : [ 4.9  3.   1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 2 : [ 4.7  3.2  1.3  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 3 : [ 4.6  3.1  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 4 : [ 5.   3.6  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 5 : [ 5.4  3.9  1.7  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 6 : [ 4.6  3.4  1.4  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 7 : [ 5.   3.4  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 8 : [ 4.4  2.9  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 9 : [ 4.9  3.1  1.5  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 10 : [ 5.4  3.7  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 11 : [ 4.8  3.4  1.6  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 12 : [ 4.8  3.   1.4  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 13 : [ 4.3  3.   1.1  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 14 : [ 5.8  4.   1.2  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 15 : [ 5.7  4.4  1.5  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 16 : [ 5.4  3.9  1.3  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 17 : [ 5.1  3.5  1.4  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 18 : [ 5.7  3.8  1.7  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 19 : [ 5.1  3.8  1.5  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 20 : [ 5.4  3.4  1.7  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 21 : [ 5.1  3.7  1.5  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 22 : [ 4.6  3.6  1.   0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 23 : [ 5.1  3.3  1.7  0.5]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 24 : [ 4.8  3.4  1.9  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 25 : [ 5.   3.   1.6  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 26 : [ 5.   3.4  1.6  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 27 : [ 5.2  3.5  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 28 : [ 5.2  3.4  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 29 : [ 4.7  3.2  1.6  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 30 : [ 4.8  3.1  1.6  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 31 : [ 5.4  3.4  1.5  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 32 : [ 5.2  4.1  1.5  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 33 : [ 5.5  4.2  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 34 : [ 4.9  3.1  1.5  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 35 : [ 5.   3.2  1.2  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 36 : [ 5.5  3.5  1.3  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 37 : [ 4.9  3.1  1.5  0.1]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 38 : [ 4.4  3.   1.3  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 39 : [ 5.1  3.4  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 40 : [ 5.   3.5  1.3  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 41 : [ 4.5  2.3  1.3  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 42 : [ 4.4  3.2  1.3  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 43 : [ 5.   3.5  1.6  0.6]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 44 : [ 5.1  3.8  1.9  0.4]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 45 : [ 4.8  3.   1.4  0.3]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 46 : [ 5.1  3.8  1.6  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 47 : [ 4.6  3.2  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 48 : [ 5.3  3.7  1.5  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 49 : [ 5.   3.3  1.4  0.2]
# 	Actual Class: 0
# 	Predicted Class: 0
# Example 50 : [ 7.   3.2  4.7  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 51 : [ 6.4  3.2  4.5  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 52 : [ 6.9  3.1  4.9  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 53 : [ 5.5  2.3  4.   1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 54 : [ 6.5  2.8  4.6  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 55 : [ 5.7  2.8  4.5  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 56 : [ 6.3  3.3  4.7  1.6]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 57 : [ 4.9  2.4  3.3  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 58 : [ 6.6  2.9  4.6  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 59 : [ 5.2  2.7  3.9  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 60 : [ 5.   2.   3.5  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 61 : [ 5.9  3.   4.2  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 62 : [ 6.   2.2  4.   1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 63 : [ 6.1  2.9  4.7  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 64 : [ 5.6  2.9  3.6  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 65 : [ 6.7  3.1  4.4  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 66 : [ 5.6  3.   4.5  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 67 : [ 5.8  2.7  4.1  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 68 : [ 6.2  2.2  4.5  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 69 : [ 5.6  2.5  3.9  1.1]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 70 : [ 5.9  3.2  4.8  1.8]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 71 : [ 6.1  2.8  4.   1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 72 : [ 6.3  2.5  4.9  1.5]
# 	Actual Class: 1
# 	Predicted Class: 2
# Example 73 : [ 6.1  2.8  4.7  1.2]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 74 : [ 6.4  2.9  4.3  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 75 : [ 6.6  3.   4.4  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 76 : [ 6.8  2.8  4.8  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 77 : [ 6.7  3.   5.   1.7]
# 	Actual Class: 1
# 	Predicted Class: 2
# Example 78 : [ 6.   2.9  4.5  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 79 : [ 5.7  2.6  3.5  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 80 : [ 5.5  2.4  3.8  1.1]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 81 : [ 5.5  2.4  3.7  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 82 : [ 5.8  2.7  3.9  1.2]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 83 : [ 6.   2.7  5.1  1.6]
# 	Actual Class: 1
# 	Predicted Class: 2
# Example 84 : [ 5.4  3.   4.5  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 85 : [ 6.   3.4  4.5  1.6]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 86 : [ 6.7  3.1  4.7  1.5]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 87 : [ 6.3  2.3  4.4  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 88 : [ 5.6  3.   4.1  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 89 : [ 5.5  2.5  4.   1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 90 : [ 5.5  2.6  4.4  1.2]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 91 : [ 6.1  3.   4.6  1.4]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 92 : [ 5.8  2.6  4.   1.2]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 93 : [ 5.   2.3  3.3  1. ]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 94 : [ 5.6  2.7  4.2  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 95 : [ 5.7  3.   4.2  1.2]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 96 : [ 5.7  2.9  4.2  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 97 : [ 6.2  2.9  4.3  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 98 : [ 5.1  2.5  3.   1.1]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 99 : [ 5.7  2.8  4.1  1.3]
# 	Actual Class: 1
# 	Predicted Class: 1
# Example 100 : [ 6.3  3.3  6.   2.5]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 101 : [ 5.8  2.7  5.1  1.9]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 102 : [ 7.1  3.   5.9  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 103 : [ 6.3  2.9  5.6  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 104 : [ 6.5  3.   5.8  2.2]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 105 : [ 7.6  3.   6.6  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 106 : [ 4.9  2.5  4.5  1.7]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 107 : [ 7.3  2.9  6.3  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 108 : [ 6.7  2.5  5.8  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 109 : [ 7.2  3.6  6.1  2.5]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 110 : [ 6.5  3.2  5.1  2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 111 : [ 6.4  2.7  5.3  1.9]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 112 : [ 6.8  3.   5.5  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 113 : [ 5.7  2.5  5.   2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 114 : [ 5.8  2.8  5.1  2.4]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 115 : [ 6.4  3.2  5.3  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 116 : [ 6.5  3.   5.5  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 117 : [ 7.7  3.8  6.7  2.2]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 118 : [ 7.7  2.6  6.9  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 119 : [ 6.   2.2  5.   1.5]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 120 : [ 6.9  3.2  5.7  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 121 : [ 5.6  2.8  4.9  2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 122 : [ 7.7  2.8  6.7  2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 123 : [ 6.3  2.7  4.9  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 124 : [ 6.7  3.3  5.7  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 125 : [ 7.2  3.2  6.   1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 126 : [ 6.2  2.8  4.8  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 127 : [ 6.1  3.   4.9  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 128 : [ 6.4  2.8  5.6  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 129 : [ 7.2  3.   5.8  1.6]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 130 : [ 7.4  2.8  6.1  1.9]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 131 : [ 7.9  3.8  6.4  2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 132 : [ 6.4  2.8  5.6  2.2]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 133 : [ 6.3  2.8  5.1  1.5]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 134 : [ 6.1  2.6  5.6  1.4]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 135 : [ 7.7  3.   6.1  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 136 : [ 6.3  3.4  5.6  2.4]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 137 : [ 6.4  3.1  5.5  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 138 : [ 6.   3.   4.8  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 139 : [ 6.9  3.1  5.4  2.1]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 140 : [ 6.7  3.1  5.6  2.4]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 141 : [ 6.9  3.1  5.1  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 142 : [ 5.8  2.7  5.1  1.9]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 143 : [ 6.8  3.2  5.9  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 144 : [ 6.7  3.3  5.7  2.5]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 145 : [ 6.7  3.   5.2  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 146 : [ 6.3  2.5  5.   1.9]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 147 : [ 6.5  3.   5.2  2. ]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 148 : [ 6.2  3.4  5.4  2.3]
# 	Actual Class: 2
# 	Predicted Class: 2
# Example 149 : [ 5.9  3.   5.1  1.8]
# 	Actual Class: 2
# 	Predicted Class: 2

# %%
import matplotlib.pyplot as plt

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.scatter(indices, Y_train_pred, color = "r")
plt.scatter(indices, Y_train, color = "b")
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.scatter(indices, Y_test_pred, color = "r")
plt.scatter(indices, Y_test, color = "b")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[37  0  0]
#  [ 0 38  1]
#  [ 0  0 36]]
# Confusion Matrix for Y_test
#  [[13  0  0]
#  [ 0  9  2]
#  [ 0  0 14]]
