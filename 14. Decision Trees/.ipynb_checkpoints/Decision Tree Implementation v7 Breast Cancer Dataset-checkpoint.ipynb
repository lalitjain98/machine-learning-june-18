# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
"""
Load the Dataset

"""
dataset = datasets.load_wine()


X = dataset.data
Y = dataset.target

feature_names = dataset.feature_names

class_names = dataset.target_names

class_dict = {i : class_names[i] for i in range(len(class_names))}

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

print(class_dict)
# Out:
# {0: 'class_0', 1: 'class_1', 2: 'class_2'}

# %%
import pandas as pd
df = pd.DataFrame(X)
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean    13.000618    2.336348    2.366517   19.494944   99.741573    2.295112
# std      0.811827    1.117146    0.274344    3.339564   14.282484    0.625851
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.362500    1.602500    2.210000   17.200000   88.000000    1.742500
# 50%     13.050000    1.865000    2.360000   19.500000   98.000000    2.355000
# 75%     13.677500    3.082500    2.557500   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#                6           7           8           9           10          11  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     2.029270    0.361854    1.590899    5.058090    0.957449    2.611685
# std      0.998859    0.124453    0.572359    2.318286    0.228572    0.709990
# min      0.340000    0.130000    0.410000    1.280000    0.480000    1.270000
# 25%      1.205000    0.270000    1.250000    3.220000    0.782500    1.937500
# 50%      2.135000    0.340000    1.555000    4.690000    0.965000    2.780000
# 75%      2.875000    0.437500    1.950000    6.200000    1.120000    3.170000
# max      5.080000    0.660000    3.580000   13.000000    1.710000    4.000000
#
#                 12
# count   178.000000
# mean    746.893258
# std     314.907474
# min     278.000000
# 25%     500.500000
# 50%     673.500000
# 75%     985.000000
# max    1680.000000

# %%
"""
Entropy function takes as input, list of labels Y and a list of all possible classes 
It returns the entropy of the current data subset.
"""

def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

"""
info_gain_for_split return inforamation gain of the current split of Y with list of integers splits
ith value of list splits means the ith Y value belongs to that split

lengths of Y and splits are equal

e.g. say Y = 1.2 4.5 3.2 2.3
    splits = 0 1 0 1 
    then 1.2 and 3.2 belong to same group, 4.5 and  2.3 belong to same group
"""

def info_gain_split_info_for_split(Y, splits):
    
    #initialize info_gain and split_info values
    info_gain = 0
    split_info = 0    
    
    # mod_Y is number of examples
    mod_Y = len(Y)
    
    # unique splits are number of groups in which data is divided
    unique_splits = list(set(splits))
    
    
    for s in unique_splits:
        
        # find indices of examples in group s
        indices = (splits == s)
        Y_split_i = Y[indices]
                
        #number of examples in current group s
        mod_Y_i = len(Y_split_i)
        
        """
                                           |Yi|
         ratio_mod_Y_i_to_mod_Y, ratio =   ----
                                           |Y|
        """
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        
        # list of all possible classes in group s
        possible_classes_Y_i = list(set(Y_split_i))
        
        # update info gain and split info values
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    
    return info_gain, split_info

"""
Considering input data to be continious, split method takes as input X - the data, Y - the labels, 
and feature index on which to split the data

1. find the set of unique values of feature f and sort it
2. build list of mid values ie mean of each pair of adjacent values
3. for each mid value
    3.1 split data into two parts
    3.2 find information gain
    3.3 keep the best split
returns min_info_gain: information gain for best split
        min_split_info : split info for best split
        best_split_labels : list of labels for each example
        mid_value_for_min_info_gain : the mid value for which best split on feature f was made
"""


def split(X, Y, feature):
    # find the set of unique values of feature f and sort it
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    pvcf.sort()
    
    
    # build list of mid values ie mean of each pair of adjacent values
    mid_values = []
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    
    # initialize variables
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = np.array([])
    
    # iterate over list of mid values
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        
        # splitting data into two parts, one group belongs to split 0 and other to split 1
        current_split_labels[ X[:, feature] <= value ] = 0
        
        # find information gain and split info for current split
        current_split_information_gain, current_split_split_info = info_gain_split_info_for_split(Y, current_split_labels)
        
        # keep the best split
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain

"""
decision_tree:
    Input:
        X : list of examples
        Y : list of labels
        features : list of indices of features; after each split, one element is removed from this list
        feature_names: list of feature names
        class_dict : dictionary of possible classes indices mapped to class names
        level : level in recursion tree (only used for printing steps)
    
    
    
    Output:
        dictionary of nodes where each node is a decision node used for prediction
"""
    
def decision_tree(X, Y, features, feature_names, class_dict, level):
    # current decision node dictionary
    node = {}
    
    #
    node["level"] = level
    
    # dictionary of classes mapped to respective counts in Y
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    
    # max_class is majority class, max_count is count of majority class
    max_count = -np.inf
    max_class = possible_classes[0]
    
    # add key value pairs of classes and their counts in class_counts dictionary
    # also find the majority class 
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[class_dict[y]] = count_y
        print("Count of", class_dict[y], "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    
    # find current entropy
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    # add the class_counts dictionary to node dictionary
    node['class_counts'] = class_counts
    
    # add entropy value to node dictionary
    node["Entropy"] = current_entropy
    
    """
    check for base case, ie either all the examples are marked with a single class
    or
    there is no more feature to split current data
    
    mark this decision node as leaf node
    add the value of predict class to this node
    
    return the node
    """
    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        node["predict_class"] = max_class
        return node
    
    """
    else
    this node is NOT a leaf node and splitting can be done
    
    """
    node["is_leaf"] = False
    
    """ initialize few variables
    
    selected_feature : index of selected feature to make split on
    
    max_info_gain : information gain on splitting using the selected_feature
    
    max_split_info : split info on splitting using the selected_feature
    
    best_split_labels : labels assigned to examples
    
    best_split_mid_value : mid value of selected feature to use for prediction
    
    """
    selected_feature = None
    max_info_gain = -np.inf
    max_split_info = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    
    # iterate over all available features
    for f in features:
        
        # find info gain
        # split info
        # current split labels for best split on curent feature 
        # mid value for current feature
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        # keep feature that gives maximum gain
        if info_gain > max_info_gain and info_gain < np.inf:
            selected_feature = f
            max_info_gain = info_gain
            max_split_info = split_info
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f

    """
    add index, name of selected feature 
    information gain
    mid value of selected feature
    number of examples at current decision
    to node dictionary
    """
    node["selected_feature"] = feature_names[selected_feature]
    node["selected_feature_index"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    node["num_of_examples"] = len(Y)
    
    if max_split_info != 0 :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio", max_info_gain/max_split_info)
    else :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio inf")
    #splits = split(X, Y, selected_feature)
    
    # find list of groups in which current dataset is divided
    unique_splits = list(set(best_split_labels))
    
    # remove index of selected feature
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    """
    recursively call decision tree on 'split' datasets
    """
    for s in unique_splits:
        # find indices of examples that belong to split s
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        # store the output dictionaries of child splits in current node dictionary
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, class_dict, level + 1)
    """
    return the "decision tree" (dictionary)
    """
    return node

features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, class_dict, level = 0)
# Out:
# Level 0
# Count of class_0 = 44
# Count of class_1 = 51
# Count of class_2 = 38
# Current Entropy is = 1.09143390092
# Splitting on feature 'ash' with gain ratio 1.73235276056
#
# Level 1
# Count of class_0 = 5
# Count of class_1 = 26
# Count of class_2 = 3
# Current Entropy is = 0.701256512359
# Splitting on feature 'malic_acid' with gain ratio 0.932051013341
#
# Level 2
# Count of class_1 = 12
# Count of class_2 = 1
# Current Entropy is = 0.271189373042
# Splitting on feature 'alcohol' with gain ratio 0.30129765713
#
# Level 3
# Count of class_1 = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_1 = 5
# Count of class_2 = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'proanthocyanins' with gain ratio 0.459147917027
#
# Level 4
# Count of class_1 = 2
# Count of class_2 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'total_phenols' with gain ratio 0.725982457879
#
# Level 5
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.0
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of class_0 = 5
# Count of class_1 = 14
# Count of class_2 = 2
# Current Entropy is = 0.83593736449
# Splitting on feature 'magnesium' with gain ratio 0.987417402348
#
# Level 3
# Count of class_1 = 8
# Count of class_2 = 1
# Current Entropy is = 0.348832095843
# Splitting on feature 'proline' with gain ratio 0.404682526477
#
# Level 4
# Count of class_1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_1 = 4
# Count of class_2 = 1
# Current Entropy is = 0.500402423538
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.411967408316
#
# Level 5
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_0 = 5
# Count of class_1 = 6
# Count of class_2 = 1
# Current Entropy is = 0.918427784993
# Splitting on feature 'proanthocyanins' with gain ratio 1.5384084713
#
# Level 4
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 5
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 5
# Count of class_1 = 5
# Current Entropy is = 0.69314718056
# Splitting on feature 'hue' with gain ratio 1.0576499346
#
# Level 5
# Count of class_1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 5
# Count of class_1 = 3
# Current Entropy is = 0.661563238158
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.924467180105
#
# Level 6
# Count of class_0 = 3
# Count of class_1 = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'total_phenols' with gain ratio 0.588973686818
#
# Level 7
# Count of class_1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 3
# Count of class_1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 8
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of class_0 = 39
# Count of class_1 = 25
# Count of class_2 = 35
# Current Entropy is = 1.08210993122
# Splitting on feature 'magnesium' with gain ratio 1.82238358443
#
# Level 2
# Count of class_1 = 12
# Count of class_2 = 9
# Current Entropy is = 0.6829081047
# Splitting on feature 'total_phenols' with gain ratio 3.3480454754
#
# Level 3
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_1 = 12
# Count of class_2 = 8
# Current Entropy is = 0.673011667009
# Splitting on feature 'nonflavanoid_phenols' with gain ratio 3.14940292558
#
# Level 4
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_1 = 12
# Count of class_2 = 7
# Current Entropy is = 0.658109987543
# Splitting on feature 'proline' with gain ratio 1.61080586999
#
# Level 5
# Count of class_1 = 12
# Count of class_2 = 5
# Current Entropy is = 0.605797499372
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.697308686596
#
# Level 6
# Count of class_1 = 3
# Count of class_2 = 4
# Current Entropy is = 0.6829081047
# Splitting on feature 'alcohol' with gain ratio 0.803521737465
#
# Level 7
# Count of class_1 = 3
# Count of class_2 = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'malic_acid' with gain ratio 0.899012663676
#
# Level 8
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_1 = 3
# Count of class_2 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'flavanoids' with gain ratio 0.0
#
# Level 9
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_1 = 9
# Count of class_2 = 1
# Current Entropy is = 0.325082973391
# Splitting on feature 'malic_acid' with gain ratio 0.40168207859
#
# Level 7
# Count of class_1 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_1 = 5
# Count of class_2 = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 8
# Count of class_1 = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of class_0 = 39
# Count of class_1 = 13
# Count of class_2 = 26
# Current Entropy is = 1.01140426471
# Splitting on feature 'nonflavanoid_phenols' with gain ratio 1.24230417723
#
# Level 3
# Count of class_0 = 34
# Count of class_1 = 8
# Count of class_2 = 6
# Current Entropy is = 0.802818782038
# Splitting on feature 'malic_acid' with gain ratio 1.02337913377
#
# Level 4
# Count of class_0 = 27
# Count of class_1 = 6
# Current Entropy is = 0.474139313058
# Splitting on feature 'proanthocyanins' with gain ratio 1.99900521479
#
# Level 5
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 26
# Count of class_1 = 5
# Current Entropy is = 0.44180334801
# Splitting on feature 'hue' with gain ratio 0.704418282059
#
# Level 6
# Count of class_0 = 4
# Count of class_1 = 3
# Current Entropy is = 0.6829081047
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.470538226361
#
# Level 7
# Count of class_0 = 1
# Count of class_1 = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 8
# Count of class_1 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 22
# Count of class_1 = 2
# Current Entropy is = 0.286835983056
# Splitting on feature 'total_phenols' with gain ratio 0.792301969447
#
# Level 7
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 8
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 21
# Count of class_1 = 1
# Current Entropy is = 0.184907399168
# Splitting on feature 'od280/od315_of_diluted_wines' with gain ratio 0.209017758878
#
# Level 8
# Count of class_0 = 14
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 7
# Count of class_1 = 1
# Current Entropy is = 0.376770161256
# Splitting on feature 'flavanoids' with gain ratio 0.40563906223
#
# Level 9
# Count of class_0 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_0 = 3
# Count of class_1 = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'proline' with gain ratio 0.5
#
# Level 10
# Count of class_0 = 1
# Count of class_1 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'alcohol' with gain ratio 0.0
#
# Level 11
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of class_0 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 7
# Count of class_1 = 2
# Count of class_2 = 6
# Current Entropy is = 0.990835386444
# Splitting on feature 'color_intensity' with gain ratio 1.52329975371
#
# Level 5
# Count of class_1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 7
# Count of class_2 = 6
# Current Entropy is = 0.690185676019
# Splitting on feature 'alcohol' with gain ratio 0.594126474025
#
# Level 6
# Count of class_2 = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 7
# Count of class_2 = 2
# Current Entropy is = 0.529706199058
# Splitting on feature 'proanthocyanins' with gain ratio 0.333333333333
#
# Level 7
# Count of class_0 = 1
# Count of class_2 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.0
#
# Level 8
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_2 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of class_0 = 5
# Count of class_1 = 5
# Count of class_2 = 20
# Current Entropy is = 0.867563228481
# Splitting on feature 'proanthocyanins' with gain ratio 1.20696799965
#
# Level 4
# Count of class_0 = 1
# Count of class_1 = 3
# Count of class_2 = 18
# Current Entropy is = 0.576382066625
# Splitting on feature 'alcohol' with gain ratio 1.10573154189
#
# Level 5
# Count of class_1 = 2
# Count of class_2 = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.725982457879
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_1 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'malic_acid' with gain ratio 0.0
#
# Level 7
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 1
# Count of class_1 = 1
# Count of class_2 = 17
# Current Entropy is = 0.409458618695
# Splitting on feature 'color_intensity' with gain ratio 0.985811855683
#
# Level 6
# Count of class_1 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Count of class_2 = 17
# Current Entropy is = 0.214559155176
# Splitting on feature 'alcalinity_of_ash' with gain ratio 0.22078344944
#
# Level 7
# Count of class_0 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'malic_acid' with gain ratio 0.0
#
# Level 8
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_2 = 16
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of class_0 = 4
# Count of class_1 = 2
# Count of class_2 = 2
# Current Entropy is = 1.03972077084
# Splitting on feature 'total_phenols' with gain ratio 1.46524581361
#
# Level 5
# Count of class_0 = 2
# Count of class_1 = 2
# Count of class_2 = 2
# Current Entropy is = 1.09861228867
# Splitting on feature 'alcalinity_of_ash' with gain ratio 1.95112256157
#
# Level 6
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of class_0 = 1
# Count of class_1 = 2
# Count of class_2 = 2
# Current Entropy is = 1.05492016799
# Splitting on feature 'alcohol' with gain ratio 0.567461932234
#
# Level 7
# Count of class_1 = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of class_0 = 1
# Count of class_2 = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'malic_acid' with gain ratio 0.725982457879
#
# Level 8
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of class_0 = 1
# Count of class_2 = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'flavanoids' with gain ratio 0.0
#
# Level 9
# Count of class_2 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of class_0 = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of class_0 = 2
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature_index"]
    feature_value = tree_dict["best_split_mid_value"]

    if X[index] <= feature_value and 0 in tree_dict.keys() :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    elif 1 in tree_dict.keys():
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])
    elif 0 in tree_dict.keys():
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[0])
    else:
        print(tree_dict)
        class_counts = tree_dict["class_counts"]
        max_count = -1
        max_class = 0
        for k, v in class_counts.items() :
            if v >max_count :
                max_class = k
                max_count = v
        return max_class
def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key])
        else:
            print(key, dictionary[key])

# %%
print_dict(tree_dict)
# Out:
# level 0
# class_counts class_0 44
# class_1 51
# class_2 38
# Entropy 1.09143390092
# is_leaf False
# selected_feature ash
# selected_feature_index 2
# max_info_gain 0.984748906847
# best_split_mid_value 2.245
# num_of_examples 133
# 0 level 1
# class_counts class_0 5
# class_1 26
# class_2 3
# Entropy 0.701256512359
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.620004308936
# best_split_mid_value 1.455
# num_of_examples 34
# 0 level 2
# class_counts class_1 12
# class_2 1
# Entropy 0.271189373042
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.207951327169
# best_split_mid_value 12.475
# num_of_examples 13
# 0 level 3
# class_counts class_1 7
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 3
# class_counts class_1 5
# class_2 1
# Entropy 0.450561208866
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.318257084147
# best_split_mid_value 1.43
# num_of_examples 6
# 0 level 4
# class_counts class_1 2
# class_2 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.462098120373
# best_split_mid_value 1.465
# num_of_examples 3
# 0 level 5
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 18.4
# num_of_examples 2
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 4
# class_counts class_1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 2
# class_counts class_0 5
# class_1 14
# class_2 2
# Entropy 0.83593736449
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.674315346786
# best_split_mid_value 89.0
# num_of_examples 21
# 0 level 3
# class_counts class_1 8
# class_2 1
# Entropy 0.348832095843
# is_leaf False
# selected_feature proline
# selected_feature_index 12
# max_info_gain 0.27800134641
# best_split_mid_value 410.5
# num_of_examples 9
# 0 level 4
# class_counts class_1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 4
# class_counts class_1 4
# class_2 1
# Entropy 0.500402423538
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.277258872224
# best_split_mid_value 19.5
# num_of_examples 5
# 0 level 5
# class_counts class_1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.685
# num_of_examples 2
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 3
# class_counts class_0 5
# class_1 6
# class_2 1
# Entropy 0.918427784993
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.69314718056
# best_split_mid_value 1.335
# num_of_examples 12
# 0 level 4
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.5
# num_of_examples 2
# 0 level 5
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 4
# class_counts class_0 5
# class_1 5
# Entropy 0.69314718056
# is_leaf False
# selected_feature hue
# selected_feature_index 10
# max_info_gain 0.529250590526
# best_split_mid_value 0.908
# num_of_examples 10
# 0 level 5
# class_counts class_1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts class_0 5
# class_1 3
# Entropy 0.661563238158
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.51986038542
# best_split_mid_value 2.98
# num_of_examples 8
# 0 level 6
# class_counts class_0 3
# class_1 3
# Entropy 0.69314718056
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.374890096413
# best_split_mid_value 2.315
# num_of_examples 6
# 0 level 7
# class_counts class_1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts class_0 3
# class_1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.76
# num_of_examples 4
# 0 level 8
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts class_0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts class_0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 1
# class_counts class_0 39
# class_1 25
# class_2 35
# Entropy 1.08210993122
# is_leaf False
# selected_feature magnesium
# selected_feature_index 4
# max_info_gain 0.94172326107
# best_split_mid_value 90.5
# num_of_examples 99
# 0 level 2
# class_counts class_1 12
# class_2 9
# Entropy 0.6829081047
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.64096349239
# best_split_mid_value 1.33
# num_of_examples 21
# 0 level 3
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 3
# class_counts class_1 12
# class_2 8
# Entropy 0.673011667009
# is_leaf False
# selected_feature nonflavanoid_phenols
# selected_feature_index 7
# max_info_gain 0.625204488166
# best_split_mid_value 0.38
# num_of_examples 20
# 0 level 4
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 4
# class_counts class_1 12
# class_2 7
# Entropy 0.658109987543
# is_leaf False
# selected_feature proline
# selected_feature_index 12
# max_info_gain 0.542029341544
# best_split_mid_value 682.5
# num_of_examples 19
# 0 level 5
# class_counts class_1 12
# class_2 5
# Entropy 0.605797499372
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.472422733342
# best_split_mid_value 21.55
# num_of_examples 17
# 0 level 6
# class_counts class_1 3
# class_2 4
# Entropy 0.6829081047
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.480722619292
# best_split_mid_value 12.78
# num_of_examples 7
# 0 level 7
# class_counts class_1 3
# class_2 2
# Entropy 0.673011667009
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.449868115695
# best_split_mid_value 1.385
# num_of_examples 5
# 0 level 8
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 8
# class_counts class_1 3
# class_2 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.0
# best_split_mid_value 1.19
# num_of_examples 4
# 0 level 9
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 9
# class_counts class_1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts class_2 2
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 6
# class_counts class_1 9
# class_2 1
# Entropy 0.325082973391
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.27033672532
# best_split_mid_value 1.59
# num_of_examples 10
# 0 level 7
# class_counts class_1 4
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts class_1 5
# class_2 1
# Entropy 0.450561208866
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.1
# num_of_examples 6
# 0 level 8
# class_counts class_1 5
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 5
# class_counts class_2 2
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 2
# class_counts class_0 39
# class_1 13
# class_2 26
# Entropy 1.01140426471
# is_leaf False
# selected_feature nonflavanoid_phenols
# selected_feature_index 7
# max_info_gain 0.827720492209
# best_split_mid_value 0.38
# num_of_examples 78
# 0 level 3
# class_counts class_0 34
# class_1 8
# class_2 6
# Entropy 0.802818782038
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.635606835991
# best_split_mid_value 2.235
# num_of_examples 48
# 0 level 4
# class_counts class_0 27
# class_1 6
# Entropy 0.474139313058
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.457036307558
# best_split_mid_value 1.395
# num_of_examples 33
# 0 level 5
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.84
# num_of_examples 2
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 5
# class_counts class_0 26
# class_1 5
# Entropy 0.44180334801
# is_leaf False
# selected_feature hue
# selected_feature_index 10
# max_info_gain 0.376271623427
# best_split_mid_value 0.97
# num_of_examples 31
# 0 level 6
# class_counts class_0 4
# class_1 3
# Entropy 0.6829081047
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.321334368354
# best_split_mid_value 3.285
# num_of_examples 7
# 0 level 7
# class_counts class_0 1
# class_1 3
# Entropy 0.562335144619
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.78
# num_of_examples 4
# 0 level 8
# class_counts class_1 3
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts class_0 3
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts class_0 22
# class_1 2
# Entropy 0.286835983056
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.227260714284
# best_split_mid_value 2.435
# num_of_examples 24
# 0 level 7
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.245
# num_of_examples 2
# 0 level 8
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 8
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 7
# class_counts class_0 21
# class_1 1
# Entropy 0.184907399168
# is_leaf False
# selected_feature od280/od315_of_diluted_wines
# selected_feature_index 11
# max_info_gain 0.137007331366
# best_split_mid_value 3.485
# num_of_examples 22
# 0 level 8
# class_counts class_0 14
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts class_0 7
# class_1 1
# Entropy 0.376770161256
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.281167572309
# best_split_mid_value 2.885
# num_of_examples 8
# 0 level 9
# class_counts class_0 4
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 9
# class_counts class_0 3
# class_1 1
# Entropy 0.562335144619
# is_leaf False
# selected_feature proline
# selected_feature_index 12
# max_info_gain 0.34657359028
# best_split_mid_value 1015.0
# num_of_examples 4
# 0 level 10
# class_counts class_0 1
# class_1 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.525
# num_of_examples 2
# 0 level 11
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 11
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 10
# class_counts class_0 2
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 4
# class_counts class_0 7
# class_1 2
# class_2 6
# Entropy 0.990835386444
# is_leaf False
# selected_feature color_intensity
# selected_feature_index 9
# max_info_gain 0.598160919216
# best_split_mid_value 3.805
# num_of_examples 15
# 0 level 5
# class_counts class_1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 5
# class_counts class_0 7
# class_2 6
# Entropy 0.690185676019
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.366719676271
# best_split_mid_value 12.905
# num_of_examples 13
# 0 level 6
# class_counts class_2 4
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 6
# class_counts class_0 7
# class_2 2
# Entropy 0.529706199058
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.212171389432
# best_split_mid_value 1.455
# num_of_examples 9
# 0 level 7
# class_counts class_0 1
# class_2 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 21.45
# num_of_examples 3
# 0 level 8
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts class_2 2
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 7
# class_counts class_0 6
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 3
# class_counts class_0 5
# class_1 5
# class_2 20
# Entropy 0.867563228481
# is_leaf False
# selected_feature proanthocyanins
# selected_feature_index 8
# max_info_gain 0.699939054416
# best_split_mid_value 1.615
# num_of_examples 30
# 0 level 4
# class_counts class_0 1
# class_1 3
# class_2 18
# Entropy 0.576382066625
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.440420739095
# best_split_mid_value 12.43
# num_of_examples 22
# 0 level 5
# class_counts class_1 2
# class_2 1
# Entropy 0.636514168295
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.462098120373
# best_split_mid_value 17.5
# num_of_examples 3
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts class_1 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 2.855
# num_of_examples 2
# 0 level 7
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 5
# class_counts class_0 1
# class_1 1
# class_2 17
# Entropy 0.409458618695
# is_leaf False
# selected_feature color_intensity
# selected_feature_index 9
# max_info_gain 0.203266568062
# best_split_mid_value 3.76
# num_of_examples 19
# 0 level 6
# class_counts class_1 1
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 6
# class_counts class_0 1
# class_2 17
# Entropy 0.214559155176
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.0770163533955
# best_split_mid_value 19.75
# num_of_examples 18
# 0 level 7
# class_counts class_0 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 2.49
# num_of_examples 2
# 0 level 8
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 8
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 7
# class_counts class_2 16
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 4
# class_counts class_0 4
# class_1 2
# class_2 2
# Entropy 1.03972077084
# is_leaf False
# selected_feature total_phenols
# selected_feature_index 5
# max_info_gain 0.823959216501
# best_split_mid_value 2.915
# num_of_examples 8
# 0 level 5
# class_counts class_0 2
# class_1 2
# class_2 2
# Entropy 1.09861228867
# is_leaf False
# selected_feature alcalinity_of_ash
# selected_feature_index 3
# max_info_gain 0.879100139988
# best_split_mid_value 17.85
# num_of_examples 6
# 0 level 6
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 6
# class_counts class_0 1
# class_1 2
# class_2 2
# Entropy 1.05492016799
# is_leaf False
# selected_feature alcohol
# selected_feature_index 0
# max_info_gain 0.381908500977
# best_split_mid_value 12.875
# num_of_examples 5
# 0 level 7
# class_counts class_1 2
# Entropy 0.0
# is_leaf True
# predict_class 1
# 1 level 7
# class_counts class_0 1
# class_2 2
# Entropy 0.636514168295
# is_leaf False
# selected_feature malic_acid
# selected_feature_index 1
# max_info_gain 0.462098120373
# best_split_mid_value 1.865
# num_of_examples 3
# 0 level 8
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 8
# class_counts class_0 1
# class_2 1
# Entropy 0.69314718056
# is_leaf False
# selected_feature flavanoids
# selected_feature_index 6
# max_info_gain 0.0
# best_split_mid_value 1.755
# num_of_examples 2
# 0 level 9
# class_counts class_2 1
# Entropy 0.0
# is_leaf True
# predict_class 2
# 1 level 9
# class_counts class_0 1
# Entropy 0.0
# is_leaf True
# predict_class 0
# 1 level 5
# class_counts class_0 2
# Entropy 0.0
# is_leaf True
# predict_class 0

# %%
for i in range(len(X)):
    print("Example", i)
    pred = predict_single(X[i], tree_dict)

    #print("\tActual Class:", class_dict[Y[i]])
    #print("\tPredicted Class:", class_dict[pred])
# Out:
# Example 0
# Example 1
# Example 2
# Example 3
# Example 4
# Example 5
# Example 6
# Example 7
# Example 8
# Example 9
# Example 10
# Example 11
# Example 12
# Example 13
# Example 14
# Example 15
# Example 16
# Example 17
# Example 18
# Example 19
# Example 20
# Example 21
# Example 22
# Example 23
# Example 24
# Example 25
# Example 26
# Example 27
# Example 28
# Example 29
# Example 30
# Example 31
# Example 32
# Example 33
# Example 34
# Example 35
# Example 36
# Example 37
# Example 38
# Example 39
# Example 40
# Example 41
# Example 42
# Example 43
# Example 44
# Example 45
# Example 46
# Example 47
# Example 48
# Example 49
# Example 50
# Example 51
# Example 52
# Example 53
# Example 54
# Example 55
# Example 56
# Example 57
# Example 58
# Example 59
# Example 60
# Example 61
# Example 62
# Example 63
# Example 64
# Example 65
# Example 66
# Example 67
# Example 68
# Example 69
# Example 70
# Example 71
# Example 72
# Example 73
# Example 74
# Example 75
# Example 76
# Example 77
# Example 78
# Example 79
# Example 80
# Example 81
# Example 82
# Example 83
# Example 84
# Example 85
# Example 86
# Example 87
# Example 88
# Example 89
# Example 90
# Example 91
# Example 92
# Example 93
# Example 94
# Example 95
# Example 96
# Example 97
# Example 98
# Example 99
# Example 100
# Example 101
# Example 102
# Example 103
# Example 104
# Example 105
# Example 106
# Example 107
# Example 108
# Example 109
# Example 110
# Example 111
# Example 112
# Example 113
# Example 114
# Example 115
# Example 116
# Example 117
# Example 118
# Example 119
# Example 120
# Example 121
# Example 122
# Example 123
# Example 124
# Example 125
# Example 126
# Example 127
# Example 128
# Example 129
# Example 130
# Example 131
# Example 132
# Example 133
# Example 134
# Example 135
# Example 136
# Example 137
# Example 138
# Example 139
# Example 140
# Example 141
# Example 142
# Example 143
# Example 144
# Example 145
# Example 146
# Example 147
# Example 148
# Example 149
# Example 150
# Example 151
# Example 152
# Example 153
# Example 154
# Example 155
# Example 156
# Example 157
# Example 158
# Example 159
# Example 160
# Example 161
# Example 162
# Example 163
# Example 164
# Example 165
# Example 166
# Example 167
# Example 168
# Example 169
# Example 170
# Example 171
# Example 172
# Example 173
# Example 174
# Example 175
# Example 176
# Example 177

# %%
import matplotlib.pyplot as plt

def get_lines(indices, Y_pred, Y):
    lines = []
    for i in indices :
        if Y_pred[i] != Y[i] :
            line = [[i, i], [Y_pred[i], Y[i]]]
            lines.append(line)
    return lines

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_train), -1, len(class_dict)))
plt.scatter(indices, Y_train_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_train, c = Y_train)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_train_pred, Y_train)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
    
plt.legend()
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_test), -1, len(class_dict)))
plt.scatter(indices, Y_test_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_test, c = Y_test)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_test_pred, Y_test)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[44  0  0]
#  [ 0 51  0]
#  [ 0  0 38]]
# Confusion Matrix for Y_test
#  [[12  1  2]
#  [ 2 15  3]
#  [ 2  2  6]]
