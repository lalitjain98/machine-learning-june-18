# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
"""
Load the Dataset

"""
dataset = datasets.load_breast_cancer()


X = dataset.data
Y = dataset.target

feature_names = dataset.feature_names


class_names = dataset.target_names

class_dict = {i : class_names[i] for i in range(len(class_names))}

print(dataset.DESCR)
# Out:
# Breast Cancer Wisconsin (Diagnostic) Database
# =============================================
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# References
# ----------
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
"""
Split Dataset into Training and Testing sets
"""
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 1)


print("Class Dictionary", class_dict)
# Out:
# Class Dictionary {0: 'malignant', 1: 'benign'}

# %%
import pandas as pd
df = pd.DataFrame(X)
df.describe()
# Out:
#                0           1           2            3           4   \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                5           6           7           8           9      ...      \
# count  569.000000  569.000000  569.000000  569.000000  569.000000     ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798     ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060     ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960     ...
# 25%      0.064920    0.029560    0.020310    0.161900    0.057700     ...
# 50%      0.092630    0.061540    0.033500    0.179200    0.061540     ...
# 75%      0.130400    0.130700    0.074000    0.195700    0.066120     ...
# max      0.345400    0.426800    0.201200    0.304000    0.097440     ...
#
#                20          21          22           23          24  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    16.269190   25.677223  107.261213   880.583128    0.132369
# std      4.833242    6.146258   33.602542   569.356993    0.022832
# min      7.930000   12.020000   50.410000   185.200000    0.071170
# 25%     13.010000   21.080000   84.110000   515.300000    0.116600
# 50%     14.970000   25.410000   97.660000   686.500000    0.131300
# 75%     18.790000   29.720000  125.400000  1084.000000    0.146000
# max     36.040000   49.540000  251.200000  4254.000000    0.222600
#
#                25          26          27          28          29
# count  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.254265    0.272188    0.114606    0.290076    0.083946
# std      0.157336    0.208624    0.065732    0.061867    0.018061
# min      0.027290    0.000000    0.000000    0.156500    0.055040
# 25%      0.147200    0.114500    0.064930    0.250400    0.071460
# 50%      0.211900    0.226700    0.099930    0.282200    0.080040
# 75%      0.339100    0.382900    0.161400    0.317900    0.092080
# max      1.058000    1.252000    0.291000    0.663800    0.207500
#
# [8 rows x 30 columns]

# %%
"""
Entropy function takes as input, list of labels Y and a list of all possible classes 
It returns the entropy of the current data subset.
"""

def entropy(Y, possible_classes):
    entropy = 0
    total_count = len(Y)
    for y in possible_classes :
        count_y = (Y == y).sum()
        p_i = count_y/total_count
        entropy -=  p_i * np.log(p_i)
    return entropy

"""
info_gain_for_split return inforamation gain of the current split of Y with list of integers splits
ith value of list splits means the ith Y value belongs to that split

lengths of Y and splits are equal

e.g. say Y = 1.2 4.5 3.2 2.3
    splits = 0 1 0 1 
    then 1.2 and 3.2 belong to same group, 4.5 and  2.3 belong to same group
"""

def info_gain_split_info_for_split(Y, splits):
    
    #initialize info_gain and split_info values
    info_gain = 0
    split_info = 0    
    
    # mod_Y is number of examples
    mod_Y = len(Y)
    
    # unique splits are number of groups in which data is divided
    unique_splits = list(set(splits))
    
    
    for s in unique_splits:
        
        # find indices of examples in group s
        indices = (splits == s)
        Y_split_i = Y[indices]
                
        #number of examples in current group s
        mod_Y_i = len(Y_split_i)
        
        """
                                           |Yi|
         ratio_mod_Y_i_to_mod_Y, ratio =   ----
                                           |Y|
        """
        ratio_mod_Y_i_to_mod_Y = (mod_Y_i/mod_Y)
        
        # list of all possible classes in group s
        possible_classes_Y_i = list(set(Y_split_i))
        
        # update info gain and split info values
        info_gain += ((ratio_mod_Y_i_to_mod_Y) * entropy( Y_split_i, possible_classes_Y_i))
        split_info -= (ratio_mod_Y_i_to_mod_Y * np.log(ratio_mod_Y_i_to_mod_Y))
    
    return info_gain, split_info

"""
Considering input data to be continious, split method takes as input X - the data, Y - the labels, 
and feature index on which to split the data

1. find the set of unique values of feature f and sort it
2. build list of mid values ie mean of each pair of adjacent values
3. for each mid value
    3.1 split data into two parts
    3.2 find information gain
    3.3 keep the best split
returns min_info_gain: information gain for best split
        min_split_info : split info for best split
        best_split_labels : list of labels for each example
        mid_value_for_min_info_gain : the mid value for which best split on feature f was made
"""


def split(X, Y, feature):
    # find the set of unique values of feature f and sort it
    possible_values_current_feature = list(set( X[:, feature] ))
    pvcf = possible_values_current_feature
    pvcf.sort()
    
    
    # build list of mid values ie mean of each pair of adjacent values
    mid_values = []
    for i in range(len(possible_values_current_feature) -1 ):
        mid_values.append((pvcf[i] + pvcf[i+1])/2)
    
    # initialize variables
    min_info_gain = np.inf
    mid_value_for_min_info_gain = 0
    min_split_info = 0
    best_split_labels = np.array([])
    
    # iterate over list of mid values
    for value in mid_values:
        current_split_labels = np.ones(len(Y))
        
        # splitting data into two parts, one group belongs to split 0 and other to split 1
        current_split_labels[ X[:, feature] <= value ] = 0
        
        # find information gain and split info for current split
        current_split_information_gain, current_split_split_info = info_gain_split_info_for_split(Y, current_split_labels)
        
        # keep the best split
        if current_split_information_gain < min_info_gain :
            min_info_gain = current_split_information_gain
            mid_value_for_min_info_gain = value
            min_split_info = current_split_split_info
            best_split_labels = current_split_labels
    
    return min_info_gain, min_split_info, best_split_labels.astype(int), mid_value_for_min_info_gain

"""
decision_tree:
    Input:
        X : list of examples
        Y : list of labels
        features : list of indices of features; after each split, one element is removed from this list
        feature_names: list of feature names
        class_dict : dictionary of possible classes indices mapped to class names
        level : level in recursion tree (only used for printing steps)
    
    
    
    Output:
        dictionary of nodes where each node is a decision node used for prediction
"""
    
def decision_tree(X, Y, features, feature_names, class_dict, level):
    # current decision node dictionary
    node = {}
    
    #
    node["level"] = level
    
    # dictionary of classes mapped to respective counts in Y
    class_counts = {}
    print("\nLevel", level)
    possible_classes = list(set(Y))
    
    # max_class is majority class, max_count is count of majority class
    max_count = -np.inf
    max_class = possible_classes[0]
    
    # add key value pairs of classes and their counts in class_counts dictionary
    # also find the majority class 
    for y in possible_classes:
        count_y = (Y == y).sum()
        class_counts[class_dict[y]] = count_y
        print("Count of", class_dict[y], "=", count_y)
        if count_y > max_count :
            max_count = count_y
            max_class = y   
    
    # find current entropy
    current_entropy = entropy(Y, possible_classes)
    print("Current Entropy is =", current_entropy)
    
    # add the class_counts dictionary to node dictionary
    node['class_counts'] = class_counts
    
    # add entropy value to node dictionary
    node["Entropy"] = current_entropy
    
    """
    check for base case, ie either all the examples are marked with a single class
    or
    there is no more feature to split current data
    
    mark this decision node as leaf node
    add the value of predict class to this node
    
    return the node
    """
    
    node["predict_class"] = max_class
    node["num_of_examples"] = len(Y)

    if len(possible_classes) == 1 or len(features) == 0:
        print("Reached leaf Node")
        node["is_leaf"] = True
        return node
    
    """
    else
    this node is NOT a leaf node and splitting can be done
    
    """
    node["is_leaf"] = False
    
    """ initialize few variables
    
    selected_feature : index of selected feature to make split on
    
    max_info_gain : information gain on splitting using the selected_feature
    
    max_split_info : split info on splitting using the selected_feature
    
    best_split_labels : labels assigned to examples
    
    best_split_mid_value : mid value of selected feature to use for prediction
    
    """
    selected_feature = None
    max_info_gain = -np.inf
    max_split_info = -np.inf
    best_split_labels = None
    best_split_mid_value = None
    
    # iterate over all available features
    for f in features:
        
        # find info gain
        # split info
        # current split labels for best split on curent feature 
        # mid value for current feature
        info_gain, split_info, current_split, current_mid_value_for_f = split(X, Y, f)
        #print("info_gain, split_info", info_gain, split_info)
        #print("gain ratio", info_gain/split_info)

        # keep feature that gives maximum gain
        if info_gain > max_info_gain and info_gain < np.inf:
            selected_feature = f
            max_info_gain = info_gain
            max_split_info = split_info
            best_split_labels = current_split
            best_split_mid_value = current_mid_value_for_f

    """
    add index, name of selected feature 
    information gain
    mid value of selected feature
    number of examples at current decision
    to node dictionary
    """
    node["selected_feature"] = feature_names[selected_feature]
    node["selected_feature_index"] = selected_feature
    node["max_info_gain"] = max_info_gain
    node["best_split_mid_value"] = best_split_mid_value
    
    if max_split_info != 0 :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio", max_info_gain/max_split_info)
    else :
        print("Splitting on feature", "\'" + feature_names[selected_feature] + "\'","with gain ratio inf")
    #splits = split(X, Y, selected_feature)
    
    # find list of groups in which current dataset is divided
    unique_splits = list(set(best_split_labels))
    
    # remove index of selected feature
    selected_feature_index = np.argwhere(features == selected_feature)
    features =  np.delete(features, selected_feature_index)
    
    """
    recursively call decision tree on 'split' datasets
    """
    for s in unique_splits:
        # find indices of examples that belong to split s
        indices = (best_split_labels == s)
        X_split_i = X[indices, :]
        Y_split_i = Y[indices]
        # store the output dictionaries of child splits in current node dictionary
        node[s] = decision_tree(X_split_i, Y_split_i, features, feature_names, class_dict, level + 1)
    """
    return the "decision tree" (dictionary)
    """
    return node

features = np.arange(len(feature_names))
tree_dict = decision_tree(X_train, Y_train, features, feature_names, class_dict, level = 0)
# Out:
# Level 0
# Count of malignant = 157
# Count of benign = 269
# Current Entropy is = 0.65817654685
# Splitting on feature 'symmetry error' with gain ratio 1.05215931423
#
# Level 1
# Count of malignant = 62
# Count of benign = 68
# Current Entropy is = 0.692081713342
# Splitting on feature 'mean fractal dimension' with gain ratio 6.14568762562
#
# Level 2
# Count of malignant = 59
# Count of benign = 68
# Current Entropy is = 0.690634069589
# Splitting on feature 'texture error' with gain ratio 2.0171286079
#
# Level 3
# Count of malignant = 2
# Count of benign = 11
# Current Entropy is = 0.429323021931
# Splitting on feature 'mean symmetry' with gain ratio 0.712554589976
#
# Level 4
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 2
# Count of benign = 8
# Current Entropy is = 0.500402423538
# Splitting on feature 'smoothness error' with gain ratio 0.879383361107
#
# Level 5
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 6
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 1
# Count of benign = 7
# Current Entropy is = 0.376770161256
# Splitting on feature 'mean smoothness' with gain ratio 0.40563906223
#
# Level 6
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean compactness' with gain ratio 0.5
#
# Level 7
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of malignant = 57
# Count of benign = 57
# Current Entropy is = 0.69314718056
# Splitting on feature 'smoothness error' with gain ratio 1.9758258276
#
# Level 4
# Count of malignant = 2
# Count of benign = 10
# Current Entropy is = 0.450561208866
# Splitting on feature 'area error' with gain ratio 0.706481985156
#
# Level 5
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 2
# Count of benign = 7
# Current Entropy is = 0.529706199058
# Splitting on feature 'mean perimeter' with gain ratio 0.892970605784
#
# Level 6
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 7
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 1
# Count of benign = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 'mean compactness' with gain ratio 0.470538226361
#
# Level 7
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean radius' with gain ratio 0.5
#
# Level 8
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 55
# Count of benign = 47
# Current Entropy is = 0.690068279283
# Splitting on feature 'fractal dimension error' with gain ratio 1.29018282466
#
# Level 5
# Count of malignant = 6
# Count of benign = 15
# Current Entropy is = 0.598269588585
# Splitting on feature 'mean symmetry' with gain ratio 0.918330670371
#
# Level 6
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 6
# Count of benign = 10
# Current Entropy is = 0.661563238158
# Splitting on feature 'mean smoothness' with gain ratio 1.16204295896
#
# Level 7
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 6
# Count of benign = 7
# Current Entropy is = 0.690185676019
# Splitting on feature 'worst fractal dimension' with gain ratio 2.35934085283
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 6
# Count of benign = 6
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean compactness' with gain ratio 1.24476551644
#
# Level 9
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 6
# Count of benign = 4
# Current Entropy is = 0.673011667009
# Splitting on feature 'worst symmetry' with gain ratio 1.76220472419
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 6
# Count of benign = 3
# Current Entropy is = 0.636514168295
# Splitting on feature 'concave points error' with gain ratio 1.00272707596
#
# Level 11
# Count of malignant = 4
# Count of benign = 3
# Current Entropy is = 0.6829081047
# Splitting on feature 'mean concave points' with gain ratio 1.44867718808
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 3
# Count of benign = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.588973686818
#
# Level 13
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean perimeter' with gain ratio 0.5
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 49
# Count of benign = 32
# Current Entropy is = 0.670958494216
# Splitting on feature 'worst fractal dimension' with gain ratio 1.0001142171
#
# Level 6
# Count of malignant = 28
# Count of benign = 27
# Current Entropy is = 0.692981882196
# Splitting on feature 'mean smoothness' with gain ratio 3.08255823785
#
# Level 7
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 28
# Count of benign = 24
# Current Entropy is = 0.690185676019
# Splitting on feature 'compactness error' with gain ratio 2.31184438798
#
# Level 8
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 28
# Count of benign = 20
# Current Entropy is = 0.679193265992
# Splitting on feature 'mean symmetry' with gain ratio 0.922490166449
#
# Level 9
# Count of malignant = 13
# Count of benign = 16
# Current Entropy is = 0.687786822992
# Splitting on feature 'concavity error' with gain ratio 1.12489606253
#
# Level 10
# Count of malignant = 1
# Count of benign = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 'mean concavity' with gain ratio 0.470538226361
#
# Level 11
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean concave points' with gain ratio 0.5
#
# Level 12
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 13
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 12
# Count of benign = 10
# Current Entropy is = 0.689009238477
# Splitting on feature 'mean compactness' with gain ratio 2.00839228678
#
# Level 11
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 12
# Count of benign = 8
# Current Entropy is = 0.673011667009
# Splitting on feature 'worst smoothness' with gain ratio 0.795200019254
#
# Level 12
# Count of malignant = 3
# Count of benign = 6
# Current Entropy is = 0.636514168295
# Splitting on feature 'concave points error' with gain ratio 1.43293426219
#
# Level 13
# Count of malignant = 2
# Count of benign = 6
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst compactness' with gain ratio 0.909080121848
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 5
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean texture' with gain ratio 0.459147917027
#
# Level 15
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'radius error' with gain ratio 0.725982457879
#
# Level 16
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 9
# Count of benign = 2
# Current Entropy is = 0.474139313058
# Splitting on feature 'worst compactness' with gain ratio 0.580820132728
#
# Level 13
# Count of malignant = 5
# Count of benign = 2
# Current Entropy is = 0.598269588585
# Splitting on feature 'concave points error' with gain ratio 0.941672653985
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 5
# Count of benign = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'worst texture' with gain ratio 0.459147917027
#
# Level 15
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean texture' with gain ratio 0.725982457879
#
# Level 16
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 15
# Count of benign = 4
# Current Entropy is = 0.514653165429
# Splitting on feature 'concave points error' with gain ratio 0.764886550939
#
# Level 10
# Count of malignant = 10
# Count of benign = 4
# Current Entropy is = 0.598269588585
# Splitting on feature 'worst symmetry' with gain ratio 0.712858974953
#
# Level 11
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'radius error' with gain ratio 0.899012663676
#
# Level 12
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'perimeter error' with gain ratio 0.5
#
# Level 13
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 8
# Count of benign = 1
# Current Entropy is = 0.348832095843
# Splitting on feature 'worst texture' with gain ratio 0.363814716071
#
# Level 12
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean texture' with gain ratio 0.5
#
# Level 13
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 21
# Count of benign = 5
# Current Entropy is = 0.489551893623
# Splitting on feature 'concave points error' with gain ratio 1.16316100508
#
# Level 7
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean texture' with gain ratio 0.725982457879
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 20
# Count of benign = 3
# Current Entropy is = 0.387212375186
# Splitting on feature 'worst concavity' with gain ratio 0.549972185203
#
# Level 8
# Count of malignant = 6
# Count of benign = 2
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst compactness' with gain ratio 0.909080121848
#
# Level 9
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 5
# Count of benign = 1
# Current Entropy is = 0.450561208866
# Splitting on feature 'mean concavity' with gain ratio 0.459147917027
#
# Level 10
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean texture' with gain ratio 0.725982457879
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 14
# Count of benign = 1
# Current Entropy is = 0.244930026795
# Splitting on feature 'perimeter error' with gain ratio 0.27700268991
#
# Level 9
# Count of malignant = 6
# Count of benign = 1
# Current Entropy is = 0.410116318288
# Splitting on feature 'radius error' with gain ratio 0.470538226361
#
# Level 10
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean texture' with gain ratio 0.5
#
# Level 11
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 8
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 1
# Count of malignant = 95
# Count of benign = 201
# Current Entropy is = 0.627580429926
# Splitting on feature 'smoothness error' with gain ratio 1.66311028476
#
# Level 2
# Count of malignant = 90
# Count of benign = 170
# Current Entropy is = 0.645033151676
# Splitting on feature 'mean fractal dimension' with gain ratio 1.57954768792
#
# Level 3
# Count of malignant = 69
# Count of benign = 156
# Current Entropy is = 0.616407575768
# Splitting on feature 'texture error' with gain ratio 3.06279754449
#
# Level 4
# Count of benign = 11
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 69
# Count of benign = 145
# Current Entropy is = 0.628687503488
# Splitting on feature 'fractal dimension error' with gain ratio 0.938125934393
#
# Level 5
# Count of malignant = 5
# Count of benign = 57
# Current Entropy is = 0.280342258775
# Splitting on feature 'mean smoothness' with gain ratio 0.766550674964
#
# Level 6
# Count of malignant = 5
# Count of benign = 50
# Current Entropy is = 0.304636097349
# Splitting on feature 'worst smoothness' with gain ratio 1.81194041588
#
# Level 7
# Count of malignant = 4
# Count of benign = 49
# Current Entropy is = 0.267567912573
# Splitting on feature 'worst fractal dimension' with gain ratio 0.705221112292
#
# Level 8
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'mean texture' with gain ratio 0.567461932234
#
# Level 9
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 2
# Count of benign = 46
# Current Entropy is = 0.173205206749
# Splitting on feature 'mean symmetry' with gain ratio 0.209731058761
#
# Level 9
# Count of benign = 23
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 2
# Count of benign = 23
# Current Entropy is = 0.278769371769
# Splitting on feature 'concave points error' with gain ratio 0.789143702368
#
# Level 10
# Count of malignant = 1
# Count of benign = 22
# Current Entropy is = 0.178844912717
# Splitting on feature 'concavity error' with gain ratio 0.210481315194
#
# Level 11
# Count of malignant = 1
# Count of benign = 10
# Current Entropy is = 0.304636097349
# Splitting on feature 'radius error' with gain ratio 0.33011987991
#
# Level 12
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean compactness' with gain ratio 0.411967408316
#
# Level 13
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of benign = 12
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of benign = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 64
# Count of benign = 88
# Current Entropy is = 0.680629487892
# Splitting on feature 'worst fractal dimension' with gain ratio 1.28231610708
#
# Level 6
# Count of malignant = 42
# Count of benign = 81
# Current Entropy is = 0.642001383857
# Splitting on feature 'mean symmetry' with gain ratio 0.915169875777
#
# Level 7
# Count of malignant = 5
# Count of benign = 36
# Current Entropy is = 0.370794716787
# Splitting on feature 'worst symmetry' with gain ratio 1.78730835945
#
# Level 8
# Count of malignant = 4
# Count of benign = 35
# Current Entropy is = 0.330680630832
# Splitting on feature 'compactness error' with gain ratio 0.656895254209
#
# Level 9
# Count of benign = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 4
# Count of benign = 28
# Current Entropy is = 0.376770161256
# Splitting on feature 'mean compactness' with gain ratio 0.816659005513
#
# Level 10
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 4
# Count of benign = 23
# Current Entropy is = 0.419483369306
# Splitting on feature 'concavity error' with gain ratio 0.806267639566
#
# Level 11
# Count of malignant = 4
# Count of benign = 18
# Current Entropy is = 0.474139313058
# Splitting on feature 'worst texture' with gain ratio 0.807611132335
#
# Level 12
# Count of malignant = 2
# Count of benign = 15
# Current Entropy is = 0.362210557135
# Splitting on feature 'mean texture' with gain ratio 0.472540321118
#
# Level 13
# Count of benign = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 2
# Count of benign = 9
# Current Entropy is = 0.474139313058
# Splitting on feature 'worst concavity' with gain ratio 0.867750948272
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Count of benign = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 'worst compactness' with gain ratio 0.404682526477
#
# Level 15
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'worst smoothness' with gain ratio 0.567461932234
#
# Level 16
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean smoothness' with gain ratio 0.725982457879
#
# Level 17
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 18
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 2
# Count of benign = 3
# Current Entropy is = 0.673011667009
# Splitting on feature 'worst compactness' with gain ratio 0.899012663676
#
# Level 13
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean smoothness' with gain ratio 0.5
#
# Level 14
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 15
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 37
# Count of benign = 45
# Current Entropy is = 0.6883805301
# Splitting on feature 'worst smoothness' with gain ratio 1.89382462042
#
# Level 8
# Count of malignant = 1
# Count of benign = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 'worst symmetry' with gain ratio 0.404682526477
#
# Level 9
# Count of benign = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'mean compactness' with gain ratio 0.567461932234
#
# Level 10
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean texture' with gain ratio 0.725982457879
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 36
# Count of benign = 37
# Current Entropy is = 0.693053351391
# Splitting on feature 'mean smoothness' with gain ratio 5.36779199184
#
# Level 9
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 36
# Count of benign = 35
# Current Entropy is = 0.693047990611
# Splitting on feature 'worst symmetry' with gain ratio 1.8595569498
#
# Level 10
# Count of malignant = 29
# Count of benign = 34
# Current Entropy is = 0.689994458033
# Splitting on feature 'worst texture' with gain ratio 1.0605701053
#
# Level 11
# Count of benign = 13
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 29
# Count of benign = 21
# Current Entropy is = 0.680292000192
# Splitting on feature 'mean texture' with gain ratio 0.796835467405
#
# Level 12
# Count of malignant = 9
# Count of benign = 17
# Current Entropy is = 0.645033151676
# Splitting on feature 'concavity error' with gain ratio 1.12670307318
#
# Level 13
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 9
# Count of benign = 12
# Current Entropy is = 0.6829081047
# Splitting on feature 'compactness error' with gain ratio 1.44867718808
#
# Level 14
# Count of malignant = 9
# Count of benign = 9
# Current Entropy is = 0.69314718056
# Splitting on feature 'worst compactness' with gain ratio 1.24476551644
#
# Level 15
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 9
# Count of benign = 6
# Current Entropy is = 0.673011667009
# Splitting on feature 'worst concavity' with gain ratio 1.10814360276
#
# Level 16
# Count of malignant = 6
# Count of benign = 6
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean compactness' with gain ratio 0.848934360211
#
# Level 17
# Count of malignant = 3
# Count of benign = 6
# Current Entropy is = 0.636514168295
# Splitting on feature 'concave points error' with gain ratio 0.60218166077
#
# Level 18
# Count of malignant = 1
# Count of benign = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 'worst concave points' with gain ratio 0.470538226361
#
# Level 19
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 19
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean concavity' with gain ratio 0.5
#
# Level 20
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 20
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 21
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 21
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 18
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 17
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 20
# Count of benign = 4
# Current Entropy is = 0.450561208866
# Splitting on feature 'concave points error' with gain ratio 0.329968917661
#
# Level 13
# Count of malignant = 3
# Count of benign = 4
# Current Entropy is = 0.6829081047
# Splitting on feature 'worst compactness' with gain ratio 0.470538226361
#
# Level 14
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'worst concave points' with gain ratio 0.5
#
# Level 15
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 16
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 16
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 15
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 17
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 7
# Count of benign = 1
# Current Entropy is = 0.376770161256
# Splitting on feature 'compactness error' with gain ratio 0.308155726702
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 6
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 22
# Count of benign = 7
# Current Entropy is = 0.552664622494
# Splitting on feature 'concavity error' with gain ratio 3.34453514078
#
# Level 7
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 22
# Count of benign = 6
# Current Entropy is = 0.519579839131
# Splitting on feature 'concave points error' with gain ratio 0.627822877428
#
# Level 8
# Count of malignant = 12
# Count of benign = 6
# Current Entropy is = 0.636514168295
# Splitting on feature 'worst smoothness' with gain ratio 0.760046024105
#
# Level 9
# Count of malignant = 1
# Count of benign = 4
# Current Entropy is = 0.500402423538
# Splitting on feature 'worst symmetry' with gain ratio 0.567461932234
#
# Level 10
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Count of benign = 2
# Current Entropy is = 0.636514168295
# Splitting on feature 'mean smoothness' with gain ratio 0.725982457879
#
# Level 11
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 11
# Count of benign = 2
# Current Entropy is = 0.429323021931
# Splitting on feature 'mean compactness' with gain ratio 0.594126474025
#
# Level 10
# Count of malignant = 7
# Count of benign = 2
# Current Entropy is = 0.529706199058
# Splitting on feature 'mean radius' with gain ratio 0.544274066117
#
# Level 11
# Count of malignant = 3
# Count of benign = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'mean perimeter' with gain ratio 0.899012663676
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean area' with gain ratio 0.5
#
# Level 13
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 13
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean texture' with gain ratio 0.0
#
# Level 14
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 14
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 10
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of malignant = 21
# Count of benign = 14
# Current Entropy is = 0.673011667009
# Splitting on feature 'fractal dimension error' with gain ratio 2.82161602071
#
# Level 4
# Count of malignant = 21
# Count of benign = 12
# Current Entropy is = 0.655481773901
# Splitting on feature 'worst smoothness' with gain ratio 0.875150389932
#
# Level 5
# Count of malignant = 7
# Count of benign = 8
# Current Entropy is = 0.690923309314
# Splitting on feature 'concavity error' with gain ratio 0.838160392039
#
# Level 6
# Count of malignant = 2
# Count of benign = 6
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean radius' with gain ratio 0.952442139541
#
# Level 7
# Count of malignant = 1
# Count of benign = 6
# Current Entropy is = 0.410116318288
# Splitting on feature 'mean texture' with gain ratio 0.470538226361
#
# Level 8
# Count of benign = 3
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean perimeter' with gain ratio 0.5
#
# Level 9
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean area' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 5
# Count of benign = 2
# Current Entropy is = 0.598269588585
# Splitting on feature 'mean symmetry' with gain ratio 0.803521737465
#
# Level 7
# Count of malignant = 3
# Count of benign = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'texture error' with gain ratio 0.899012663676
#
# Level 8
# Count of malignant = 3
# Count of benign = 1
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean smoothness' with gain ratio 0.5
#
# Level 9
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 14
# Count of benign = 4
# Current Entropy is = 0.529706199058
# Splitting on feature 'mean smoothness' with gain ratio 2.05123108818
#
# Level 6
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 14
# Count of benign = 3
# Current Entropy is = 0.465999256961
# Splitting on feature 'radius error' with gain ratio 1.58506284709
#
# Level 7
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 14
# Count of benign = 2
# Current Entropy is = 0.376770161256
# Splitting on feature 'mean symmetry' with gain ratio 0.827552816301
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 13
# Count of benign = 1
# Current Entropy is = 0.257318640544
# Splitting on feature 'mean compactness' with gain ratio 0.295836389291
#
# Level 9
# Count of malignant = 6
# Count of benign = 1
# Current Entropy is = 0.410116318288
# Splitting on feature 'perimeter error' with gain ratio 0.399456068151
#
# Level 10
# Count of malignant = 4
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'texture error' with gain ratio 0.725982457879
#
# Level 11
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 11
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 12
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 12
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 7
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 2
# Count of malignant = 5
# Count of benign = 31
# Current Entropy is = 0.402941357867
# Splitting on feature 'fractal dimension error' with gain ratio 0.639074796205
#
# Level 3
# Count of benign = 9
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 3
# Count of malignant = 5
# Count of benign = 22
# Current Entropy is = 0.479165623928
# Splitting on feature 'worst smoothness' with gain ratio 0.730152969957
#
# Level 4
# Count of malignant = 3
# Count of benign = 4
# Current Entropy is = 0.6829081047
# Splitting on feature 'mean compactness' with gain ratio 1.44867718808
#
# Level 5
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 3
# Count of benign = 3
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean symmetry' with gain ratio 1.24476551644
#
# Level 6
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 3
# Count of benign = 2
# Current Entropy is = 0.673011667009
# Splitting on feature 'concave points error' with gain ratio 1.10814360276
#
# Level 7
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of malignant = 2
# Count of benign = 2
# Current Entropy is = 0.69314718056
# Splitting on feature 'texture error' with gain ratio 0.848934360211
#
# Level 8
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 2
# Count of benign = 1
# Current Entropy is = 0.636514168295
# Splitting on feature 'compactness error' with gain ratio 0.725982457879
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 10
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 10
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 4
# Count of malignant = 2
# Count of benign = 18
# Current Entropy is = 0.325082973391
# Splitting on feature 'worst fractal dimension' with gain ratio 0.807233780893
#
# Level 5
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 6
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 5
# Count of malignant = 1
# Count of benign = 17
# Current Entropy is = 0.214559155176
# Splitting on feature 'compactness error' with gain ratio 0.251629167388
#
# Level 6
# Count of benign = 9
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 6
# Count of malignant = 1
# Count of benign = 8
# Current Entropy is = 0.348832095843
# Splitting on feature 'mean symmetry' with gain ratio 0.363814716071
#
# Level 7
# Count of malignant = 1
# Count of benign = 3
# Current Entropy is = 0.562335144619
# Splitting on feature 'mean compactness' with gain ratio 0.5
#
# Level 8
# Count of benign = 2
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 8
# Count of malignant = 1
# Count of benign = 1
# Current Entropy is = 0.69314718056
# Splitting on feature 'mean radius' with gain ratio 0.0
#
# Level 9
# Count of benign = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 9
# Count of malignant = 1
# Current Entropy is = 0.0
# Reached leaf Node
#
# Level 7
# Count of benign = 5
# Current Entropy is = 0.0
# Reached leaf Node

# %%
def predict_single(X, tree_dict):
    if tree_dict['is_leaf']:
        return tree_dict["predict_class"]
    index = tree_dict["selected_feature_index"]
    feature_value = tree_dict["best_split_mid_value"]

    if X[index] <= feature_value :
        #print(X[index], "<=" ,feature_value)
        return predict_single(X, tree_dict[0])
    else:
        #print(X[index], ">" ,feature_value)
        return predict_single(X, tree_dict[1])
    
def predict(X, tree_dict):
    Y_pred = []
    for i in range(len(X)):
        Y_pred.append(predict_single(X[i], tree_dict))
    return Y_pred

def print_dict(dictionary):
    for key in dictionary:
        if isinstance(dictionary[key], dict) :
            print(key, end = " ")
            print_dict(dictionary[key])
        else:
            print(key, dictionary[key])

# %%
print_dict(tree_dict)
# Out:
# level 0
# class_counts malignant 157
# benign 269
# Entropy 0.65817654685
# predict_class 1
# num_of_examples 426
# is_leaf False
# selected_feature symmetry error
# selected_feature_index 18
# max_info_gain 0.64726392017
# best_split_mid_value 0.015595
# 0 level 1
# class_counts malignant 62
# benign 68
# Entropy 0.692081713342
# predict_class 1
# num_of_examples 130
# is_leaf False
# selected_feature mean fractal dimension
# selected_feature_index 9
# max_info_gain 0.674696360291
# best_split_mid_value 0.072915
# 0 level 2
# class_counts malignant 59
# benign 68
# Entropy 0.690634069589
# predict_class 1
# num_of_examples 127
# is_leaf False
# selected_feature texture error
# selected_feature_index 11
# max_info_gain 0.666141558023
# best_split_mid_value 0.54415
# 0 level 3
# class_counts malignant 2
# benign 11
# Entropy 0.429323021931
# predict_class 1
# num_of_examples 13
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.384924941183
# best_split_mid_value 0.14875
# 0 level 4
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 4
# class_counts malignant 2
# benign 8
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 10
# is_leaf False
# selected_feature smoothness error
# selected_feature_index 14
# max_info_gain 0.440045565117
# best_split_mid_value 0.0034855
# 0 level 5
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.1
# 0 level 6
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts malignant 1
# benign 7
# Entropy 0.376770161256
# predict_class 1
# num_of_examples 8
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.281167572309
# best_split_mid_value 0.089395
# 0 level 6
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.34657359028
# best_split_mid_value 0.10274
# 0 level 7
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.2
# 0 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 6
# class_counts benign 4
# Entropy 0.0
# predict_class 1
# num_of_examples 4
# is_leaf True
# 1 level 3
# class_counts malignant 57
# benign 57
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 114
# is_leaf False
# selected_feature smoothness error
# selected_feature_index 14
# max_info_gain 0.664857008713
# best_split_mid_value 0.003968
# 0 level 4
# class_counts malignant 2
# benign 10
# Entropy 0.450561208866
# predict_class 1
# num_of_examples 12
# is_leaf False
# selected_feature area error
# selected_feature_index 13
# max_info_gain 0.397279649293
# best_split_mid_value 13.2
# 0 level 5
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 5
# class_counts malignant 2
# benign 7
# Entropy 0.529706199058
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature mean perimeter
# selected_feature_index 2
# max_info_gain 0.47301206546
# best_split_mid_value 85.83
# 0 level 6
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.185
# 0 level 7
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 1
# benign 6
# Entropy 0.410116318288
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.321334368354
# best_split_mid_value 0.05471
# 0 level 7
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 7
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.34657359028
# best_split_mid_value 14.675
# 0 level 8
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 8
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 17.12
# 0 level 9
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 4
# class_counts malignant 55
# benign 47
# Entropy 0.690068279283
# predict_class 0
# num_of_examples 102
# is_leaf False
# selected_feature fractal dimension error
# selected_feature_index 19
# max_info_gain 0.655993131292
# best_split_mid_value 0.001795
# 0 level 5
# class_counts malignant 6
# benign 15
# Entropy 0.598269588585
# predict_class 1
# num_of_examples 21
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.504048181454
# best_split_mid_value 0.1509
# 0 level 6
# class_counts benign 5
# Entropy 0.0
# predict_class 1
# num_of_examples 5
# is_leaf True
# 1 level 6
# class_counts malignant 6
# benign 10
# Entropy 0.661563238158
# predict_class 1
# num_of_examples 16
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.560775861765
# best_split_mid_value 0.085155
# 0 level 7
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 7
# class_counts malignant 6
# benign 7
# Entropy 0.690185676019
# predict_class 1
# num_of_examples 13
# is_leaf False
# selected_feature worst fractal dimension
# selected_feature_index 29
# max_info_gain 0.639828166671
# best_split_mid_value 0.064715
# 0 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 6
# benign 6
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 12
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.560843055841
# best_split_mid_value 0.06213
# 0 level 9
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 9
# class_counts malignant 6
# benign 4
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 10
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.572862751465
# best_split_mid_value 0.24105
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 6
# benign 3
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 9
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.5311507481
# best_split_mid_value 0.011375
# 0 level 11
# class_counts malignant 4
# benign 3
# Entropy 0.6829081047
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature mean concave points
# selected_feature_index 7
# max_info_gain 0.594126154766
# best_split_mid_value 0.02856
# 0 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 3
# benign 3
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 6
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.374890096413
# best_split_mid_value 13.535
# 0 level 13
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature mean perimeter
# selected_feature_index 2
# max_info_gain 0.34657359028
# best_split_mid_value 93.125
# 0 level 14
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 19.935
# 0 level 15
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 11
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 5
# class_counts malignant 49
# benign 32
# Entropy 0.670958494216
# predict_class 0
# num_of_examples 81
# is_leaf False
# selected_feature worst fractal dimension
# selected_feature_index 29
# max_info_gain 0.627683367345
# best_split_mid_value 0.088705
# 0 level 6
# class_counts malignant 28
# benign 27
# Entropy 0.692981882196
# predict_class 0
# num_of_examples 55
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.6525391846
# best_split_mid_value 0.08086
# 0 level 7
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 7
# class_counts malignant 28
# benign 24
# Entropy 0.690185676019
# predict_class 0
# num_of_examples 52
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.626947630146
# best_split_mid_value 0.008665
# 0 level 8
# class_counts benign 4
# Entropy 0.0
# predict_class 1
# num_of_examples 4
# is_leaf True
# 1 level 8
# class_counts malignant 28
# benign 20
# Entropy 0.679193265992
# predict_class 0
# num_of_examples 48
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.619254750207
# best_split_mid_value 0.1754
# 0 level 9
# class_counts malignant 13
# benign 16
# Entropy 0.687786822992
# predict_class 1
# num_of_examples 29
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.621690257742
# best_split_mid_value 0.01928
# 0 level 10
# class_counts malignant 1
# benign 6
# Entropy 0.410116318288
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature mean concavity
# selected_feature_index 6
# max_info_gain 0.321334368354
# best_split_mid_value 0.029525
# 0 level 11
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean concave points
# selected_feature_index 7
# max_info_gain 0.34657359028
# best_split_mid_value 0.027975
# 0 level 12
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 12
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.44
# 0 level 13
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 13
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 12
# benign 10
# Entropy 0.689009238477
# predict_class 0
# num_of_examples 22
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.61182878819
# best_split_mid_value 0.061915
# 0 level 11
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 11
# class_counts malignant 12
# benign 8
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 20
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.547207997914
# best_split_mid_value 0.13215
# 0 level 12
# class_counts malignant 3
# benign 6
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.499853461883
# best_split_mid_value 0.01525
# 0 level 13
# class_counts malignant 2
# benign 6
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 8
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.51120770179
# best_split_mid_value 0.199
# 0 level 14
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.095
# 0 level 15
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# benign 5
# Entropy 0.450561208866
# predict_class 1
# num_of_examples 6
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.318257084147
# best_split_mid_value 18.775
# 0 level 15
# class_counts malignant 1
# benign 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature radius error
# selected_feature_index 10
# max_info_gain 0.462098120373
# best_split_mid_value 0.2696
# 0 level 16
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 16
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 16.535
# 0 level 17
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 17
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 13
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 9
# benign 2
# Entropy 0.474139313058
# predict_class 0
# num_of_examples 11
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.380717010918
# best_split_mid_value 0.28055
# 0 level 13
# class_counts malignant 5
# benign 2
# Entropy 0.598269588585
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.386195321885
# best_split_mid_value 0.007404
# 0 level 14
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 5
# benign 1
# Entropy 0.450561208866
# predict_class 0
# num_of_examples 6
# is_leaf False
# selected_feature worst texture
# selected_feature_index 21
# max_info_gain 0.318257084147
# best_split_mid_value 28.19
# 0 level 15
# class_counts malignant 2
# benign 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.462098120373
# best_split_mid_value 17.435
# 0 level 16
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 16
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.7
# 0 level 17
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 17
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 13
# class_counts malignant 4
# Entropy 0.0
# predict_class 0
# num_of_examples 4
# is_leaf True
# 1 level 9
# class_counts malignant 15
# benign 4
# Entropy 0.514653165429
# predict_class 0
# num_of_examples 19
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.440830223168
# best_split_mid_value 0.013705
# 0 level 10
# class_counts malignant 10
# benign 4
# Entropy 0.598269588585
# predict_class 0
# num_of_examples 14
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.464610514117
# best_split_mid_value 0.27605
# 0 level 11
# class_counts malignant 2
# benign 3
# Entropy 0.673011667009
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature radius error
# selected_feature_index 10
# max_info_gain 0.449868115695
# best_split_mid_value 0.6812
# 0 level 12
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature perimeter error
# selected_feature_index 12
# max_info_gain 0.34657359028
# best_split_mid_value 1.704
# 0 level 13
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.25
# 0 level 14
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 8
# benign 1
# Entropy 0.348832095843
# predict_class 0
# num_of_examples 9
# is_leaf False
# selected_feature worst texture
# selected_feature_index 21
# max_info_gain 0.249926730942
# best_split_mid_value 26.195
# 0 level 12
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.34657359028
# best_split_mid_value 18.985
# 0 level 13
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.21
# 0 level 14
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 5
# Entropy 0.0
# predict_class 0
# num_of_examples 5
# is_leaf True
# 1 level 10
# class_counts malignant 5
# Entropy 0.0
# predict_class 0
# num_of_examples 5
# is_leaf True
# 1 level 6
# class_counts malignant 21
# benign 5
# Entropy 0.489551893623
# predict_class 0
# num_of_examples 26
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.415977966699
# best_split_mid_value 0.0089485
# 0 level 7
# class_counts malignant 1
# benign 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.462098120373
# best_split_mid_value 17.525
# 0 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.535
# 0 level 9
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 20
# benign 3
# Entropy 0.387212375186
# predict_class 0
# num_of_examples 23
# is_leaf False
# selected_feature worst concavity
# selected_feature_index 26
# max_info_gain 0.355331806907
# best_split_mid_value 0.48345
# 0 level 8
# class_counts malignant 6
# benign 2
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 8
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.51120770179
# best_split_mid_value 0.29175
# 0 level 9
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.92
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 5
# benign 1
# Entropy 0.450561208866
# predict_class 0
# num_of_examples 6
# is_leaf False
# selected_feature mean concavity
# selected_feature_index 6
# max_info_gain 0.318257084147
# best_split_mid_value 0.102985
# 0 level 10
# class_counts malignant 2
# benign 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.462098120373
# best_split_mid_value 16.495
# 0 level 11
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.695
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 8
# class_counts malignant 14
# benign 1
# Entropy 0.244930026795
# predict_class 0
# num_of_examples 15
# is_leaf False
# selected_feature perimeter error
# selected_feature_index 12
# max_info_gain 0.191387615201
# best_split_mid_value 3.4175
# 0 level 9
# class_counts malignant 6
# benign 1
# Entropy 0.410116318288
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature radius error
# selected_feature_index 10
# max_info_gain 0.321334368354
# best_split_mid_value 0.26775
# 0 level 10
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 10
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.34657359028
# best_split_mid_value 19.605
# 0 level 11
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.495
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 8
# Entropy 0.0
# predict_class 0
# num_of_examples 8
# is_leaf True
# 1 level 2
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 1
# class_counts malignant 95
# benign 201
# Entropy 0.627580429926
# predict_class 1
# num_of_examples 296
# is_leaf False
# selected_feature smoothness error
# selected_feature_index 14
# max_info_gain 0.615589555132
# best_split_mid_value 0.010845
# 0 level 2
# class_counts malignant 90
# benign 170
# Entropy 0.645033151676
# predict_class 1
# num_of_examples 260
# is_leaf False
# selected_feature mean fractal dimension
# selected_feature_index 9
# max_info_gain 0.624027357281
# best_split_mid_value 0.070105
# 0 level 3
# class_counts malignant 69
# benign 156
# Entropy 0.616407575768
# predict_class 1
# num_of_examples 225
# is_leaf False
# selected_feature texture error
# selected_feature_index 11
# max_info_gain 0.597951669984
# best_split_mid_value 0.5491
# 0 level 4
# class_counts benign 11
# Entropy 0.0
# predict_class 1
# num_of_examples 11
# is_leaf True
# 1 level 4
# class_counts malignant 69
# benign 145
# Entropy 0.628687503488
# predict_class 1
# num_of_examples 214
# is_leaf False
# selected_feature fractal dimension error
# selected_feature_index 19
# max_info_gain 0.564658421512
# best_split_mid_value 0.002491
# 0 level 5
# class_counts malignant 5
# benign 57
# Entropy 0.280342258775
# predict_class 1
# num_of_examples 62
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.270241699261
# best_split_mid_value 0.1043
# 0 level 6
# class_counts malignant 5
# benign 50
# Entropy 0.304636097349
# predict_class 1
# num_of_examples 55
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.283043522318
# best_split_mid_value 0.1475
# 0 level 7
# class_counts malignant 4
# benign 49
# Entropy 0.267567912573
# predict_class 1
# num_of_examples 53
# is_leaf False
# selected_feature worst fractal dimension
# selected_feature_index 29
# max_info_gain 0.220356759604
# best_split_mid_value 0.05979
# 0 level 8
# class_counts malignant 2
# benign 3
# Entropy 0.673011667009
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.381908500977
# best_split_mid_value 22.18
# 0 level 9
# class_counts malignant 2
# benign 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 16.35
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 9
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 8
# class_counts malignant 2
# benign 46
# Entropy 0.173205206749
# predict_class 1
# num_of_examples 48
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.145192381129
# best_split_mid_value 0.1712
# 0 level 9
# class_counts benign 23
# Entropy 0.0
# predict_class 1
# num_of_examples 23
# is_leaf True
# 1 level 9
# class_counts malignant 2
# benign 23
# Entropy 0.278769371769
# predict_class 1
# num_of_examples 25
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.219989094144
# best_split_mid_value 0.015245
# 0 level 10
# class_counts malignant 1
# benign 22
# Entropy 0.178844912717
# predict_class 1
# num_of_examples 23
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.145695524819
# best_split_mid_value 0.014665
# 0 level 11
# class_counts malignant 1
# benign 10
# Entropy 0.304636097349
# predict_class 1
# num_of_examples 11
# is_leaf False
# selected_feature radius error
# selected_feature_index 10
# max_info_gain 0.227455647063
# best_split_mid_value 0.2424
# 0 level 12
# class_counts benign 6
# Entropy 0.0
# predict_class 1
# num_of_examples 6
# is_leaf True
# 1 level 12
# class_counts malignant 1
# benign 4
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.277258872224
# best_split_mid_value 0.065515
# 0 level 13
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 13
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.78
# 0 level 14
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts benign 12
# Entropy 0.0
# predict_class 1
# num_of_examples 12
# is_leaf True
# 1 level 10
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.555
# 0 level 11
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.37
# 0 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts benign 7
# Entropy 0.0
# predict_class 1
# num_of_examples 7
# is_leaf True
# 1 level 5
# class_counts malignant 64
# benign 88
# Entropy 0.680629487892
# predict_class 1
# num_of_examples 152
# is_leaf False
# selected_feature worst fractal dimension
# selected_feature_index 29
# max_info_gain 0.624956870176
# best_split_mid_value 0.093935
# 0 level 6
# class_counts malignant 42
# benign 81
# Entropy 0.642001383857
# predict_class 1
# num_of_examples 123
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.582518592329
# best_split_mid_value 0.17195
# 0 level 7
# class_counts malignant 5
# benign 36
# Entropy 0.370794716787
# predict_class 1
# num_of_examples 41
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.348361925941
# best_split_mid_value 0.28895
# 0 level 8
# class_counts malignant 4
# benign 35
# Entropy 0.330680630832
# predict_class 1
# num_of_examples 39
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.309144747698
# best_split_mid_value 0.01004
# 0 level 9
# class_counts benign 7
# Entropy 0.0
# predict_class 1
# num_of_examples 7
# is_leaf True
# 1 level 9
# class_counts malignant 4
# benign 28
# Entropy 0.376770161256
# predict_class 1
# num_of_examples 32
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.353939092852
# best_split_mid_value 0.059045
# 0 level 10
# class_counts benign 5
# Entropy 0.0
# predict_class 1
# num_of_examples 5
# is_leaf True
# 1 level 10
# class_counts malignant 4
# benign 23
# Entropy 0.419483369306
# predict_class 1
# num_of_examples 27
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.386335736566
# best_split_mid_value 0.05128
# 0 level 11
# class_counts malignant 4
# benign 18
# Entropy 0.474139313058
# predict_class 1
# num_of_examples 22
# is_leaf False
# selected_feature worst texture
# selected_feature_index 21
# max_info_gain 0.432847173016
# best_split_mid_value 30.875
# 0 level 12
# class_counts malignant 2
# benign 15
# Entropy 0.362210557135
# predict_class 1
# num_of_examples 17
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.306796026096
# best_split_mid_value 18.07
# 0 level 13
# class_counts benign 6
# Entropy 0.0
# predict_class 1
# num_of_examples 6
# is_leaf True
# 1 level 13
# class_counts malignant 2
# benign 9
# Entropy 0.474139313058
# predict_class 1
# num_of_examples 11
# is_leaf False
# selected_feature worst concavity
# selected_feature_index 26
# max_info_gain 0.411434838519
# best_split_mid_value 0.1012
# 0 level 14
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 12.265
# 0 level 15
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# benign 8
# Entropy 0.348832095843
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.27800134641
# best_split_mid_value 0.2002
# 0 level 15
# class_counts benign 4
# Entropy 0.0
# predict_class 1
# num_of_examples 4
# is_leaf True
# 1 level 15
# class_counts malignant 1
# benign 4
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.381908500977
# best_split_mid_value 0.12455
# 0 level 16
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 16
# class_counts malignant 1
# benign 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.090575
# 0 level 17
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 17
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 16.16
# 0 level 18
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 18
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 2
# benign 3
# Entropy 0.673011667009
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.449868115695
# best_split_mid_value 0.3193
# 0 level 13
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.34657359028
# best_split_mid_value 0.089635
# 0 level 14
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 13.3
# 0 level 15
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts benign 5
# Entropy 0.0
# predict_class 1
# num_of_examples 5
# is_leaf True
# 1 level 8
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 17.345
# 0 level 9
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 37
# benign 45
# Entropy 0.6883805301
# predict_class 1
# num_of_examples 82
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.655272969685
# best_split_mid_value 0.1092
# 0 level 8
# class_counts malignant 1
# benign 8
# Entropy 0.348832095843
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.27800134641
# best_split_mid_value 0.2763
# 0 level 9
# class_counts benign 4
# Entropy 0.0
# predict_class 1
# num_of_examples 4
# is_leaf True
# 1 level 9
# class_counts malignant 1
# benign 4
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.381908500977
# best_split_mid_value 0.079635
# 0 level 10
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 10
# class_counts malignant 1
# benign 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.462098120373
# best_split_mid_value 16.385
# 0 level 11
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.065
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 36
# benign 37
# Entropy 0.693053351391
# predict_class 1
# num_of_examples 73
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.67406037443
# best_split_mid_value 0.08331
# 0 level 9
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 9
# class_counts malignant 36
# benign 35
# Entropy 0.693047990611
# predict_class 0
# num_of_examples 71
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.654701579523
# best_split_mid_value 0.36045
# 0 level 10
# class_counts malignant 29
# benign 34
# Entropy 0.689994458033
# predict_class 1
# num_of_examples 63
# is_leaf False
# selected_feature worst texture
# selected_feature_index 21
# max_info_gain 0.539914285867
# best_split_mid_value 21.31
# 0 level 11
# class_counts benign 13
# Entropy 0.0
# predict_class 1
# num_of_examples 13
# is_leaf True
# 1 level 11
# class_counts malignant 29
# benign 21
# Entropy 0.680292000192
# predict_class 0
# num_of_examples 50
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.551686619127
# best_split_mid_value 19.455
# 0 level 12
# class_counts malignant 9
# benign 17
# Entropy 0.645033151676
# predict_class 1
# num_of_examples 26
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.551579623027
# best_split_mid_value 0.023165
# 0 level 13
# class_counts benign 5
# Entropy 0.0
# predict_class 1
# num_of_examples 5
# is_leaf True
# 1 level 13
# class_counts malignant 9
# benign 12
# Entropy 0.6829081047
# predict_class 1
# num_of_examples 21
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.594126154766
# best_split_mid_value 0.035305
# 0 level 14
# class_counts malignant 9
# benign 9
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 18
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.560843055841
# best_split_mid_value 0.20645
# 0 level 15
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 15
# class_counts malignant 9
# benign 6
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 15
# is_leaf False
# selected_feature worst concavity
# selected_feature_index 26
# max_info_gain 0.554517744448
# best_split_mid_value 0.3817
# 0 level 16
# class_counts malignant 6
# benign 6
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 12
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.477385626221
# best_split_mid_value 0.1213
# 0 level 17
# class_counts malignant 3
# benign 6
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.318979358669
# best_split_mid_value 0.014995
# 0 level 18
# class_counts malignant 1
# benign 6
# Entropy 0.410116318288
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature worst concave points
# selected_feature_index 27
# max_info_gain 0.321334368354
# best_split_mid_value 0.11155
# 0 level 19
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 19
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean concavity
# selected_feature_index 6
# max_info_gain 0.34657359028
# best_split_mid_value 0.08727
# 0 level 20
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 20
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.885
# 0 level 21
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 21
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 18
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 17
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 16
# class_counts malignant 3
# Entropy 0.0
# predict_class 0
# num_of_examples 3
# is_leaf True
# 1 level 14
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 12
# class_counts malignant 20
# benign 4
# Entropy 0.450561208866
# predict_class 0
# num_of_examples 24
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.199181530538
# best_split_mid_value 0.013755
# 0 level 13
# class_counts malignant 3
# benign 4
# Entropy 0.6829081047
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature worst compactness
# selected_feature_index 25
# max_info_gain 0.321334368354
# best_split_mid_value 0.1906
# 0 level 14
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 14
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature worst concave points
# selected_feature_index 27
# max_info_gain 0.34657359028
# best_split_mid_value 0.14685
# 0 level 15
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.31
# 0 level 16
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 16
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 15
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 17
# Entropy 0.0
# predict_class 0
# num_of_examples 17
# is_leaf True
# 1 level 10
# class_counts malignant 7
# benign 1
# Entropy 0.376770161256
# predict_class 0
# num_of_examples 8
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.17328679514
# best_split_mid_value 0.02258
# 0 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 16.085
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 6
# Entropy 0.0
# predict_class 0
# num_of_examples 6
# is_leaf True
# 1 level 6
# class_counts malignant 22
# benign 7
# Entropy 0.552664622494
# predict_class 0
# num_of_examples 29
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.501663292954
# best_split_mid_value 0.0154625
# 0 level 7
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 22
# benign 6
# Entropy 0.519579839131
# predict_class 0
# num_of_examples 28
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.409187679618
# best_split_mid_value 0.01563
# 0 level 8
# class_counts malignant 12
# benign 6
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 18
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.449067300155
# best_split_mid_value 0.1354
# 0 level 9
# class_counts malignant 1
# benign 4
# Entropy 0.500402423538
# predict_class 1
# num_of_examples 5
# is_leaf False
# selected_feature worst symmetry
# selected_feature_index 28
# max_info_gain 0.381908500977
# best_split_mid_value 0.2711
# 0 level 10
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 10
# class_counts malignant 1
# benign 2
# Entropy 0.636514168295
# predict_class 1
# num_of_examples 3
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.462098120373
# best_split_mid_value 0.090485
# 0 level 11
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.015
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 11
# benign 2
# Entropy 0.429323021931
# predict_class 0
# num_of_examples 13
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.366719676271
# best_split_mid_value 0.1616
# 0 level 10
# class_counts malignant 7
# benign 2
# Entropy 0.529706199058
# predict_class 0
# num_of_examples 9
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.373895370561
# best_split_mid_value 13.6
# 0 level 11
# class_counts malignant 3
# benign 2
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 5
# is_leaf False
# selected_feature mean perimeter
# selected_feature_index 2
# max_info_gain 0.449868115695
# best_split_mid_value 80.895
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature mean area
# selected_feature_index 3
# max_info_gain 0.34657359028
# best_split_mid_value 509.5
# 0 level 13
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 13
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.0
# best_split_mid_value 18.07
# 0 level 14
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 14
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 4
# Entropy 0.0
# predict_class 0
# num_of_examples 4
# is_leaf True
# 1 level 10
# class_counts malignant 4
# Entropy 0.0
# predict_class 0
# num_of_examples 4
# is_leaf True
# 1 level 8
# class_counts malignant 10
# Entropy 0.0
# predict_class 0
# num_of_examples 10
# is_leaf True
# 1 level 3
# class_counts malignant 21
# benign 14
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 35
# is_leaf False
# selected_feature fractal dimension error
# selected_feature_index 19
# max_info_gain 0.618025672536
# best_split_mid_value 0.01291
# 0 level 4
# class_counts malignant 21
# benign 12
# Entropy 0.655481773901
# predict_class 0
# num_of_examples 33
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.60298670372
# best_split_mid_value 0.14705
# 0 level 5
# class_counts malignant 7
# benign 8
# Entropy 0.690923309314
# predict_class 1
# num_of_examples 15
# is_leaf False
# selected_feature concavity error
# selected_feature_index 16
# max_info_gain 0.579104551803
# best_split_mid_value 0.05737
# 0 level 6
# class_counts malignant 2
# benign 6
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 8
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.358851778502
# best_split_mid_value 16.105
# 0 level 7
# class_counts malignant 1
# benign 6
# Entropy 0.410116318288
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature mean texture
# selected_feature_index 1
# max_info_gain 0.321334368354
# best_split_mid_value 16.38
# 0 level 8
# class_counts benign 3
# Entropy 0.0
# predict_class 1
# num_of_examples 3
# is_leaf True
# 1 level 8
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean perimeter
# selected_feature_index 2
# max_info_gain 0.34657359028
# best_split_mid_value 80.23
# 0 level 9
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean area
# selected_feature_index 3
# max_info_gain 0.0
# best_split_mid_value 356.25
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 7
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 5
# benign 2
# Entropy 0.598269588585
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.480722619292
# best_split_mid_value 0.23635
# 0 level 7
# class_counts malignant 3
# benign 2
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 5
# is_leaf False
# selected_feature texture error
# selected_feature_index 11
# max_info_gain 0.449868115695
# best_split_mid_value 1.827
# 0 level 8
# class_counts malignant 3
# benign 1
# Entropy 0.562335144619
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.34657359028
# best_split_mid_value 0.09997
# 0 level 9
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 15.025
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 2
# Entropy 0.0
# predict_class 0
# num_of_examples 2
# is_leaf True
# 1 level 5
# class_counts malignant 14
# benign 4
# Entropy 0.529706199058
# predict_class 0
# num_of_examples 18
# is_leaf False
# selected_feature mean smoothness
# selected_feature_index 4
# max_info_gain 0.440110409352
# best_split_mid_value 0.10555
# 0 level 6
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 14
# benign 3
# Entropy 0.465999256961
# predict_class 0
# num_of_examples 17
# is_leaf False
# selected_feature radius error
# selected_feature_index 10
# max_info_gain 0.354607210594
# best_split_mid_value 0.18895
# 0 level 7
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 14
# benign 2
# Entropy 0.376770161256
# predict_class 0
# num_of_examples 16
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.311797208046
# best_split_mid_value 0.19995
# 0 level 8
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 11.2205
# 0 level 9
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 13
# benign 1
# Entropy 0.257318640544
# predict_class 0
# num_of_examples 14
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.205058159144
# best_split_mid_value 0.22575
# 0 level 9
# class_counts malignant 6
# benign 1
# Entropy 0.410116318288
# predict_class 0
# num_of_examples 7
# is_leaf False
# selected_feature perimeter error
# selected_feature_index 12
# max_info_gain 0.272791786412
# best_split_mid_value 2.9465
# 0 level 10
# class_counts malignant 4
# Entropy 0.0
# predict_class 0
# num_of_examples 4
# is_leaf True
# 1 level 10
# class_counts malignant 2
# benign 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature texture error
# selected_feature_index 11
# max_info_gain 0.462098120373
# best_split_mid_value 1.0118
# 0 level 11
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 11
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 11.539
# 0 level 12
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 12
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 7
# Entropy 0.0
# predict_class 0
# num_of_examples 7
# is_leaf True
# 1 level 4
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 2
# class_counts malignant 5
# benign 31
# Entropy 0.402941357867
# predict_class 1
# num_of_examples 36
# is_leaf False
# selected_feature fractal dimension error
# selected_feature_index 19
# max_info_gain 0.359374217946
# best_split_mid_value 0.003923
# 0 level 3
# class_counts benign 9
# Entropy 0.0
# predict_class 1
# num_of_examples 9
# is_leaf True
# 1 level 3
# class_counts malignant 5
# benign 22
# Entropy 0.479165623928
# predict_class 1
# num_of_examples 27
# is_leaf False
# selected_feature worst smoothness
# selected_feature_index 24
# max_info_gain 0.417852451879
# best_split_mid_value 0.12535
# 0 level 4
# class_counts malignant 3
# benign 4
# Entropy 0.6829081047
# predict_class 1
# num_of_examples 7
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.594126154766
# best_split_mid_value 0.085325
# 0 level 5
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts malignant 3
# benign 3
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 6
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.560843055841
# best_split_mid_value 0.13065
# 0 level 6
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 3
# benign 2
# Entropy 0.673011667009
# predict_class 0
# num_of_examples 5
# is_leaf False
# selected_feature concave points error
# selected_feature_index 17
# max_info_gain 0.554517744448
# best_split_mid_value 0.015865
# 0 level 7
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts malignant 2
# benign 2
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 4
# is_leaf False
# selected_feature texture error
# selected_feature_index 11
# max_info_gain 0.477385626221
# best_split_mid_value 1.2596
# 0 level 8
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 8
# class_counts malignant 2
# benign 1
# Entropy 0.636514168295
# predict_class 0
# num_of_examples 3
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.462098120373
# best_split_mid_value 0.061795
# 0 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 14.34
# 0 level 10
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 10
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 4
# class_counts malignant 2
# benign 18
# Entropy 0.325082973391
# predict_class 1
# num_of_examples 20
# is_leaf False
# selected_feature worst fractal dimension
# selected_feature_index 29
# max_info_gain 0.262417957715
# best_split_mid_value 0.080625
# 0 level 5
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 18.89
# 0 level 6
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 6
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 5
# class_counts malignant 1
# benign 17
# Entropy 0.214559155176
# predict_class 1
# num_of_examples 18
# is_leaf False
# selected_feature compactness error
# selected_feature_index 15
# max_info_gain 0.174416047922
# best_split_mid_value 0.03277
# 0 level 6
# class_counts benign 9
# Entropy 0.0
# predict_class 1
# num_of_examples 9
# is_leaf True
# 1 level 6
# class_counts malignant 1
# benign 8
# Entropy 0.348832095843
# predict_class 1
# num_of_examples 9
# is_leaf False
# selected_feature mean symmetry
# selected_feature_index 8
# max_info_gain 0.249926730942
# best_split_mid_value 0.1878
# 0 level 7
# class_counts malignant 1
# benign 3
# Entropy 0.562335144619
# predict_class 1
# num_of_examples 4
# is_leaf False
# selected_feature mean compactness
# selected_feature_index 5
# max_info_gain 0.34657359028
# best_split_mid_value 0.11935
# 0 level 8
# class_counts benign 2
# Entropy 0.0
# predict_class 1
# num_of_examples 2
# is_leaf True
# 1 level 8
# class_counts malignant 1
# benign 1
# Entropy 0.69314718056
# predict_class 0
# num_of_examples 2
# is_leaf False
# selected_feature mean radius
# selected_feature_index 0
# max_info_gain 0.0
# best_split_mid_value 11.837
# 0 level 9
# class_counts benign 1
# Entropy 0.0
# predict_class 1
# num_of_examples 1
# is_leaf True
# 1 level 9
# class_counts malignant 1
# Entropy 0.0
# predict_class 0
# num_of_examples 1
# is_leaf True
# 1 level 7
# class_counts benign 5
# Entropy 0.0
# predict_class 1
# num_of_examples 5
# is_leaf True

# %%
for i in range(len(X)):
    print("Example", i)
    pred = predict_single(X[i], tree_dict)

    print("\tActual Class:", class_dict[Y[i]])
    print("\tPredicted Class:", class_dict[pred])
# Out:
# Example 0
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 1
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 2
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 3
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 4
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 5
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 6
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 7
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 8
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 9
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 10
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 11
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 12
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 13
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 14
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 15
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 16
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 17
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 18
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 19
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 20
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 21
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 22
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 23
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 24
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 25
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 26
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 27
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 28
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 29
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 30
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 31
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 32
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 33
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 34
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 35
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 36
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 37
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 38
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 39
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 40
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 41
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 42
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 43
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 44
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 45
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 46
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 47
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 48
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 49
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 50
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 51
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 52
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 53
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 54
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 55
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 56
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 57
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 58
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 59
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 60
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 61
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 62
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 63
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 64
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 65
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 66
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 67
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 68
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 69
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 70
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 71
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 72
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 73
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 74
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 75
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 76
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 77
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 78
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 79
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 80
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 81
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 82
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 83
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 84
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 85
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 86
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 87
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 88
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 89
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 90
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 91
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 92
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 93
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 94
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 95
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 96
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 97
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 98
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 99
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 100
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 101
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 102
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 103
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 104
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 105
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 106
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 107
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 108
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 109
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 110
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 111
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 112
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 113
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 114
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 115
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 116
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 117
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 118
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 119
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 120
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 121
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 122
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 123
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 124
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 125
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 126
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 127
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 128
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 129
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 130
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 131
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 132
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 133
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 134
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 135
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 136
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 137
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 138
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 139
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 140
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 141
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 142
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 143
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 144
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 145
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 146
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 147
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 148
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 149
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 150
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 151
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 152
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 153
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 154
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 155
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 156
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 157
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 158
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 159
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 160
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 161
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 162
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 163
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 164
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 165
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 166
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 167
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 168
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 169
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 170
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 171
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 172
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 173
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 174
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 175
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 176
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 177
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 178
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 179
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 180
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 181
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 182
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 183
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 184
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 185
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 186
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 187
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 188
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 189
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 190
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 191
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 192
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 193
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 194
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 195
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 196
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 197
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 198
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 199
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 200
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 201
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 202
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 203
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 204
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 205
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 206
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 207
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 208
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 209
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 210
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 211
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 212
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 213
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 214
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 215
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 216
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 217
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 218
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 219
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 220
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 221
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 222
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 223
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 224
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 225
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 226
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 227
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 228
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 229
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 230
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 231
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 232
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 233
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 234
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 235
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 236
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 237
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 238
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 239
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 240
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 241
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 242
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 243
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 244
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 245
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 246
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 247
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 248
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 249
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 250
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 251
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 252
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 253
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 254
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 255
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 256
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 257
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 258
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 259
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 260
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 261
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 262
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 263
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 264
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 265
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 266
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 267
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 268
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 269
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 270
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 271
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 272
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 273
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 274
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 275
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 276
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 277
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 278
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 279
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 280
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 281
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 282
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 283
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 284
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 285
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 286
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 287
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 288
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 289
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 290
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 291
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 292
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 293
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 294
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 295
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 296
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 297
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 298
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 299
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 300
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 301
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 302
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 303
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 304
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 305
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 306
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 307
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 308
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 309
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 310
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 311
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 312
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 313
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 314
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 315
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 316
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 317
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 318
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 319
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 320
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 321
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 322
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 323
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 324
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 325
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 326
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 327
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 328
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 329
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 330
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 331
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 332
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 333
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 334
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 335
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 336
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 337
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 338
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 339
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 340
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 341
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 342
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 343
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 344
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 345
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 346
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 347
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 348
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 349
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 350
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 351
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 352
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 353
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 354
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 355
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 356
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 357
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 358
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 359
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 360
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 361
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 362
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 363
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 364
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 365
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 366
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 367
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 368
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 369
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 370
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 371
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 372
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 373
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 374
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 375
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 376
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 377
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 378
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 379
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 380
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 381
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 382
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 383
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 384
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 385
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 386
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 387
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 388
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 389
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 390
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 391
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 392
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 393
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 394
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 395
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 396
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 397
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 398
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 399
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 400
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 401
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 402
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 403
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 404
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 405
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 406
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 407
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 408
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 409
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 410
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 411
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 412
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 413
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 414
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 415
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 416
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 417
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 418
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 419
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 420
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 421
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 422
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 423
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 424
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 425
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 426
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 427
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 428
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 429
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 430
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 431
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 432
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 433
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 434
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 435
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 436
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 437
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 438
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 439
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 440
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 441
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 442
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 443
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 444
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 445
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 446
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 447
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 448
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 449
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 450
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 451
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 452
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 453
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 454
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 455
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 456
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 457
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 458
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 459
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 460
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 461
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 462
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 463
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 464
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 465
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 466
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 467
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 468
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 469
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 470
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 471
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 472
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 473
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 474
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 475
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 476
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 477
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 478
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 479
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 480
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 481
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 482
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 483
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 484
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 485
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 486
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 487
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 488
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 489
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 490
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 491
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 492
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 493
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 494
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 495
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 496
# 	Actual Class: benign
# 	Predicted Class: malignant
# Example 497
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 498
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 499
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 500
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 501
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 502
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 503
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 504
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 505
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 506
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 507
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 508
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 509
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 510
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 511
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 512
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 513
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 514
# 	Actual Class: malignant
# 	Predicted Class: benign
# Example 515
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 516
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 517
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 518
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 519
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 520
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 521
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 522
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 523
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 524
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 525
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 526
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 527
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 528
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 529
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 530
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 531
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 532
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 533
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 534
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 535
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 536
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 537
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 538
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 539
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 540
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 541
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 542
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 543
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 544
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 545
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 546
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 547
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 548
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 549
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 550
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 551
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 552
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 553
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 554
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 555
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 556
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 557
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 558
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 559
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 560
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 561
# 	Actual Class: benign
# 	Predicted Class: benign
# Example 562
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 563
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 564
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 565
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 566
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 567
# 	Actual Class: malignant
# 	Predicted Class: malignant
# Example 568
# 	Actual Class: benign
# 	Predicted Class: benign

# %%
import matplotlib.pyplot as plt

def get_lines(indices, Y_pred, Y):
    lines = []
    for i in indices :
        if Y_pred[i] != Y[i] :
            line = [[i, i], [Y_pred[i], Y[i]]]
            lines.append(line)
    return lines

indices = np.arange(len(Y_train))
Y_train_pred = predict(X_train, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_train), -1, len(class_dict)))
plt.scatter(indices, Y_train_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_train, c = Y_train)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_train_pred, Y_train)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
    
plt.legend()
plt.show()

indices = np.arange(len(Y_test))

Y_test_pred = predict(X_test, tree_dict)
plt.figure(figsize = (10, 7))
plt.title("Predicted vs Actual Class Labels")
plt.axis((-1,len(X_test), -1, len(class_dict)))
plt.scatter(indices, Y_test_pred, c = 'r', label = "Wrong Prediction")
plt.scatter(indices, Y_test, c = Y_test)
plt.xlabel("Example Number")
plt.ylabel("Class")
lines = get_lines(indices, Y_test_pred, Y_test)

for line in lines:
    line_X = line[0]
    line_Y = line[1]
    plt.plot(line_X, line_Y, c = 'black', linestyle = "dashed")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix for Y_train\n", confusion_matrix(Y_train, Y_train_pred))
print("Confusion Matrix for Y_test\n", confusion_matrix(Y_test, Y_test_pred))
# Out:
# Confusion Matrix for Y_train
#  [[157   0]
#  [  0 269]]
# Confusion Matrix for Y_test
#  [[39 16]
#  [ 8 80]]

# %%
# Level order traversal

def print_node(node):
    for key, val in node.items() :
        if not isinstance(val, dict) :
            print(key, ":", val)
    
def print_tree_level_order(tree_dict):
    from collections import deque
    q = deque([tree_dict])
    while len(q)!= 0 :
        node = q.popleft()
        print("*" * 100)
        print("Len", len(q))
        print("*" * 100)
        if 0 in node.keys() :
            q.append(node[0])
            
        if 1 in node.keys() :
            q.append(node[1])
        print_node(node)

print_tree_level_order(tree_dict)
# Out:
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 0
# Entropy : 0.65817654685
# predict_class : 1
# num_of_examples : 426
# is_leaf : False
# selected_feature : symmetry error
# selected_feature_index : 18
# max_info_gain : 0.64726392017
# best_split_mid_value : 0.015595
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 1
# Entropy : 0.692081713342
# predict_class : 1
# num_of_examples : 130
# is_leaf : False
# selected_feature : mean fractal dimension
# selected_feature_index : 9
# max_info_gain : 0.674696360291
# best_split_mid_value : 0.072915
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 1
# Entropy : 0.627580429926
# predict_class : 1
# num_of_examples : 296
# is_leaf : False
# selected_feature : smoothness error
# selected_feature_index : 14
# max_info_gain : 0.615589555132
# best_split_mid_value : 0.010845
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 2
# Entropy : 0.690634069589
# predict_class : 1
# num_of_examples : 127
# is_leaf : False
# selected_feature : texture error
# selected_feature_index : 11
# max_info_gain : 0.666141558023
# best_split_mid_value : 0.54415
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 2
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 2
# Entropy : 0.645033151676
# predict_class : 1
# num_of_examples : 260
# is_leaf : False
# selected_feature : mean fractal dimension
# selected_feature_index : 9
# max_info_gain : 0.624027357281
# best_split_mid_value : 0.070105
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 2
# Entropy : 0.402941357867
# predict_class : 1
# num_of_examples : 36
# is_leaf : False
# selected_feature : fractal dimension error
# selected_feature_index : 19
# max_info_gain : 0.359374217946
# best_split_mid_value : 0.003923
# ****************************************************************************************************
# Len 5
# ****************************************************************************************************
# level : 3
# Entropy : 0.429323021931
# predict_class : 1
# num_of_examples : 13
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.384924941183
# best_split_mid_value : 0.14875
# ****************************************************************************************************
# Len 6
# ****************************************************************************************************
# level : 3
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 114
# is_leaf : False
# selected_feature : smoothness error
# selected_feature_index : 14
# max_info_gain : 0.664857008713
# best_split_mid_value : 0.003968
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 3
# Entropy : 0.616407575768
# predict_class : 1
# num_of_examples : 225
# is_leaf : False
# selected_feature : texture error
# selected_feature_index : 11
# max_info_gain : 0.597951669984
# best_split_mid_value : 0.5491
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 3
# Entropy : 0.673011667009
# predict_class : 0
# num_of_examples : 35
# is_leaf : False
# selected_feature : fractal dimension error
# selected_feature_index : 19
# max_info_gain : 0.618025672536
# best_split_mid_value : 0.01291
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 3
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 9
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 3
# Entropy : 0.479165623928
# predict_class : 1
# num_of_examples : 27
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.417852451879
# best_split_mid_value : 0.12535
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 4
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 4
# Entropy : 0.500402423538
# predict_class : 1
# num_of_examples : 10
# is_leaf : False
# selected_feature : smoothness error
# selected_feature_index : 14
# max_info_gain : 0.440045565117
# best_split_mid_value : 0.0034855
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 4
# Entropy : 0.450561208866
# predict_class : 1
# num_of_examples : 12
# is_leaf : False
# selected_feature : area error
# selected_feature_index : 13
# max_info_gain : 0.397279649293
# best_split_mid_value : 13.2
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 4
# Entropy : 0.690068279283
# predict_class : 0
# num_of_examples : 102
# is_leaf : False
# selected_feature : fractal dimension error
# selected_feature_index : 19
# max_info_gain : 0.655993131292
# best_split_mid_value : 0.001795
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 4
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 11
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 4
# Entropy : 0.628687503488
# predict_class : 1
# num_of_examples : 214
# is_leaf : False
# selected_feature : fractal dimension error
# selected_feature_index : 19
# max_info_gain : 0.564658421512
# best_split_mid_value : 0.002491
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 4
# Entropy : 0.655481773901
# predict_class : 0
# num_of_examples : 33
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.60298670372
# best_split_mid_value : 0.14705
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 4
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 4
# Entropy : 0.6829081047
# predict_class : 1
# num_of_examples : 7
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.594126154766
# best_split_mid_value : 0.085325
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 4
# Entropy : 0.325082973391
# predict_class : 1
# num_of_examples : 20
# is_leaf : False
# selected_feature : worst fractal dimension
# selected_feature_index : 29
# max_info_gain : 0.262417957715
# best_split_mid_value : 0.080625
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 5
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 15.1
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.376770161256
# predict_class : 1
# num_of_examples : 8
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.281167572309
# best_split_mid_value : 0.089395
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 5
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 5
# Entropy : 0.529706199058
# predict_class : 1
# num_of_examples : 9
# is_leaf : False
# selected_feature : mean perimeter
# selected_feature_index : 2
# max_info_gain : 0.47301206546
# best_split_mid_value : 85.83
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 5
# Entropy : 0.598269588585
# predict_class : 1
# num_of_examples : 21
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.504048181454
# best_split_mid_value : 0.1509
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 5
# Entropy : 0.670958494216
# predict_class : 0
# num_of_examples : 81
# is_leaf : False
# selected_feature : worst fractal dimension
# selected_feature_index : 29
# max_info_gain : 0.627683367345
# best_split_mid_value : 0.088705
# ****************************************************************************************************
# Len 17
# ****************************************************************************************************
# level : 5
# Entropy : 0.280342258775
# predict_class : 1
# num_of_examples : 62
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.270241699261
# best_split_mid_value : 0.1043
# ****************************************************************************************************
# Len 18
# ****************************************************************************************************
# level : 5
# Entropy : 0.680629487892
# predict_class : 1
# num_of_examples : 152
# is_leaf : False
# selected_feature : worst fractal dimension
# selected_feature_index : 29
# max_info_gain : 0.624956870176
# best_split_mid_value : 0.093935
# ****************************************************************************************************
# Len 19
# ****************************************************************************************************
# level : 5
# Entropy : 0.690923309314
# predict_class : 1
# num_of_examples : 15
# is_leaf : False
# selected_feature : concavity error
# selected_feature_index : 16
# max_info_gain : 0.579104551803
# best_split_mid_value : 0.05737
# ****************************************************************************************************
# Len 20
# ****************************************************************************************************
# level : 5
# Entropy : 0.529706199058
# predict_class : 0
# num_of_examples : 18
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.440110409352
# best_split_mid_value : 0.10555
# ****************************************************************************************************
# Len 21
# ****************************************************************************************************
# level : 5
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 20
# ****************************************************************************************************
# level : 5
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 6
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.560843055841
# best_split_mid_value : 0.13065
# ****************************************************************************************************
# Len 21
# ****************************************************************************************************
# level : 5
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 18.89
# ****************************************************************************************************
# Len 22
# ****************************************************************************************************
# level : 5
# Entropy : 0.214559155176
# predict_class : 1
# num_of_examples : 18
# is_leaf : False
# selected_feature : compactness error
# selected_feature_index : 15
# max_info_gain : 0.174416047922
# best_split_mid_value : 0.03277
# ****************************************************************************************************
# Len 23
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 22
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 21
# ****************************************************************************************************
# level : 6
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.10274
# ****************************************************************************************************
# Len 22
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 4
# is_leaf : True
# ****************************************************************************************************
# Len 21
# ****************************************************************************************************
# level : 6
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 13.185
# ****************************************************************************************************
# Len 22
# ****************************************************************************************************
# level : 6
# Entropy : 0.410116318288
# predict_class : 1
# num_of_examples : 7
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.321334368354
# best_split_mid_value : 0.05471
# ****************************************************************************************************
# Len 23
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 5
# is_leaf : True
# ****************************************************************************************************
# Len 22
# ****************************************************************************************************
# level : 6
# Entropy : 0.661563238158
# predict_class : 1
# num_of_examples : 16
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.560775861765
# best_split_mid_value : 0.085155
# ****************************************************************************************************
# Len 23
# ****************************************************************************************************
# level : 6
# Entropy : 0.692981882196
# predict_class : 0
# num_of_examples : 55
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.6525391846
# best_split_mid_value : 0.08086
# ****************************************************************************************************
# Len 24
# ****************************************************************************************************
# level : 6
# Entropy : 0.489551893623
# predict_class : 0
# num_of_examples : 26
# is_leaf : False
# selected_feature : concave points error
# selected_feature_index : 17
# max_info_gain : 0.415977966699
# best_split_mid_value : 0.0089485
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 6
# Entropy : 0.304636097349
# predict_class : 1
# num_of_examples : 55
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.283043522318
# best_split_mid_value : 0.1475
# ****************************************************************************************************
# Len 26
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 7
# is_leaf : True
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 6
# Entropy : 0.642001383857
# predict_class : 1
# num_of_examples : 123
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.582518592329
# best_split_mid_value : 0.17195
# ****************************************************************************************************
# Len 26
# ****************************************************************************************************
# level : 6
# Entropy : 0.552664622494
# predict_class : 0
# num_of_examples : 29
# is_leaf : False
# selected_feature : concavity error
# selected_feature_index : 16
# max_info_gain : 0.501663292954
# best_split_mid_value : 0.0154625
# ****************************************************************************************************
# Len 27
# ****************************************************************************************************
# level : 6
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 8
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.358851778502
# best_split_mid_value : 16.105
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 6
# Entropy : 0.598269588585
# predict_class : 0
# num_of_examples : 7
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.480722619292
# best_split_mid_value : 0.23635
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 6
# Entropy : 0.465999256961
# predict_class : 0
# num_of_examples : 17
# is_leaf : False
# selected_feature : radius error
# selected_feature_index : 10
# max_info_gain : 0.354607210594
# best_split_mid_value : 0.18895
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 6
# Entropy : 0.673011667009
# predict_class : 0
# num_of_examples : 5
# is_leaf : False
# selected_feature : concave points error
# selected_feature_index : 17
# max_info_gain : 0.554517744448
# best_split_mid_value : 0.015865
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 27
# ****************************************************************************************************
# level : 6
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 9
# is_leaf : True
# ****************************************************************************************************
# Len 26
# ****************************************************************************************************
# level : 6
# Entropy : 0.348832095843
# predict_class : 1
# num_of_examples : 9
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.249926730942
# best_split_mid_value : 0.1878
# ****************************************************************************************************
# Len 27
# ****************************************************************************************************
# level : 7
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 14.2
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 27
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 26
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 24
# ****************************************************************************************************
# level : 7
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.34657359028
# best_split_mid_value : 14.675
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 24
# ****************************************************************************************************
# level : 7
# Entropy : 0.690185676019
# predict_class : 1
# num_of_examples : 13
# is_leaf : False
# selected_feature : worst fractal dimension
# selected_feature_index : 29
# max_info_gain : 0.639828166671
# best_split_mid_value : 0.064715
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 24
# ****************************************************************************************************
# level : 7
# Entropy : 0.690185676019
# predict_class : 0
# num_of_examples : 52
# is_leaf : False
# selected_feature : compactness error
# selected_feature_index : 15
# max_info_gain : 0.626947630146
# best_split_mid_value : 0.008665
# ****************************************************************************************************
# Len 25
# ****************************************************************************************************
# level : 7
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 3
# is_leaf : False
# selected_feature : mean texture
# selected_feature_index : 1
# max_info_gain : 0.462098120373
# best_split_mid_value : 17.525
# ****************************************************************************************************
# Len 26
# ****************************************************************************************************
# level : 7
# Entropy : 0.387212375186
# predict_class : 0
# num_of_examples : 23
# is_leaf : False
# selected_feature : worst concavity
# selected_feature_index : 26
# max_info_gain : 0.355331806907
# best_split_mid_value : 0.48345
# ****************************************************************************************************
# Len 27
# ****************************************************************************************************
# level : 7
# Entropy : 0.267567912573
# predict_class : 1
# num_of_examples : 53
# is_leaf : False
# selected_feature : worst fractal dimension
# selected_feature_index : 29
# max_info_gain : 0.220356759604
# best_split_mid_value : 0.05979
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 7
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 15.37
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 7
# Entropy : 0.370794716787
# predict_class : 1
# num_of_examples : 41
# is_leaf : False
# selected_feature : worst symmetry
# selected_feature_index : 28
# max_info_gain : 0.348361925941
# best_split_mid_value : 0.28895
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 7
# Entropy : 0.6883805301
# predict_class : 1
# num_of_examples : 82
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.655272969685
# best_split_mid_value : 0.1092
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 7
# Entropy : 0.519579839131
# predict_class : 0
# num_of_examples : 28
# is_leaf : False
# selected_feature : concave points error
# selected_feature_index : 17
# max_info_gain : 0.409187679618
# best_split_mid_value : 0.01563
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.410116318288
# predict_class : 1
# num_of_examples : 7
# is_leaf : False
# selected_feature : mean texture
# selected_feature_index : 1
# max_info_gain : 0.321334368354
# best_split_mid_value : 16.38
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.673011667009
# predict_class : 0
# num_of_examples : 5
# is_leaf : False
# selected_feature : texture error
# selected_feature_index : 11
# max_info_gain : 0.449868115695
# best_split_mid_value : 1.827
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 7
# Entropy : 0.376770161256
# predict_class : 0
# num_of_examples : 16
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.311797208046
# best_split_mid_value : 0.19995
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 7
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : texture error
# selected_feature_index : 11
# max_info_gain : 0.477385626221
# best_split_mid_value : 1.2596
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 7
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.11935
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 7
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 5
# is_leaf : True
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean texture
# selected_feature_index : 1
# max_info_gain : 0.0
# best_split_mid_value : 17.12
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 12
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.560843055841
# best_split_mid_value : 0.06213
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 4
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 8
# Entropy : 0.679193265992
# predict_class : 0
# num_of_examples : 48
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.619254750207
# best_split_mid_value : 0.1754
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 28
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 13.535
# ****************************************************************************************************
# Len 29
# ****************************************************************************************************
# level : 8
# Entropy : 0.562335144619
# predict_class : 0
# num_of_examples : 8
# is_leaf : False
# selected_feature : worst compactness
# selected_feature_index : 25
# max_info_gain : 0.51120770179
# best_split_mid_value : 0.29175
# ****************************************************************************************************
# Len 30
# ****************************************************************************************************
# level : 8
# Entropy : 0.244930026795
# predict_class : 0
# num_of_examples : 15
# is_leaf : False
# selected_feature : perimeter error
# selected_feature_index : 12
# max_info_gain : 0.191387615201
# best_split_mid_value : 3.4175
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 8
# Entropy : 0.673011667009
# predict_class : 1
# num_of_examples : 5
# is_leaf : False
# selected_feature : mean texture
# selected_feature_index : 1
# max_info_gain : 0.381908500977
# best_split_mid_value : 22.18
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 8
# Entropy : 0.173205206749
# predict_class : 1
# num_of_examples : 48
# is_leaf : False
# selected_feature : mean symmetry
# selected_feature_index : 8
# max_info_gain : 0.145192381129
# best_split_mid_value : 0.1712
# ****************************************************************************************************
# Len 33
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 31
# ****************************************************************************************************
# level : 8
# Entropy : 0.330680630832
# predict_class : 1
# num_of_examples : 39
# is_leaf : False
# selected_feature : compactness error
# selected_feature_index : 15
# max_info_gain : 0.309144747698
# best_split_mid_value : 0.01004
# ****************************************************************************************************
# Len 32
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 17.345
# ****************************************************************************************************
# Len 33
# ****************************************************************************************************
# level : 8
# Entropy : 0.348832095843
# predict_class : 1
# num_of_examples : 9
# is_leaf : False
# selected_feature : worst symmetry
# selected_feature_index : 28
# max_info_gain : 0.27800134641
# best_split_mid_value : 0.2763
# ****************************************************************************************************
# Len 34
# ****************************************************************************************************
# level : 8
# Entropy : 0.693053351391
# predict_class : 1
# num_of_examples : 73
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.67406037443
# best_split_mid_value : 0.08331
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 8
# Entropy : 0.636514168295
# predict_class : 0
# num_of_examples : 18
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.449067300155
# best_split_mid_value : 0.1354
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 10
# is_leaf : True
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 34
# ****************************************************************************************************
# level : 8
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean perimeter
# selected_feature_index : 2
# max_info_gain : 0.34657359028
# best_split_mid_value : 80.23
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 8
# Entropy : 0.562335144619
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.09997
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 11.2205
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 8
# Entropy : 0.257318640544
# predict_class : 0
# num_of_examples : 14
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.205058159144
# best_split_mid_value : 0.22575
# ****************************************************************************************************
# Len 37
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 8
# Entropy : 0.636514168295
# predict_class : 0
# num_of_examples : 3
# is_leaf : False
# selected_feature : compactness error
# selected_feature_index : 15
# max_info_gain : 0.462098120373
# best_split_mid_value : 0.061795
# ****************************************************************************************************
# Len 37
# ****************************************************************************************************
# level : 8
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 8
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 11.837
# ****************************************************************************************************
# Len 37
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 34
# ****************************************************************************************************
# level : 9
# Entropy : 0.673011667009
# predict_class : 0
# num_of_examples : 10
# is_leaf : False
# selected_feature : worst symmetry
# selected_feature_index : 28
# max_info_gain : 0.572862751465
# best_split_mid_value : 0.24105
# ****************************************************************************************************
# Len 35
# ****************************************************************************************************
# level : 9
# Entropy : 0.687786822992
# predict_class : 1
# num_of_examples : 29
# is_leaf : False
# selected_feature : concavity error
# selected_feature_index : 16
# max_info_gain : 0.621690257742
# best_split_mid_value : 0.01928
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 9
# Entropy : 0.514653165429
# predict_class : 0
# num_of_examples : 19
# is_leaf : False
# selected_feature : concave points error
# selected_feature_index : 17
# max_info_gain : 0.440830223168
# best_split_mid_value : 0.013705
# ****************************************************************************************************
# Len 37
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 36
# ****************************************************************************************************
# level : 9
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# ...
# ****************************************************************************************************
# Len 18
# ****************************************************************************************************
# level : 14
# Entropy : 0.562335144619
# predict_class : 0
# num_of_examples : 4
# is_leaf : False
# selected_feature : worst concave points
# selected_feature_index : 27
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.14685
# ****************************************************************************************************
# Len 19
# ****************************************************************************************************
# level : 14
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 18
# ****************************************************************************************************
# level : 14
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 17
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 16
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 15
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 15
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 3
# is_leaf : False
# selected_feature : radius error
# selected_feature_index : 10
# max_info_gain : 0.462098120373
# best_split_mid_value : 0.2696
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 15
# Entropy : 0.636514168295
# predict_class : 0
# num_of_examples : 3
# is_leaf : False
# selected_feature : mean texture
# selected_feature_index : 1
# max_info_gain : 0.462098120373
# best_split_mid_value : 17.435
# ****************************************************************************************************
# Len 14
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 13
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 12
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 4
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 15
# Entropy : 0.500402423538
# predict_class : 1
# num_of_examples : 5
# is_leaf : False
# selected_feature : worst smoothness
# selected_feature_index : 24
# max_info_gain : 0.381908500977
# best_split_mid_value : 0.12455
# ****************************************************************************************************
# Len 11
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 15
# Entropy : 0.673011667009
# predict_class : 0
# num_of_examples : 15
# is_leaf : False
# selected_feature : worst concavity
# selected_feature_index : 26
# max_info_gain : 0.554517744448
# best_split_mid_value : 0.3817
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 15
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 14.31
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 15
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 16
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 16.535
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 16
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 15.7
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 16
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 3
# is_leaf : False
# selected_feature : mean smoothness
# selected_feature_index : 4
# max_info_gain : 0.462098120373
# best_split_mid_value : 0.090575
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 16
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 12
# is_leaf : False
# selected_feature : mean compactness
# selected_feature_index : 5
# max_info_gain : 0.477385626221
# best_split_mid_value : 0.1213
# ****************************************************************************************************
# Len 10
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 9
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 8
# ****************************************************************************************************
# level : 16
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 7
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 6
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 5
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 17
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 16.16
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 17
# Entropy : 0.636514168295
# predict_class : 1
# num_of_examples : 9
# is_leaf : False
# selected_feature : concave points error
# selected_feature_index : 17
# max_info_gain : 0.318979358669
# best_split_mid_value : 0.014995
# ****************************************************************************************************
# Len 4
# ****************************************************************************************************
# level : 17
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 3
# ****************************************************************************************************
# level : 18
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 18
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 18
# Entropy : 0.410116318288
# predict_class : 1
# num_of_examples : 7
# is_leaf : False
# selected_feature : worst concave points
# selected_feature_index : 27
# max_info_gain : 0.321334368354
# best_split_mid_value : 0.11155
# ****************************************************************************************************
# Len 2
# ****************************************************************************************************
# level : 18
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 19
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 3
# is_leaf : True
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 19
# Entropy : 0.562335144619
# predict_class : 1
# num_of_examples : 4
# is_leaf : False
# selected_feature : mean concavity
# selected_feature_index : 6
# max_info_gain : 0.34657359028
# best_split_mid_value : 0.08727
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 20
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 2
# is_leaf : True
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 20
# Entropy : 0.69314718056
# predict_class : 0
# num_of_examples : 2
# is_leaf : False
# selected_feature : mean radius
# selected_feature_index : 0
# max_info_gain : 0.0
# best_split_mid_value : 14.885
# ****************************************************************************************************
# Len 1
# ****************************************************************************************************
# level : 21
# Entropy : 0.0
# predict_class : 1
# num_of_examples : 1
# is_leaf : True
# ****************************************************************************************************
# Len 0
# ****************************************************************************************************
# level : 21
# Entropy : 0.0
# predict_class : 0
# num_of_examples : 1
# is_leaf : True

# %% [markdown]
# ### PyDotPlus Documentation Reference
# http://pydotplus.readthedocs.io/reference.html

# %%
import pydotplus as dot

def get_node_data(node, class_dict):
    data = ""
    if not node['is_leaf'] :
        data += node['selected_feature'] + " <= " + str(node['best_split_mid_value']) + "\n"
        data += "Gain = " + str(node['max_info_gain']) + "\n"
    data += "entropy = " + str(node['Entropy']) + "\n"
    data += "samples = " + str(node['num_of_examples']) + "\n"
    value = [0 for i in range(len(class_dict))]
    for index, name in class_dict.items():
        if name in node["class_counts"] :
            value[index] = (node["class_counts"][name])
    data += "value = " + str(value) + "\n"
    data += "class = " + class_dict[node['predict_class']]
        
    return data

def get_decision_tree_graph(tree_dict, class_dict):
    graph = dot.Dot(graph_type = "digraph")
    
    from collections import deque
    q = deque([tree_dict])
    
    
    while len(q)!= 0 :
        
        node = q.popleft()
        
        parent_node = get_node_data(node, class_dict)
        
        if 0 in node.keys() :
            q.append(node[0])
            child_0_node = get_node_data(node[0], class_dict)
            edge = dot.Edge(parent_node, child_0_node, label = True)
            graph.add_edge(edge)
            
        if 1 in node.keys() :
            q.append(node[1])
            child_1_node = get_node_data(node[1], class_dict)
            edge = dot.Edge(parent_node, child_1_node, label = False)
            graph.add_edge(edge)
    return graph

graph = get_decision_tree_graph(tree_dict, class_dict)
graph.write_png("breast_cancer_dataset_decision_tree.png")
# Out:
# True
